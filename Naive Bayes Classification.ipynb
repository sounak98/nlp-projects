# %% [markdown]
# # Naive Bayes Classifier

# %% [markdown]
# ## Imports and Initializations
#
# We need to import some common packages and library such as `numpy`, `matplotlib`, etc.

# %%
import os, pprint, pickle, math
from collections import Counter
import matplotlib.pyplot as plt
import numpy as np
from copy import deepcopy
import math as m

pp = pprint.PrettyPrinter(indent=2)

TRAIN_FILE_PATH = '/Users/sounak/Documents/clg/nlp/nlp-projects/data/gram_error/train.txt'
TEST_FILE_PATH = '/Users/sounak/Documents/clg/nlp/nlp-projects/data/gram_error/dev.txt'

# %% [markdown]
# ## Utility Functions
#
# These functions are for saving the probability and count dicts as pickle files for faster loading when the script is run later.

# %%
def save_obj(obj, name):
    if 'obj' not in os.listdir():
        os.mkdir('obj')
    with open('obj/'+ name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name):
    try:
        with open('obj/' + name + '.pkl', 'rb') as f:
            return pickle.load(f)
    except:
        return None

# %% [markdown]
# ## Tokenizing Training Data
#
# In the training data words are already tokenized. We only need to figure out which words contribute to grammatical errors and the classes that the grammatical error belongs to.

# %%
lines_train = load_obj('lines_train')
lines_test = load_obj('lines_test')

if not (lines_train and lines_test):
    f = open(TRAIN_FILE_PATH, 'r')
    text = f.read()
    f.close()
    raw_data_train = text.split('\n')
    lines_train = []
    temp = []
    for l in raw_data_train:
        if l == '':
            lines_train.append(temp)
            temp = []
        else:
            temp.append(l)           
    save_obj(lines_train, 'lines_train')

    f = open(TEST_FILE_PATH, 'r')
    text = f.read()
    f.close()    
    raw_data_test = text.split('\n')
    lines_test = []
    temp = []
    for l in raw_data_test:
        if l == '':
            lines_test.append(temp)
            temp = []
        else:
            temp.append(l)           
    save_obj(lines_test, 'lines_test')
    
print('lines_train and lines_test have been loaded')
# Out:
# lines_train and lines_test have been loaded

# %% [markdown]
# ## Classifer
#
# Here, we are creating the `Counter` with all the counts of the error grams and the correct grams classified according to the training data.

# %%
def get_grams(sent, i, n=1):
    grams = tuple()
    for j in range(i-n+1, i+1):
        try:
            if j < 0:
                grams += (' ', )
            else:
                grams += (sent[j].split('   ')[0], )
        except:
            grams += (' ', )
    return grams
        
def find_counts(data, n):
    counts_ = {}
    for sent in data:
        for i, word in enumerate(sent):
            tokens = word.split('   ')
            if len(tokens) == 3:
                try:
                    counts_[tokens[2]].update([get_grams(sent, i, n)])
                except KeyError:
                    counts_[tokens[2]] = Counter([get_grams(sent, i, n)])
                counts_['correct'].update([get_grams(sent, i, n)[:-1] + (tokens[1],)])
            else:
                try:
                    counts_['correct'].update([get_grams(sent, i, n)])
                except:
                    counts_['correct'] = Counter([get_grams(sent, i, n)])
    return counts_
    
counts = load_obj('counts')

if not counts:
    counts = {}
    for i in range(1, 4):
        counts[i] = find_counts(lines_train, i)
    save_obj(counts, 'counts')
print('counts have been loaded')
# Out:
# counts have been loaded

# %%
counts[2]['correct']
# Out:
# Counter({(' ', 'so'): 77,
#          ('so', 'vhtr'): 1,
#          ('vhtr', 'is'): 88,
#          ('is', 'environment'): 2,
#          ('environment', 'friendly'): 3,
#          ('friendly', 'and'): 5,
#          ('and', 'the'): 684,
#          ('the', 'most'): 195,
#          ('most', 'optimized'): 1,
#          ('optimized', 'solution'): 1,
#          ('solution', 'towards'): 2,
#          ('towards', 'green'): 2,
#          ('green', 'house'): 17,
#          ('house', 'errors'): 1,
#          ('effect', '.'): 10,
#          (' ', 'retrieved'): 20,
#          ('retrieved', 'on'): 9,
#          ('on', '5/09/2009.http'): 1,
#          ('5/09/2009.http', ':'): 1,
#          (':', 'transportation'): 1,
#          ('//www.purdue.edu/uns/x/2007a/070314agrawalbiomass.html', ')'): 1,
#          (' ', 'for'): 476,
#          ('for', 'instance'): 166,
#          ('instance', ','): 152,
#          (',', 'an'): 75,
#          ('an', 'insurance'): 9,
#          ('insurance', 'company'): 8,
#          ('company', 'will'): 7,
#          ('will', 'refuse'): 2,
#          ('refuse', 'to'): 9,
#          ('to', 'provide'): 133,
#          ('provide', 'any'): 3,
#          ('any', 'insurance'): 1,
#          ('insurance', 'coverage'): 11,
#          ('coverage', 'for'): 3,
#          ('for', 'an'): 29,
#          ('an', 'individual'): 65,
#          ('individual', 'who'): 13,
#          ('who', 'may'): 7,
#          ('may', 'have'): 39,
#          ('have', 'had'): 7,
#          ('had', 'been'): 40,
#          ('been', 'tested'): 8,
#          ('tested', 'positive'): 10,
#          ('positive', 'of'): 1,
#          ('of', 'a'): 360,
#          ('a', 'genetic'): 30,
#          ('genetic', 'disorder'): 38,
#          ('disorder', 'or'): 6,
#          ('or', 'has'): 1,
#          ('has', 'a'): 99,
#          ('a', 'high'): 51,
#          ('high', 'probability'): 1,
#          ('probability', '-'): 1,
#          ('of', '-'): 622,
#          ('acquiring', '-'): 1,
#          ('a', '-'): 221,
#          ('genetic', '-'): 9,
#          ('disorder', ','): 12,
#          (',', 'since'): 51,
#          ('since', 'the'): 110,
#          ('the', 'insurance'): 14,
#          ('company', 'finds'): 1,
#          ('finds', 'it'): 2,
#          ('it', 'a'): 9,
#          ('a', 'loss'): 3,
#          ('loss', 'to'): 2,
#          ('to', 'make'): 186,
#          ('make', 'a'): 22,
#          ('a', 'payout'): 1,
#          ('payout', 'to'): 3,
#          ('to', 'an'): 65,
#          ('an', "'already"): 1,
#          ("'already", 'or'): 1,
#          ('or', 'potentially-sick'): 1,
#          ('potentially-sick', "'"): 1,
#          ("'", 'individual'): 1,
#          ('individual', '.'): 17,
#          (' ', 'in'): 1350,
#          ('in', 'brief'): 9,
#          ('brief', ','): 8,
#          (',', 'with'): 160,
#          ('with', 'the'): 610,
#          ('the', 'advancement'): 21,
#          ('advancement', 'of'): 15,
#          ('of', 'medical'): 32,
#          ('medical', 'technologies'): 7,
#          ('technologies', ','): 33,
#          (',', 'the'): 2649,
#          ('the', 'robotic'): 13,
#          ('robotic', 'surgery'): 22,
#          ('surgery', 'systems'): 3,
#          ('systems', '-'): 2,
#          ('are', 'definitely'): 6,
#          ('definitely', 'benefit'): 7,
#          ('benefit', 'both'): 3,
#          ('both', 'the'): 43,
#          ('the', 'patients'): 42,
#          ('patients', 'and'): 10,
#          ('the', 'surgeons'): 7,
#          ('surgeons', '.'): 3,
#          (' ', 'shantakumar'): 1,
#          ('shantakumar', '( 1999 )'): 1,
#          ('1999', ','): 5,
#          (',', 'asher'): 1,
#          ('asher', '( 1996 and 1998 )'): 1,
#          ('1996', '( 1996 and 1998 )'): 1,
#          ('and', '( 1996 and 1998 )'): 1,
#          ('1998', ','): 4,
#          (',', 'lee'): 4,
#          ('lee', '( 1999 an 2001a )'): 1,
#          ('1999', '( 1999 an 2001a )'): 1,
#          ('and', '( 1999 an 2001a )'): 1,
#          ('2001a', ','): 1,
#          (',', '-'): 996,
#          ('have', 'pointed'): 2,
#          ('pointed', 'out'): 11,
#          ('out', 'the'): 32,
#          ('the', 'lack'): 75,
#          ('lack', 'of'): 134,
#          ('of', 'universal'): 1,
#          ('universal', 'coverage'): 1,
#          ('coverage', 'and'): 2,
#          ('of', 'adequacy'): 1,
#          ('adequacy', 'of'): 1,
#          ('of', 'funds'): 36,
#          ('funds', 'for'): 23,
#          ('for', 'retirement'): 13,
#          ('retirement', 'security'): 4,
#          ('security', 'in'): 9,
#          ('in', 'the'): 1756,
#          ('this', 'cpf'): 2,
#          ('cpf', 'scheme'): 8,
#          ('scheme', ','): 22,
#          (',', 'especially'): 103,
#          ('especially', 'for'): 25,
#          ('for', 'the'): 1073,
#          ('the', 'low-income'): 3,
#          ('low-income', 'elderly'): 1,
#          ('elderly', '('): 13,
#          ('(', 'as'): 18,
#          ('as', 'cited'): 19,
#          ('cited', 'in'): 20,
#          ('in', 'david'): 1,
#          ('david', 'r.'): 1,
#          ('r.', 'phillips'): 1,
#          ('phillips', 'and'): 1,
#          ('and', 'alfred'): 1,
#          ('alfred', 'c.m'): 1,
#          ('c.m', '.'): 1,
#          (' ', 'through'): 24,
#          ('through', 'these'): 4,
#          ('these', ','): 9,
#          ('-', 'engineers'): 1,
#          ('engineers', 'can'): 15,
#          ('can', 'predict'): 1,
#          ('predict', 'the'): 5,
#          ('the', 'impact'): 32,
#          ('impact', 'of'): 25,
#          ('a', 'possible'): 7,
#          ('possible', 'defect'): 1,
#          ('defeated', 'in'): 1,
#          ('in', 'current'): 3,
#          ('current', 'and'): 5,
#          ('and', 'faraway'): 2,
#          ('faraway', 'situations'): 1,
#          ('situation', ';'): 2,
#          (';', 'study'): 1,
#          ('study', 'about'): 1,
#          ('about', 'the'): 155,
#          ('the', 'leak'): 2,
#          ('leak', 'before'): 1,
#          ('before', 'break'): 1,
#          ('break', '('): 1,
#          ('(', 'lbb'): 1,
#          ('lbb', ')'): 1,
#          (')', 'technology'): 3,
#          ('technology', ';'): 3,
#          (';', 'make'): 1,
#          ('making', 'model'): 1,
#          ('model', 'for'): 2,
#          ('for', 'vessel'): 1,
#          ('vessel', 'cooling'): 1,
#          ('cooling', 'system'): 10,
#          ('system', '('): 19,
#          ('(', 'vcs'): 1,
#          ('vcs', ')'): 1,
#          (')', ';'): 3,
#          (';', 'analyse'): 1,
#          ('analyses', 'of'): 1,
#          ('of', 'the'): 2920,
#          ('the', 'moment'): 9,
#          ('moment', 'when'): 2,
#          ('when', 'the'): 106,
#          ('-', 'accident'): 13,
#          ('accident', 'happened'): 10,
#          ('happened', ';'): 1,
#          (';', 'explore'): 1,
#          ('-', 'safety'): 16,
#          ('safety', 'aspects'): 4,
#          ('aspects', 'of'): 30,
#          ('the', 'ways'): 14,
#          ('way', '-'): 12,
#          ('how', 'to'): 54,
#          ('to', 'combine'): 1,
#          ('combine', 'the'): 1,
#          ('the', 'reactor'): 90,
#          ('reactor', 'to'): 13,
#          ('to', 'the'): 1355,
#          ('the', 'hydrogen'): 7,
#          ('hydrogen', 'production'): 22,
#          ('production', 'plant'): 5,
#          ('plant', '.'): 55,
#          (' ', 'pursuing'): 1,
#          ('pursing', 'patents'): 1,
#          ('patents', 'is'): 2,
#          ('are', 'not'): 159,
#          ('not', 'easy'): 3,
#          ('easy', 'as'): 1,
#          ('as', 'they'): 173,
#          ('they', '-'): 80,
#          ('will', 'take'): 14,
#          ('take', 'a long time'): 1,
#          ('long', 'period'): 10,
#          ('period', 'of'): 29,
#          ('of', 'time'): 46,
#          ('time', 'to'): 38,
#          ('to', 'process'): 3,
#          ('process', ','): 115,
#          (',', 'requiring'): 1,
#          ('requiring', 'large'): 1,
#          ('large', 'amount'): 48,
#          ('amount', 'of'): 242,
#          ('of', 'money'): 94,
#          ('money', '.'): 25,
#          (' ', 'critics'): 27,
#          ('critics', 'of'): 12,
#          ('of', 'this'): 119,
#          ('this', 'proposal'): 1,
#          ('proposal', 'have'): 1,
#          ('out', 'that'): 30,
#          ('that', 'the'): 791,
#          ('the', 'money'): 85,
#          ('money', 'set'): 1,
#          ('set', 'aside'): 25,
#          ('aside', 'for'): 8,
#          ('for', 'this'): 35,
#          ('this', 'scheme'): 19,
#          ('scheme', 'will'): 2,
#          ('will', 'go'): 6,
#          ('go', 'to'): 15,
#          ('to', 'waste'): 3,
#          ('waste', 'if'): 1,
#          ('if', 'the elderly'): 1,
#          ('they', 'passed'): 1,
#          ('pass', 'away'): 1,
#          ('away', 'even'): 1,
#          ('even', 'before'): 5,
#          ('before', 'they'): 17,
#          ('they', 'can'): 149,
#          ('can', 'utilize'): 3,
#          ('utilize', 'them'): 1,
#          ('them', '.'): 154,
#          (' ', 'when'): 89,
#          ('when', 'people'): 17,
#          ('people', 'get'): 6,
#          ('get', 'older'): 1,
#          ('older', ','): 11,
#          (',', 'it'): 834,
#          ('it', 'is'): 1030,
#          ('is', 'only'): 45,
#          ('only', 'natural'): 2,
#          ('natural', 'that'): 2,
#          ('that', 'they'): 184,
#          ('they', 'are'): 346,
#          ('are', 'more'): 69,
#          ('more', 'prone'): 6,
#          ('prone', 'to'): 20,
#          ('to', 'illness'): 3,
#          ('illness', 'be'): 1,
#          ('be', 'it'): 11,
#          ('it', 'mental'): 1,
#          ('mentally', 'or'): 1,
#          ('or', 'physical'): 2,
#          ('physically', '.'): 3,
#          (' ', 'This'): 34,
#          ('these', 'permits'): 1,
#          ('permit', 'the'): 1,
#          ('the', 'aged'): 797,
#          ('aged', 'population'): 29,
#          ('population', 'to'): 13,
#          ('to', 'continue'): 28,
#          ('continue', 'serving'): 2,
#          ('serving', '-'): 2,
#          ('the', 'society'): 242,
#          ('society', 'and'): 46,
#          ('and', 'also'): 85,
#          ('also', 'in'): 11,
#          ('in', 'certain'): 18,
#          ('certain', 'ways'): 1,
#          ('ways', 'helps'): 1,
#          ('help', 'to'): 145,
#          ('to', 'build'): 78,
#          ('build', 'confidence'): 1,
#          ('confidence', 'in'): 9,
#          ('the', 'elderly'): 997,
#          ('elderly', '.'): 233,
#          (' ', 'however'): 797,
#          ('however', ','): 828,
#          ('the', 'two'): 80,
#          ('two', 'technologies'): 15,
#          ('technologies', 'are'): 24,
#          ('are', 'similar'): 6,
#          ('similar', 'in'): 6,
#          ('these', 'the'): 1,
#          ('two', 'stages'): 3,
#          ('stages', '-'): 2,
#          ('after', '-'): 18,
#          ('recognizing', '-'): 2,
#          ('problem', '-'): 29,
#          ('or', '-'): 80,
#          ('need', '-'): 26,
#          (':', '-'): 59,
#          ('-', '-'): 9,
#          ('further', '-'): 10,
#          ('research', 'on'): 43,
#          ('on', 'basic'): 1,
#          ('basic', '-'): 4,
#          ('and', 'application'): 3,
#          ('application', '-'): 7,
#          (',', 'and'): 601,
#          ('and', 'development'): 236,
#          ('development', '-'): 49,
#          ('stages', '.'): 4,
#          (' ', 'beside'): 1,
#          ('beside', 'the'): 4,
#          ('of', 'facilities'): 8,
#          ('facilities', ','): 16,
#          (',', 'engineers'): 66,
#          ('engineers', 'are'): 22,
#          ('are', 'constrained'): 3,
#          ('constrain', 'by'): 1,
#          ('by', 'the'): 444,
#          ('the', 'strict'): 3,
#          ('strict', 'regulations'): 3,
#          ('regulatory', 'imposed'): 1,
#          ('imposed', 'by'): 3,
#          ('the', 'governement'): 1,
#          ('governement', '.'): 1,
#          (' ', 'thus'): 293,
#          ('thus', 'it'): 26,
#          ('it', 'comes'): 27,
#          ('comes', 'as'): 2,
#          ('as', 'no'): 4,
#          ('no', 'surprise'): 3,
#          ('surprise', 'that'): 3,
#          ('that', 'governments'): 14,
#          ('governments', 'around'): 3,
#          ('around', 'number'): 1,
#          ('the', 'world'): 297,
#          ('world', 'have'): 10,
#          ('have', 'stepped'): 2,
#          ('stepped', 'up'): 2,
#          ('up', 'their'): 16,
#          ('their', 'efforts'): 3,
#          ('efforts', 'to'): 14,
#          ('to', 'alleviate'): 8,
#          ('alleviate', 'the'): 11,
#          ('the', 'effects'): 32,
#          ('effects', 'of'): 45,
#          ('of', 'global'): 23,
#          ('global', 'aging'): 9,
#          ('aging', '.'): 31,
#          (' ', 'hopefully'): 7,
#          ('hopefully', ','): 8,
#          ('the', 'next'): 71,
#          ('next', 'typical'): 1,
#          ('typical', 'image'): 2,
#          ('image', 'left'): 1,
#          ('left', 'by'): 1,
#          ('by', 'china'): 2,
#          ('china', 'to'): 2,
#          ('world', 'will'): 8,
#          ('will', 'be'): 586,
#          ('be', 'that of the'): 1,
#          ('-', 'e-bike'): 4,
#          ('e-bike', '.'): 2,
#          (' ', 'the'): 1435,
#          ('-', 'iphone'): 4,
#          ('iphone', '-'): 3,
#          ('now', 'can'): 7,
#          ('can', 'serve'): 2,
#          ('serve', 'many'): 1,
#          ('many', 'functions , such as'): 1,
#          ('purposes', 'functions , such as'): 1,
#          ('of', 'functions , such as'): 1,
#          ('users', 'functions , such as'): 1,
#          ('like', 'entertainment'): 1,
#          ('entertainment', 'and'): 3,
#          (',', 'video'): 4,
#          ('video', 'conference'): 1,
#          ('conference', '.'): 1,
#          (' ', 'apart'): 24,
#          ('apart', 'from'): 26,
#          ('from', 'that'): 8,
#          ('that', ','): 116,
#          ('is', 'well'): 12,
#          ('well', 'known'): 5,
#          ('known', 'how'): 1,
#          ('how', 'corrupted'): 1,
#          ('corrupted', 'the'): 1,
#          ('the', 'country'): 533,
#          ('country', 'is'): 19,
#          ('is', '.'): 12,
#          (' ', 'or'): 3,
#          ('or', 'is'): 2,
#          ('is', 'it'): 9,
#          ('it', 'that'): 3,
#          ('that', 'it'): 166,
#          ('is', 'a'): 462,
#          ('a', 'must'): 6,
#          ('must', 'to'): 3,
#          ('to', 'reveal'): 68,
#          ('reveal', 'it'): 3,
#          ('it', 'due'): 1,
#          ('due', 'to'): 395,
#          ('to', 'reality'): 2,
#          ('reality', 'and'): 1,
#          ('and', 'we'): 22,
#          ('we', ','): 3,
#          (',', 'individuals'): 41,
#          ('individual', 'do'): 2,
#          ('do', 'not'): 219,
#          ('not', 'have'): 143,
#          ('have', 'the'): 189,
#          ('the', 'final'): 100,
#          ('final', 'say'): 68,
#          ('say', 'to'): 8,
#          ('reveal', 'our'): 1,
#          ('our', 'testing'): 1,
#          ('testing', 'to'): 10,
#          ('the', 'public'): 303,
#          ('public', '.'): 38,
#          (' ', 'water'): 4,
#          ('water', 'treatment'): 3,
#          ('treatment', 'is'): 2,
#          ('has', 'largely'): 1,
#          ('largely', 'been'): 1,
#          ('been', 'classified'): 1,
#          ('classified', 'as'): 2,
#          ('as', 'one'): 28,
#          ('one', 'engineering'): 1,
#          ('engineering', 'process'): 16,
#          ('process', 'which'): 11,
#          ('which', 'turns'): 1,
#          ('turns', 'used-water'): 1,
#          ('used-water', 'into'): 1,
#          ('into', 'clean'): 1,
#          ('clean', ','): 7,
#          (',', 'acceptable'): 1,
#          ('acceptable', 'water'): 1,
#          ('water', 'for'): 2,
#          ('for', 'end'): 1,
#          ('end', 'use'): 1,
#          ('use', ','): 9,
#          ('and', 'sometime'): 1,
#          ('sometime', 'even'): 1,
#          ('even', 'drinkable'): 1,
#          ('drinkable', 'water'): 4,
#          ('water', '.'): 24,
#          ('the', 'repercussions'): 3,
#          ('repercussions', 'following'): 1,
#          ('following', 'the'): 7,
#          ('the', 'aging'): 371,
#          ('aging', 'population'): 375,
#          ('population', 'would'): 12,
#          ('would', 'be'): 239,
#          ('be', 'social'): 1,
#          ('social', 'and'): 38,
#          ('and', 'economic'): 32,
#          ('economy', 'concerns'): 1,
#          ('concerns', 'as'): 2,
#          ('as', 'the'): 530,
#          ('the', 'younger'): 83,
#          ('younger', 'generations'): 25,
#          ('generations', 'would'): 1,
#          ('would', 'have'): 65,
#          ('have', 'to'): 228,
#          ('to', 'struggle'): 4,
#          ('struggle', 'to'): 4,
#          ('to', 'support'): 148,
#          ('support', 'their'): 32,
#          ('their', 'families'): 32,
#          ('families', '.'): 17,
#          ('the', 'burden'): 64,
#          ('burden', 'on'): 34,
#          ('on', 'an'): 16,
#          ('an', 'average'): 13,
#          ('average', 'working'): 1,
#          ('working', 'class'): 6,
#          ('class', 'adult'): 1,
#          ('adult', 'has'): 1,
#          ('has', 'increased'): 28,
#          ('been', 'increased'): 7,
#          ('increasing', 'with'): 2,
#          ('with', 'yearly'): 1,
#          ('yearly', 'inflation'): 1,
#          ('inflation', 'and'): 3,
#          ('and', 'higher'): 11,
#          ('higher', 'standards'): 1,
#          ('standards', 'of'): 8,
#          ('of', 'living'): 80,
#          ('living', '.'): 27,
#          (' ', 'engineers'): 28,
#          ('engineers', 'have'): 29,
#          ('have', 'come up with'): 1,
#          ('brought', 'come up with'): 1,
#          ('out', 'some'): 3,
#          ('some', 'solutions'): 1,
#          ('solutions', 'to'): 36,
#          ('for', 'saving'): 2,
#          ('saving', '-'): 5,
#          ('the', 'petroleum'): 5,
#          ('petroleum', '.'): 5,
#          (' ', 'one'): 195,
#          ('one', 'step'): 3,
#          ('step', 'that'): 1,
#          ('that', 'could have been'): 1,
#          ('can', 'could have been'): 4,
#          ('be', 'taken'): 41,
#          ('taken', 'would'): 1,
#          ('be', 'to'): 18,
#          ('to', 'remove'): 7,
#          ('remove', 'sharp'): 1,
#          ('sharp', '148-degree'): 1,
#          ('148-', '148-degree'): 1,
#          ('degree', 'turns'): 1,
#          ('turns', 'that'): 1,
#          ('the', 'pa1736'): 1,
#          ('pa1736', ','): 1,
#          (',', 'a'): 302,
#          ('a', '747'): 1,
#          ('747', ','): 1,
#          (',', 'would'): 10,
#          ('would', 'not'): 72,
#          ('not', 'be'): 417,
#          ('be', 'able'): 191,
#          ('able', 'to'): 432,
#          ('to', 'take'): 176,
#          ('take', '.'): 3,
#          (' ', 'This method is basically to'): 1,
#          ('basically', 'set'): 1,
#          ('set', 'up'): 35,
#          ('up', 'a'): 25,
#          ('a', 'healthier'): 12,
#          ('healthier', 'financial'): 1,
#          ('financial', 'saving'): 1,
#          ('saving', 'system'): 1,
#          ('system', '-'): 19,
#          ('according', '-'): 11,
#          ('to', '-'): 656,
#          ('different', '-'): 11,
#          ('period', '-'): 8,
#          ('the', '-'): 1068,
#          ('economic', '-'): 29,
#          ('situation', '-'): 12,
#          ('with', '-'): 145,
#          ('proper', '-'): 5,
#          ('interest', '-'): 2,
#          ('rate', '-'): 4,
#          ('and', '-'): 466,
#          ('bonus', '.'): 3,
#          (' ', 'on'): 162,
#          ('on', 'fashionable'): 1,
#          ('the', 'other'): 222,
#          ('other', 'hand'): 116,
#          ('hand', ','): 138,
#          (',', 'apple'): 5,
#          ('apple', 'has'): 1,
#          ('has', 'also'): 40,
#          ('also', 'release'): 2,
#          ('release', 'its'): 1,
#          ('its', 'highly'): 2,
#          ('highly', 'portable'): 1,
#          ('portable', 'laptop'): 1,
#          ('laptop', 'called'): 1,
#          ('called', 'macbook'): 1,
#          ('macbook', 'pro'): 2,
#          ('pro', 'which'): 1,
#          ('which', 'is'): 260,
#          ('is', 'the'): 422,
#          ('the', 'thinnest'): 1,
#          ('thinnest', '17-inch'): 1,
#          ('17-inch', 'laptop'): 1,
#          ('laptop', 'in'): 5,
#          ('world', '.'): 81,
#          ('the', '3m'): 6,
#          ('3m', 'researchers'): 3,
#          ('researchers', 'found'): 2,
#          ('found', 'that'): 15,
#          ('out', 'this'): 6,
#          ('this', 'failed'): 1,
#          ('failed', 'bonding'): 1,
#          ('bonding', 'agent'): 10,
#          ('agent', 'was'): 2,
#          ('was', 'suitable'): 2,
#          ('suitable', 'for'): 11,
#          ('for', 'attaching'): 1,
#          ('attaching', 'notes'): 1,
#          ('notes', 'which'): 2,
#          ('which', 'satisfied'): 1,
#          ('satisfy', 'many'): 1,
#          ('many', 'people'): 62,
#          ('people', "'s"): 88,
#          ("'s", 'needs'): 10,
#          ('needs', '.'): 56,
#          (' ', 'besides'): 143,
#          ('besides', 'that'): 35,
#          ('the', 'cpf'): 24,
#          ('cpf', 'can'): 1,
#          ('can', 'also'): 64,
#          ('also', 'be'): 91,
#          ('be', 'used'): 187,
#          ('used', 'to'): 137,
#          ('to', 'buy'): 21,
#          ('buy', 'a'): 6,
#          ('a', 'house'): 3,
#          ('house', ','): 6,
#          (',', 'cover'): 1,
#          ('cover', 'hospital'): 2,
#          ('hospital', 'expenses'): 1,
#          ('expenses', 'or'): 2,
#          ('or', 'for'): 3,
#          ('for', '-'): 244,
#          ('child', '-'): 3,
#          ("'s", 'education'): 10,
#          ('education', 'fees'): 2,
#          ('fees', '.'): 12,
#          ('however', 'taking'): 1,
#          ('taking', 'a'): 6,
#          ('a', 'look'): 4,
#          ('look', 'around'): 4,
#          ('around', 'us'): 5,
#          ('us', 'today'): 3,
#          ('today', ','): 27,
#          (',', 'current'): 33,
#          ('current', 'research'): 51,
#          ('research', ','): 54,
#          (',', 'development'): 22,
#          ('development', 'and'): 54,
#          ('and', 'various'): 7,
#          ('various', 'policies'): 5,
#          ('policies', 'have'): 44,
#          ('have', 'evolved'): 1,
#          ('evolved', 'to'): 4,
#          ('an', 'extent'): 4,
#          ('extent', 'large'): 1,
#          ('large', 'enough'): 1,
#          ('enough', 'to'): 37,
#          ('to', 'dismiss'): 1,
#          ('dismiss', '-'): 1,
#          ('our', 'concerns'): 1,
#          ('concerns', 'about'): 19,
#          ('with', 'a'): 167,
#          ('a', 'greying'): 4,
#          ('greying', 'population'): 4,
#          ('population', '.'): 172,
#          (' ', 'but'): 93,
#          ('but', 'on'): 6,
#          ('on', 'the'): 1280,
#          (',', 'not'): 59,
#          ('not', 'all'): 15,
#          ('all', 'factors'): 2,
#          ('factors', 'are'): 10,
#          ('are', 'within'): 2,
#          ('within', 'the'): 49,
#          ('the', 'control'): 9,
#          ('control', 'of'): 8,
#          ('of', 'human'): 60,
#          ('human', '-'): 31,
#          ("'s", 'capability'): 3,
#          ('capability', '.'): 3,
#          (' ', 'at'): 54,
#          ('at', 'that'): 22,
#          ('that', 'point'): 3,
#          ('point', ','): 15,
#          (',', 'trevor'): 1,
#          ('trevor', 'baylis'): 1,
#          ('baylis', 'came'): 1,
#          ('came', 'up'): 13,
#          ('up', 'with'): 82,
#          ('the', 'idea'): 44,
#          ('idea', 'of'): 34,
#          ('-', 'wind-up'): 1,
#          ('wind-up', 'radio'): 2,
#          ('radio', ','): 2,
#          (',', 'making'): 25,
#          ('making', 'the'): 18,
#          ('-', 'idea'): 1,
#          ('of', 'broadcasting'): 1,
#          ('broadcasting', 'education'): 1,
#          ('education', 'possible'): 1,
#          ('possible', '.'): 25,
#          ('in', 'addition'): 218,
#          ('addition', 'to'): 21,
#          ('to', 'that'): 10,
#          ('money', 'that'): 10,
#          ('that', 'is'): 135,
#          ('is', 'spent'): 6,
#          ('spent', 'on helping'): 1,
#          ('to', 'on helping'): 1,
#          ('help', 'the'): 96,
#          ('elderly', 'is'): 29,
#          ('is', 'partially'): 2,
#          ('partially', 'their'): 1,
#          ('their', 'money'): 8,
#          ('money', 'which'): 2,
#          ('which', 'was'): 47,
#          ('was', 'deducted'): 1,
#          ('deducted', 'through'): 1,
#          ('through', 'tax'): 1,
#          ('tax', 'payment'): 1,
#          ('payment', '.'): 3,
#          (' ', 'However , this'): 2,
#          ('this', 'is'): 262,
#          ('is', 'not'): 329,
#          ('not', 'true'): 9,
#          ('true', 'as'): 7,
#          ('the', 'vhtr'): 181,
#          ('is', 'developing'): 4,
#          ('developing', 'a'): 12,
#          ('a', 'passive'): 7,
#          ('passive', 'heat'): 3,
#          ('heat', 'removal'): 6,
#          ('removal', 'system'): 4,
#          ('system', 'that'): 6,
#          ('that', 'can'): 81,
#          ('could', 'achieve'): 1,
#          ('achieve', 'a'): 13,
#          ('a', 'higher'): 40,
#          ('higher', 'level'): 6,
#          ('level', 'of'): 59,
#          ('of', 'safety'): 37,
#          ('safety', 'which'): 2,
#          ('not', 'dependent'): 1,
#          ('dependent', 'on'): 34,
#          ('on', 'human'): 13,
#          ("'s", 'intervention'): 2,
#          ('intervention', '.'): 4,
#          (' ', 'hence'): 277,
#          ('hence', ','): 272,
#          (',', 'in'): 282,
#          ('in', 'future'): 24,
#          ('future', ','): 42,
#          (',', 'when'): 81,
#          ('when', 'migration'): 1,
#          ('migration', 'issues'): 1,
#          ('issue', 'becomes'): 1,
#          ('becomes', 'a'): 9,
#          ('a', 'global'): 10,
#          ('global', 'pandemic'): 1,
#          ('pandemic', ','): 2,
#          ('-', 'public'): 34,
#          ('public', 'should'): 6,
#          ('should', 'give'): 8,
#          ('give', 'a'): 12,
#          ('a', 'helping'): 1,
#          ('helping', 'hand'): 2,
#          ('hand', 'to'): 5,
#          ('aged', 'since'): 2,
#          ('the', 'children'): 56,
#          ('children', 'will'): 13,
#          ('will', 'no'): 10,
#          ('no', 'longer'): 44,
#          ('longer', 'take'): 1,
#          ('take', 'care'): 110,
#          ('care', 'of'): 221,
#          ('of', 'their'): 263,
#          ('his', 'needs'): 1,
#          (' ', 'an'): 51,
#          ('an', 'example'): 33,
#          ('example', 'could'): 2,
#          ('could', 'be'): 166,
#          ('be', 'seen'): 35,
#          ('seen', 'in'): 9,
#          ('the', 'following'): 15,
#          ('following', 'stressesfl'): 1,
#          ('article', 'stressesfl'): 1,
#          ('which', 'writes'): 1,
#          ('writes', '``'): 1,
#          ('``', 'is'): 2,
#          ('is', "n't"): 4,
#          ("n't", 'the'): 2,
#          ('the', 'hdb'): 5,
#          ('hdb', "'s"): 2,
#          ("'s", 'policies'): 5,
#          ('policies', 'self-contradictory'): 1,
#          ('self-contradictory', ','): 1,
#          ('when', 'it'): 43,
#          ('it', "'s"): 15,
#          ("'s", 'income'): 5,
#          ('income', 'ceiling'): 1,
#          ('ceiling', 'policy'): 1,
#          ('policy', "'forces"): 1,
#          ("'forces", "'"): 1,
#          ("'", 'the'): 2,
#          ('the', 'lower-income'): 2,
#          ('lower-income', 'to'): 1,
#          ('buy', 'larger'): 1,
#          ('larger', 'flats'): 1,
#          ('flats', 'than'): 1,
#          ('than', 'they'): 3,
#          ('can', 'afford'): 14,
#          ('afford', '...'): 1,
#          ('...', 'hdb'): 1,
#          ('income', 'eligibility'): 1,
#          ('eligibility', 'requires'): 1,
#          ('requires', 'a'): 10,
#          ('a', 'household'): 3,
#          ('household', 'earning'): 2,
#          ('earning', 'more'): 2,
#          ('more', 'than'): 99,
#          ('than', '$'): 4,
#          ('$', '2,000'): 2,
#          ('2,000', 'a'): 1,
#          ('a', 'month'): 4,
#          ('month', 'to'): 2,
#          ('a', 'flat'): 3,
#          ('flat', 'that'): 1,
#          ('is', 'bigger'): 1,
#          ('bigger', 'than'): 1,
#          ('than', 'a'): 24,
#          ('a', 'two-room'): 1,
#          ('two-room', 'flat'): 1,
#          ('flat', '...'): 1,
#          ('...', 'a'): 1,
#          ('earning', 'just'): 1,
#          ('just', 'over'): 2,
#          ('over', '$'): 6,
#          ('$', '3,000'): 2,
#          ('3,000', ','): 1,
#          (',', 'is'): 76,
#          ('is', 'also'): 163,
#          ('also', 'not'): 9,
#          ('not', 'eligible'): 2,
#          ('eligible', 'to'): 2,
#          ('a', 'three-room'): 1,
#          ('three-room', 'flat'): 1,
#          ('flat', ','): 3,
#          ('and', 'have'): 30,
#          ('a', 'four-room'): 1,
#          ('four-room', 'flat'): 1,
#          ('flat', '.'): 5,
#          ('thus', ','): 274,
#          ('is', 'fair'): 1,
#          ('fair', 'to'): 3,
#          ('to', 'say'): 16,
#          ('say', 'that'): 38,
#          ('that', 'both'): 9,
#          ('either', 'conventional'): 1,
#          ('conventional', 'technology'): 8,
#          ('technology', 'or'): 4,
#          ('or', 'serendipitous'): 2,
#          ('serendipitous', 'technology'): 6,
#          ('technology', 'are'): 7,
#          ('is', 'stimulated'): 2,
#          ('stimulated', 'by'): 2,
#          ('the', 'realization'): 4,
#          ('realization', 'of'): 4,
#          ('of', 'problems'): 18,
#          ('problems', 'and'): 27,
#          ('and', 'needs'): 6,
#          (' ', 'as'): 463,
#          ('country', 'will'): 27,
#          ('will', 'have'): 107,
#          ('have', 'a smaller'): 1,
#          ('less', 'work'): 1,
#          ('working', 'force'): 14,
#          ('force', 'in'): 5,
#          ('in', '2030'): 5,
#          ('2030', ','): 14,
#          ('the', 'government'): 747,
#          ('government', 'should'): 140,
#          ('should', 'invest'): 9,
#          ('invest', 'more'): 11,
#          ('more', 'money'): 81,
#          ('money', 'on'): 73,
#          ('on', 'education'): 25,
#          ('education', 'to'): 9,
#          ('to', 'obtain'): 15,
#          ('obtain', 'a'): 3,
#          ('a', 'stronger'): 6,
#          ('stronger', 'work'): 2,
#          ('force', 'to'): 5,
#          ('support', 'the'): 67,
#          ('country', 'and'): 40,
#          ('the', 'large'): 16,
#          ('large', 'group'): 3,
#          ('group', 'of'): 55,
#          ('of', 'elderly'): 77,
#          ('-', 'bionic'): 2,
#          ('bionic', 'eyes'): 3,
#          ('eyes', ','): 4,
#          ('it', 'was'): 128,
#          ('was', 'done'): 4,
#          ('done', 'via'): 1,
#          ('via', 'research'): 15,
#          ('research', 'after'): 1,
#          ('after', 'it was seen'): 1,
#          ('seeing', 'it was seen'): 1,
#          ('it', 'in'): 15,
#          ('in', 'a'): 295,
#          ('a', 'movie'): 1,
#          ('movie', 'called'): 1,
#          ('called', "'terminator"): 1,
#          ("'terminator", "'"): 1,
#          ("'", ','): 15,
#          (',', 'where'): 48,
#          ('where', 'a'): 7,
#          ('a', 'woman'): 4,
#          ('woman', 'is'): 1,
#          ('is', 'able'): 54,
#          ('to', 'zoom'): 1,
#          ('zoom', 'into'): 1,
#          ('on', 'places'): 1,
#          ('places', 'that'): 1,
#          ('that', 'are'): 101,
#          ('are', 'far'): 3,
#          ('far', 'away'): 5,
#          ('away', '.'): 11,
#          ('as', 'a'): 375,
#          ('a', 'result'): 135,
#          ('result', ','): 114,
#          (',', 'many'): 119,
#          ('many', 'students'): 3,
#          ('students', 'get'): 1,
#          ('get', 'used'): 2,
#          ('to', 'accepting'): 1,
#          ('accepting', '-'): 1,
#          ('the', 'information'): 58,
#          ('information', '-'): 14,
#          ('in', '-'): 433,
#          ('references', 'without'): 1,
#          ('without', 'thinking'): 2,
#          ('thinking', 'and'): 5,
#          ('and', 'investigating'): 1,
#          ('investigating', 'by'): 1,
#          ('by', 'themselves'): 9,
#          ('themselves', '.'): 51,
#          (' ', 'with'): 281,
#          ('with', 'this'): 40,
#          ('this', 'kind'): 20,
#          ('kind', 'of'): 62,
#          ('of', 'hydrogen'): 18,
#          ('hydrogen', 'energy'): 5,
#          ('energy', ','): 73,
#          ('a', 'lot'): 142,
#          ('lot', 'of'): 98,
#          ('problems', 'that'): 42,
#          ('that', 'obese'): 1,
#          ('obese', 'us'): 1,
#          ('today', 'will'): 1,
#          ('be', 'solved.no'): 1,
#          ('solved.no', 'wars'): 1,
#          ('wars', 'for'): 1,
#          ('for', 'energy'): 25,
#          ('energy', 'will'): 17,
#          ('will', 'break'): 2,
#          ('break', '.'): 2,
#          (' ', 'These'): 10,
#          ('there', 'are'): 409,
#          ('are', 'the'): 102,
#          ('the', 'architectural'): 1,
#          ('architectural', ','): 2,
#          (',', 'biomedical'): 2,
#          ('biomedical', ','): 2,
#          (',', 'civil'): 1,
#          ('civil', ','): 1,
#          (',', 'computer'): 2,
#          ('computer', ','): 4,
#          (',', 'electrical'): 1,
#          ('electrical', ','): 1,
#          (',', 'industrial'): 5,
#          ('industrial', ','): 1,
#          (',', 'mechanical'): 1,
#          ('mechanical', 'and'): 1,
#          ('and', 'software'): 1,
#          ('software', 'engineering'): 1,
#          ('engineering', '.'): 5,
#          (' ', 'moreover'): 175,
#          ('moreover', ','): 172,
#          (',', 'for'): 95,
#          ('the', 'generation'): 93,
#          ('generation', '('): 10,
#          ('(', 'iv'): 3,
#          ('iv', ')'): 7,
#          (')', 'reactors'): 7,
#          ('reactors', ','): 63,
#          (',', 'there'): 416,
#          ('there', 'is'): 313,
#          ...})

# %% [markdown]
# ## Probabilities
#
# Here, we are calculating the probabilities of the ngrams that are seen in the corpus.

# %%
def get_probability(group, error_class, n):
    return counts[n][error_class][group] / sum(counts[n][error_class].values())

# %% [markdown]
# ## Smoothing
#
# But what about the unseen ngrams? We deal with them using the add-k smoothing where we take the value of `k` as `0.1`.

# %%
error_classes = counts[1].keys()
N = {}
S = {}
V = {}

vocabulary = {}
for i in range(1, 4):
    vocabulary[i] = set()
    N[i] = dict()
    for e in error_classes:
        vocabulary[i] = vocabulary[i] | set(counts[i][e].keys())
        N[i][e] = sum(counts[i][e].values())
    V[i] = len(vocabulary[i])

for i in range(1, 4):
    S[i] = {}
    for e in error_classes:
        S[i][e] = sum([counts[i][e][_] for _ in vocabulary[i]]) + V[i]

# %%
def get_count(group, error_class, n):
    return counts[n][error_class][group]
    
def get_smoothed_prob(group, error_class, n, factor=0.1):
    return (get_count(group, error_class, n) + factor) / S[n][error_class]

probs = load_obj('probs')
if not probs:
    probs = deepcopy(counts)
    for i in range(1, 4):
        for cls in probs[i].keys():
            for group in probs[i][cls].keys():
                probs[i][cls][group] = get_smoothed_prob(group, cls, i)
        save_obj(probs, 'probs')
print('probs have been loaded')

def get_prob(group, error_class, n):
    if group in probs[n][error_class].keys():
        return probs[n][error_class][group]
    else:
        return get_smoothed_prob(group, error_class, n)
# Out:
# probs have been loaded

# %% [markdown]
# ## Calculating `P(gram|class)`
#
# We define functions which will return the conditional probability of a gram given a class and the function which returns the sorted probabilites of the classes given the gram.

# %%
def prob_class(groups, error_class, n, log=True):
    probs_grams = [get_prob(g, error_class, n) for g in groups]
    product = np.product(probs_grams)
    final_prob = product * (N[n][error_class] / sum(N[n].values()))
    if log:
        return np.log(final_prob)
    return final_prob

def naive_classifier(groups, n):
    temp = [(e, prob_class(groups, e, n)) for e in error_classes]
    return sorted(temp, key=lambda k: k[1], reverse=True)

# %%
sent = lines_test[2]
sent_grams = lambda sent, n: [get_grams(sent, i, n) for i in range(len(sent))]

# %%
def get_errors(sent):
    tokens = sent_grams(sent, 2)
    tokens = [sent_grams(_, 1) for _ in tokens]
    for token in tokens:
        classes = [(token, naive_classifier(token, 1)[:4]) for token in tokens]
        pp.pprint(classes)

get_errors(sent)
# Out:
# [ ( [(' ',), ('one',)],
#     [ ('correct', -21.66288323759064),
#       ('Rloc-', -23.77210245289838),
#       ('Um', -24.495255181817317),
#       ('Wci', -24.513283587630752)]),
#   ( [('one',), ('cause',)],
#     [ ('correct', -14.003240283025958),
#       ('Rloc-', -20.05853038619407),
#       ('Wci', -20.118834432958316),
#       ('Um', -20.78168311511301)]),
#   ( [('cause',), ('for',)],
#     [ ('correct', -12.526439875002708),
#       ('Wci', -18.320733788391813),
#       ('Um', -18.785129233238944),
#       ('Rloc-', -18.92340817548617)]),
#   ( [('for',), ('this',)],
#     [ ('correct', -10.265688996964904),
#       ('Um', -16.582499237335814),
#       ('Rloc-', -16.748102283857598),
#       ('Wci', -16.913064567687186)]),
#   ( [('this',), ('is',)],
#     [ ('correct', -9.923593730785608),
#       ('Um', -16.343986188690504),
#       ('Rloc-', -16.377819957581163),
#       ('Wci', -17.204546518048744)]),
#   ( [('is',), ('attributed',)],
#     [ ('correct', -15.13445736207576),
#       ('Wci', -19.962142455702384),
#       ('Um', -22.26018825129794),
#       ('Rloc-', -22.266697915914044)]),
#   ( [('attributed',), ('to',)],
#     [ ('correct', -14.368406591973725),
#       ('Wci', -18.62482863220175),
#       ('Rloc-', -21.338628898980055),
#       ('Um', -21.412132815116927)]),
#   ( [('to',), ('the',)],
#     [ ('correct', -6.602367685677116),
#       ('Um', -12.825227011289389),
#       ('Rloc-', -12.939994043687951),
#       ('Wci', -13.738785215691207)]),
#   ( [('the',), ('era',)],
#     [ ('correct', -13.716501014512183),
#       ('ArtOrDet', -20.009326849501306),
#       ('Um', -20.70413992358652),
#       ('Rloc-', -20.89892053673806)]),
#   ( [('era',), ('of',)],
#     [ ('correct', -14.5176127145645),
#       ('Rloc-', -21.3351397119091),
#       ('Um', -21.515769880927195),
#       ('Wci', -21.78707857624817)]),
#   ( [('of',), ('baby',)],
#     [ ('correct', -13.361292108275743),
#       ('Um', -18.471247443203772),
#       ('Wci', -19.3891833034498),
#       ('WOinc', -20.52962279973486)]),
#   ( [('baby',), ('boomers',)],
#     [ ('correct', -20.64130036115993),
#       ('Um', -23.848628016892267),
#       ('Wci', -26.990585638033533),
#       ('WOinc', -27.51526461737407)]),
#   ( [('boomers',), (',',)],
#     [ ('correct', -14.298997966318908),
#       ('Um', -18.958995221079366),
#       ('Rloc-', -21.2263368520603),
#       ('Mec', -22.121579332080508)]),
#   ( [(',',), ('who',)],
#     [ ('correct', -10.00718648845957),
#       ('Um', -16.21522693737508),
#       ('Rloc-', -16.277576961682133),
#       ('Wci', -18.846275964725116)]),
#   ( [('who',), ('are',)],
#     [ ('correct', -11.75053737018663),
#       ('Um', -17.68635271399073),
#       ('Rloc-', -17.701107128088665),
#       ('Wci', -19.445724569375077)]),
#   ( [('are',), ('now',)],
#     [ ('correct', -12.79619417632477),
#       ('Rloc-', -17.9403368171545),
#       ('Vt', -19.104985123156474),
#       ('Um', -19.11444420378908)]),
#   ( [('now',), ('mostly',)],
#     [ ('correct', -18.024923256066092),
#       ('Rloc-', -21.543502752994407),
#       ('WOinc', -25.518710735499997),
#       ('Um', -25.577473660709753)]),
#   ( [('mostly',), ('in',)],
#     [ ('correct', -14.436012823090632),
#       ('Rloc-', -18.837857844693445),
#       ('Um', -22.097359909018948),
#       ('Wci', -22.233084608935172)]),
#   ( [('in',), ('their',)],
#     [ ('correct', -9.549275715358368),
#       ('Rloc-', -15.727522188400451),
#       ('Um', -15.803940630172466),
#       ('Wci', -16.790666898413377)]),
#   ( [('their',), ('late',)],
#     [ ('correct', -15.336372264205668),
#       ('Um', -20.599731175769207),
#       ('Wci', -20.901540762586688),
#       ('Rloc-', -23.142697298013747)]),
#   ( [('late',), ('fifties',)],
#     [ ('correct', -22.96687765564222),
#       ('Wci', -26.343958473108483),
#       ('Um', -26.89315045461569),
#       ('Rloc-', -29.297555392030166)]),
#   ( [('fifties',), ('or',)],
#     [ ('correct', -19.094504892831367),
#       ('Rloc-', -23.164157349033516),
#       ('Um', -23.806248793923405),
#       ('Wci', -24.994031756159465)]),
#   ( [('or',), ('early',)],
#     [ ('correct', -14.794132111514326),
#       ('Um', -20.761726356199983),
#       ('Rloc-', -20.766262076235144),
#       ('Wci', -21.28045968945516)]),
#   ( [('early',), ('sixties',)],
#     [ ('correct', -24.108922584846972),
#       ('Wci', -25.674908844127597),
#       ('Um', -26.246523289690636),
#       ('Rloc-', -26.899660119231793)]),
#   ( [('sixties',), ('.',)],
#     [ ('correct', -18.775644014524993),
#       ('Um', -21.806115444124398),
#       ('Rloc-', -22.19835364847707),
#       ('Wci', -23.47227884822447)])]
# [ ( [(' ',), ('one',)],
#     [ ('correct', -21.66288323759064),
#       ('Rloc-', -23.77210245289838),
#       ('Um', -24.495255181817317),
#       ('Wci', -24.513283587630752)]),
#   ( [('one',), ('cause',)],
#     [ ('correct', -14.003240283025958),
#       ('Rloc-', -20.05853038619407),
#       ('Wci', -20.118834432958316),
#       ('Um', -20.78168311511301)]),
#   ( [('cause',), ('for',)],
#     [ ('correct', -12.526439875002708),
#       ('Wci', -18.320733788391813),
#       ('Um', -18.785129233238944),
#       ('Rloc-', -18.92340817548617)]),
#   ( [('for',), ('this',)],
#     [ ('correct', -10.265688996964904),
#       ('Um', -16.582499237335814),
#       ('Rloc-', -16.748102283857598),
#       ('Wci', -16.913064567687186)]),
#   ( [('this',), ('is',)],
#     [ ('correct', -9.923593730785608),
#       ('Um', -16.343986188690504),
#       ('Rloc-', -16.377819957581163),
#       ('Wci', -17.204546518048744)]),
#   ( [('is',), ('attributed',)],
#     [ ('correct', -15.13445736207576),
#       ('Wci', -19.962142455702384),
#       ('Um', -22.26018825129794),
#       ('Rloc-', -22.266697915914044)]),
#   ( [('attributed',), ('to',)],
#     [ ('correct', -14.368406591973725),
#       ('Wci', -18.62482863220175),
#       ('Rloc-', -21.338628898980055),
#       ('Um', -21.412132815116927)]),
#   ( [('to',), ('the',)],
#     [ ('correct', -6.602367685677116),
#       ('Um', -12.825227011289389),
#       ('Rloc-', -12.939994043687951),
#       ('Wci', -13.738785215691207)]),
#   ( [('the',), ('era',)],
#     [ ('correct', -13.716501014512183),
#       ('ArtOrDet', -20.009326849501306),
#       ('Um', -20.70413992358652),
#       ('Rloc-', -20.89892053673806)]),
#   ( [('era',), ('of',)],
#     [ ('correct', -14.5176127145645),
#       ('Rloc-', -21.3351397119091),
#       ('Um', -21.515769880927195),
#       ('Wci', -21.78707857624817)]),
#   ( [('of',), ('baby',)],
#     [ ('correct', -13.361292108275743),
#       ('Um', -18.471247443203772),
#       ('Wci', -19.3891833034498),
#       ('WOinc', -20.52962279973486)]),
#   ( [('baby',), ('boomers',)],
#     [ ('correct', -20.64130036115993),
#       ('Um', -23.848628016892267),
#       ('Wci', -26.990585638033533),
#       ('WOinc', -27.51526461737407)]),
#   ( [('boomers',), (',',)],
#     [ ('correct', -14.298997966318908),
#       ('Um', -18.958995221079366),
#       ('Rloc-', -21.2263368520603),
#       ('Mec', -22.121579332080508)]),
#   ( [(',',), ('who',)],
#     [ ('correct', -10.00718648845957),
#       ('Um', -16.21522693737508),
#       ('Rloc-', -16.277576961682133),
#       ('Wci', -18.846275964725116)]),
#   ( [('who',), ('are',)],
#     [ ('correct', -11.75053737018663),
#       ('Um', -17.68635271399073),
#       ('Rloc-', -17.701107128088665),
#       ('Wci', -19.445724569375077)]),
#   ( [('are',), ('now',)],
#     [ ('correct', -12.79619417632477),
#       ('Rloc-', -17.9403368171545),
#       ('Vt', -19.104985123156474),
#       ('Um', -19.11444420378908)]),
#   ( [('now',), ('mostly',)],
#     [ ('correct', -18.024923256066092),
#       ('Rloc-', -21.543502752994407),
#       ('WOinc', -25.518710735499997),
#       ('Um', -25.577473660709753)]),
#   ( [('mostly',), ('in',)],
#     [ ('correct', -14.436012823090632),
#       ('Rloc-', -18.837857844693445),
#       ('Um', -22.097359909018948),
#       ('Wci', -22.233084608935172)]),
#   ( [('in',), ('their',)],
#     [ ('correct', -9.549275715358368),
#       ('Rloc-', -15.727522188400451),
#       ('Um', -15.803940630172466),
#       ('Wci', -16.790666898413377)]),
#   ( [('their',), ('late',)],
#     [ ('correct', -15.336372264205668),
#       ('Um', -20.599731175769207),
#       ('Wci', -20.901540762586688),
#       ('Rloc-', -23.142697298013747)]),
#   ( [('late',), ('fifties',)],
#     [ ('correct', -22.96687765564222),
#       ('Wci', -26.343958473108483),
#       ('Um', -26.89315045461569),
#       ('Rloc-', -29.297555392030166)]),
#   ( [('fifties',), ('or',)],
#     [ ('correct', -19.094504892831367),
#       ('Rloc-', -23.164157349033516),
#       ('Um', -23.806248793923405),
#       ('Wci', -24.994031756159465)]),
#   ( [('or',), ('early',)],
#     [ ('correct', -14.794132111514326),
#       ('Um', -20.761726356199983),
#       ('Rloc-', -20.766262076235144),
#       ('Wci', -21.28045968945516)]),
#   ( [('early',), ('sixties',)],
#     [ ('correct', -24.108922584846972),
#       ('Wci', -25.674908844127597),
#       ('Um', -26.246523289690636),
#       ('Rloc-', -26.899660119231793)]),
#   ( [('sixties',), ('.',)],
#     [ ('correct', -18.775644014524993),
#       ('Um', -21.806115444124398),
#       ('Rloc-', -22.19835364847707),
#       ('Wci', -23.47227884822447)])]
# [ ( [(' ',), ('one',)],
#     [ ('correct', -21.66288323759064),
#       ('Rloc-', -23.77210245289838),
#       ('Um', -24.495255181817317),
#       ('Wci', -24.513283587630752)]),
#   ( [('one',), ('cause',)],
#     [ ('correct', -14.003240283025958),
#       ('Rloc-', -20.05853038619407),
#       ('Wci', -20.118834432958316),
#       ('Um', -20.78168311511301)]),
#   ( [('cause',), ('for',)],
#     [ ('correct', -12.526439875002708),
#       ('Wci', -18.320733788391813),
#       ('Um', -18.785129233238944),
#       ('Rloc-', -18.92340817548617)]),
#   ( [('for',), ('this',)],
#     [ ('correct', -10.265688996964904),
#       ('Um', -16.582499237335814),
#       ('Rloc-', -16.748102283857598),
#       ('Wci', -16.913064567687186)]),
#   ( [('this',), ('is',)],
#     [ ('correct', -9.923593730785608),
#       ('Um', -16.343986188690504),
#       ('Rloc-', -16.377819957581163),
#       ('Wci', -17.204546518048744)]),
#   ( [('is',), ('attributed',)],
#     [ ('correct', -15.13445736207576),
#       ('Wci', -19.962142455702384),
#       ('Um', -22.26018825129794),
#       ('Rloc-', -22.266697915914044)]),
#   ( [('attributed',), ('to',)],
#     [ ('correct', -14.368406591973725),
#       ('Wci', -18.62482863220175),
#       ('Rloc-', -21.338628898980055),
#       ('Um', -21.412132815116927)]),
#   ( [('to',), ('the',)],
#     [ ('correct', -6.602367685677116),
#       ('Um', -12.825227011289389),
#       ('Rloc-', -12.939994043687951),
#       ('Wci', -13.738785215691207)]),
#   ( [('the',), ('era',)],
#     [ ('correct', -13.716501014512183),
#       ('ArtOrDet', -20.009326849501306),
#       ('Um', -20.70413992358652),
#       ('Rloc-', -20.89892053673806)]),
#   ( [('era',), ('of',)],
#     [ ('correct', -14.5176127145645),
#       ('Rloc-', -21.3351397119091),
#       ('Um', -21.515769880927195),
#       ('Wci', -21.78707857624817)]),
#   ( [('of',), ('baby',)],
#     [ ('correct', -13.361292108275743),
#       ('Um', -18.471247443203772),
#       ('Wci', -19.3891833034498),
#       ('WOinc', -20.52962279973486)]),
#   ( [('baby',), ('boomers',)],
#     [ ('correct', -20.64130036115993),
#       ('Um', -23.848628016892267),
#       ('Wci', -26.990585638033533),
#       ('WOinc', -27.51526461737407)]),
#   ( [('boomers',), (',',)],
#     [ ('correct', -14.298997966318908),
#       ('Um', -18.958995221079366),
#       ('Rloc-', -21.2263368520603),
#       ('Mec', -22.121579332080508)]),
#   ( [(',',), ('who',)],
#     [ ('correct', -10.00718648845957),
#       ('Um', -16.21522693737508),
#       ('Rloc-', -16.277576961682133),
#       ('Wci', -18.846275964725116)]),
#   ( [('who',), ('are',)],
#     [ ('correct', -11.75053737018663),
#       ('Um', -17.68635271399073),
#       ('Rloc-', -17.701107128088665),
#       ('Wci', -19.445724569375077)]),
#   ( [('are',), ('now',)],
#     [ ('correct', -12.79619417632477),
#       ('Rloc-', -17.9403368171545),
#       ('Vt', -19.104985123156474),
#       ('Um', -19.11444420378908)]),
#   ( [('now',), ('mostly',)],
#     [ ('correct', -18.024923256066092),
#       ('Rloc-', -21.543502752994407),
#       ('WOinc', -25.518710735499997),
#       ('Um', -25.577473660709753)]),
#   ( [('mostly',), ('in',)],
#     [ ('correct', -14.436012823090632),
#       ('Rloc-', -18.837857844693445),
#       ('Um', -22.097359909018948),
#       ('Wci', -22.233084608935172)]),
#   ( [('in',), ('their',)],
#     [ ('correct', -9.549275715358368),
#       ('Rloc-', -15.727522188400451),
#       ('Um', -15.803940630172466),
#       ('Wci', -16.790666898413377)]),
#   ( [('their',), ('late',)],
#     [ ('correct', -15.336372264205668),
#       ('Um', -20.599731175769207),
#       ('Wci', -20.901540762586688),
#       ('Rloc-', -23.142697298013747)]),
#   ( [('late',), ('fifties',)],
#     [ ('correct', -22.96687765564222),
#       ('Wci', -26.343958473108483),
#       ('Um', -26.89315045461569),
#       ('Rloc-', -29.297555392030166)]),
#   ( [('fifties',), ('or',)],
#     [ ('correct', -19.094504892831367),
#       ('Rloc-', -23.164157349033516),
#       ('Um', -23.806248793923405),
#       ('Wci', -24.994031756159465)]),
#   ( [('or',), ('early',)],
#     [ ('correct', -14.794132111514326),
#       ('Um', -20.761726356199983),
#       ('Rloc-', -20.766262076235144),
#       ('Wci', -21.28045968945516)]),
#   ( [('early',), ('sixties',)],
#     [ ('correct', -24.108922584846972),
#       ('Wci', -25.674908844127597),
#       ('Um', -26.246523289690636),
#       ('Rloc-', -26.899660119231793)]),
#   ( [('sixties',), ('.',)],
#     [ ('correct', -18.775644014524993),
#       ('Um', -21.806115444124398),
#       ('Rloc-', -22.19835364847707),
#       ('Wci', -23.47227884822447)])]
# [ ( [(' ',), ('one',)],
#     [ ('correct', -21.66288323759064),
#       ('Rloc-', -23.77210245289838),
#       ('Um', -24.495255181817317),
#       ('Wci', -24.513283587630752)]),
#   ( [('one',), ('cause',)],
#     [ ('correct', -14.003240283025958),
#       ('Rloc-', -20.05853038619407),
#       ('Wci', -20.118834432958316),
#       ('Um', -20.78168311511301)]),
#   ( [('cause',), ('for',)],
#     [ ('correct', -12.526439875002708),
#       ('Wci', -18.320733788391813),
#       ('Um', -18.785129233238944),
#       ('Rloc-', -18.92340817548617)]),
#   ( [('for',), ('this',)],
#     [ ('correct', -10.265688996964904),
#       ('Um', -16.582499237335814),
#       ('Rloc-', -16.748102283857598),
#       ('Wci', -16.913064567687186)]),
#   ( [('this',), ('is',)],
#     [ ('correct', -9.923593730785608),
#       ('Um', -16.343986188690504),
#       ('Rloc-', -16.377819957581163),
#       ('Wci', -17.204546518048744)]),
#   ( [('is',), ('attributed',)],
#     [ ('correct', -15.13445736207576),
#       ('Wci', -19.962142455702384),
#       ('Um', -22.26018825129794),
#       ('Rloc-', -22.266697915914044)]),
#   ( [('attributed',), ('to',)],
#     [ ('correct', -14.368406591973725),
#       ('Wci', -18.62482863220175),
#       ('Rloc-', -21.338628898980055),
#       ('Um', -21.412132815116927)]),
#   ( [('to',), ('the',)],
#     [ ('correct', -6.602367685677116),
#       ('Um', -12.825227011289389),
#       ('Rloc-', -12.939994043687951),
#       ('Wci', -13.738785215691207)]),
#   ( [('the',), ('era',)],
#     [ ('correct', -13.716501014512183),
#       ('ArtOrDet', -20.009326849501306),
#       ('Um', -20.70413992358652),
#       ('Rloc-', -20.89892053673806)]),
#   ( [('era',), ('of',)],
#     [ ('correct', -14.5176127145645),
#       ('Rloc-', -21.3351397119091),
#       ('Um', -21.515769880927195),
#       ('Wci', -21.78707857624817)]),
#   ( [('of',), ('baby',)],
#     [ ('correct', -13.361292108275743),
#       ('Um', -18.471247443203772),
#       ('Wci', -19.3891833034498),
#       ('WOinc', -20.52962279973486)]),
#   ( [('baby',), ('boomers',)],
#     [ ('correct', -20.64130036115993),
#       ('Um', -23.848628016892267),
#       ('Wci', -26.990585638033533),
#       ('WOinc', -27.51526461737407)]),
#   ( [('boomers',), (',',)],
#     [ ('correct', -14.298997966318908),
#       ('Um', -18.958995221079366),
#       ('Rloc-', -21.2263368520603),
#       ('Mec', -22.121579332080508)]),
#   ( [(',',), ('who',)],
#     [ ('correct', -10.00718648845957),
#       ('Um', -16.21522693737508),
#       ('Rloc-', -16.277576961682133),
#       ('Wci', -18.846275964725116)]),
#   ( [('who',), ('are',)],
#     [ ('correct', -11.75053737018663),
#       ('Um', -17.68635271399073),
#       ('Rloc-', -17.701107128088665),
#       ('Wci', -19.445724569375077)]),
#   ( [('are',), ('now',)],
#     [ ('correct', -12.79619417632477),
#       ('Rloc-', -17.9403368171545),
#       ('Vt', -19.104985123156474),
#       ('Um', -19.11444420378908)]),
#   ( [('now',), ('mostly',)],
#     [ ('correct', -18.024923256066092),
#       ('Rloc-', -21.543502752994407),
#       ('WOinc', -25.518710735499997),
#       ('Um', -25.577473660709753)]),
#   ( [('mostly',), ('in',)],
#     [ ('correct', -14.436012823090632),
#       ('Rloc-', -18.837857844693445),
#       ('Um', -22.097359909018948),
#       ('Wci', -22.233084608935172)]),
#   ( [('in',), ('their',)],
#     [ ('correct', -9.549275715358368),
#       ('Rloc-', -15.727522188400451),
#       ('Um', -15.803940630172466),
#       ('Wci', -16.790666898413377)]),
#   ( [('their',), ('late',)],
#     [ ('correct', -15.336372264205668),
#       ('Um', -20.599731175769207),
#       ('Wci', -20.901540762586688),
#       ('Rloc-', -23.142697298013747)]),
#   ( [('late',), ('fifties',)],
#     [ ('correct', -22.96687765564222),
#       ('Wci', -26.343958473108483),
#       ('Um', -26.89315045461569),
#       ('Rloc-', -29.297555392030166)]),
#   ( [('fifties',), ('or',)],
#     [ ('correct', -19.094504892831367),
#       ('Rloc-', -23.164157349033516),
#       ('Um', -23.806248793923405),
#       ('Wci', -24.994031756159465)]),
#   ( [('or',), ('early',)],
#     [ ('correct', -14.794132111514326),
#       ('Um', -20.761726356199983),
#       ('Rloc-', -20.766262076235144),
#       ('Wci', -21.28045968945516)]),
#   ( [('early',), ('sixties',)],
#     [ ('correct', -24.108922584846972),
#       ('Wci', -25.674908844127597),
#       ('Um', -26.246523289690636),
#       ('Rloc-', -26.899660119231793)]),
#   ( [('sixties',), ('.',)],
#     [ ('correct', -18.775644014524993),
#       ('Um', -21.806115444124398),
#       ('Rloc-', -22.19835364847707),
#       ('Wci', -23.47227884822447)])]
# [ ( [(' ',), ('one',)],
#     [ ('correct', -21.66288323759064),
#       ('Rloc-', -23.77210245289838),
#       ('Um', -24.495255181817317),
#       ('Wci', -24.513283587630752)]),
#   ( [('one',), ('cause',)],
#     [ ('correct', -14.003240283025958),
#       ('Rloc-', -20.05853038619407),
#       ('Wci', -20.118834432958316),
#       ('Um', -20.78168311511301)]),
#   ( [('cause',), ('for',)],
#     [ ('correct', -12.526439875002708),
#       ('Wci', -18.320733788391813),
#       ('Um', -18.785129233238944),
#       ('Rloc-', -18.92340817548617)]),
#   ( [('for',), ('this',)],
#     [ ('correct', -10.265688996964904),
#       ('Um', -16.582499237335814),
#       ('Rloc-', -16.748102283857598),
#       ('Wci', -16.913064567687186)]),
#   ( [('this',), ('is',)],
#     [ ('correct', -9.923593730785608),
#       ('Um', -16.343986188690504),
#       ('Rloc-', -16.377819957581163),
#       ('Wci', -17.204546518048744)]),
#   ( [('is',), ('attributed',)],
#     [ ('correct', -15.13445736207576),
#       ('Wci', -19.962142455702384),
#       ('Um', -22.26018825129794),
#       ('Rloc-', -22.266697915914044)]),
#   ( [('attributed',), ('to',)],
#     [ ('correct', -14.368406591973725),
#       ('Wci', -18.62482863220175),
#       ('Rloc-', -21.338628898980055),
#       ('Um', -21.412132815116927)]),
#   ( [('to',), ('the',)],
#     [ ('correct', -6.602367685677116),
#       ('Um', -12.825227011289389),
#       ('Rloc-', -12.939994043687951),
#       ('Wci', -13.738785215691207)]),
#   ( [('the',), ('era',)],
#     [ ('correct', -13.716501014512183),
#       ('ArtOrDet', -20.009326849501306),
#       ('Um', -20.70413992358652),
#       ('Rloc-', -20.89892053673806)]),
#   ( [('era',), ('of',)],
#     [ ('correct', -14.5176127145645),
#       ('Rloc-', -21.3351397119091),
#       ('Um', -21.515769880927195),
#       ('Wci', -21.78707857624817)]),
#   ( [('of',), ('baby',)],
#     [ ('correct', -13.361292108275743),
#       ('Um', -18.471247443203772),
#       ('Wci', -19.3891833034498),
#       ('WOinc', -20.52962279973486)]),
#   ( [('baby',), ('boomers',)],
#     [ ('correct', -20.64130036115993),
#       ('Um', -23.848628016892267),
#       ('Wci', -26.990585638033533),
#       ('WOinc', -27.51526461737407)]),
#   ( [('boomers',), (',',)],
#     [ ('correct', -14.298997966318908),
#       ('Um', -18.958995221079366),
#       ('Rloc-', -21.2263368520603),
#       ('Mec', -22.121579332080508)]),
#   ( [(',',), ('who',)],
#     [ ('correct', -10.00718648845957),
#       ('Um', -16.21522693737508),
#       ('Rloc-', -16.277576961682133),
#       ('Wci', -18.846275964725116)]),
#   ( [('who',), ('are',)],
#     [ ('correct', -11.75053737018663),
#       ('Um', -17.68635271399073),
#       ('Rloc-', -17.701107128088665),
#       ('Wci', -19.445724569375077)]),
#   ( [('are',), ('now',)],
#     [ ('correct', -12.79619417632477),
#       ('Rloc-', -17.9403368171545),
#       ('Vt', -19.104985123156474),
#       ('Um', -19.11444420378908)]),
#   ( [('now',), ('mostly',)],
#     [ ('correct', -18.024923256066092),
#       ('Rloc-', -21.543502752994407),
#       ('WOinc', -25.518710735499997),
#       ('Um', -25.577473660709753)]),
#   ( [('mostly',), ('in',)],
#     [ ('correct', -14.436012823090632),
#       ('Rloc-', -18.837857844693445),
#       ('Um', -22.097359909018948),
#       ('Wci', -22.233084608935172)]),
#   ( [('in',), ('their',)],
#     [ ('correct', -9.549275715358368),
#       ('Rloc-', -15.727522188400451),
#       ('Um', -15.803940630172466),
#       ('Wci', -16.790666898413377)]),
#   ( [('their',), ('late',)],
#     [ ('correct', -15.336372264205668),
#       ('Um', -20.599731175769207),
#       ('Wci', -20.901540762586688),
#       ('Rloc-', -23.142697298013747)]),
#   ( [('late',), ('fifties',)],
#     [ ('correct', -22.96687765564222),
#       ('Wci', -26.343958473108483),
#       ('Um', -26.89315045461569),
#       ('Rloc-', -29.297555392030166)]),
#   ( [('fifties',), ('or',)],
#     [ ('correct', -19.094504892831367),
#       ('Rloc-', -23.164157349033516),
#       ('Um', -23.806248793923405),
#       ('Wci', -24.994031756159465)]),
#   ( [('or',), ('early',)],
#     [ ('correct', -14.794132111514326),
#       ('Um', -20.761726356199983),
#       ('Rloc-', -20.766262076235144),
#       ('Wci', -21.28045968945516)]),
#   ( [('early',), ('sixties',)],
#     [ ('correct', -24.108922584846972),
#       ('Wci', -25.674908844127597),
#       ('Um', -26.246523289690636),
#       ('Rloc-', -26.899660119231793)]),
#   ( [('sixties',), ('.',)],
#     [ ('correct', -18.775644014524993),
#       ('Um', -21.806115444124398),
#       ('Rloc-', -22.19835364847707),
#       ('Wci', -23.47227884822447)])]
# [ ( [(' ',), ('one',)],
#     [ ('correct', -21.66288323759064),
#       ('Rloc-', -23.77210245289838),
#       ('Um', -24.495255181817317),
#       ('Wci', -24.513283587630752)]),
#   ( [('one',), ('cause',)],
#     [ ('correct', -14.003240283025958),
#       ('Rloc-', -20.05853038619407),
#       ('Wci', -20.118834432958316),
#       ('Um', -20.78168311511301)]),
#   ( [('cause',), ('for',)],
#     [ ('correct', -12.526439875002708),
#       ('Wci', -18.320733788391813),
#       ('Um', -18.785129233238944),
#       ('Rloc-', -18.92340817548617)]),
#   ( [('for',), ('this',)],
#     [ ('correct', -10.265688996964904),
#       ('Um', -16.582499237335814),
#       ('Rloc-', -16.748102283857598),
#       ('Wci', -16.913064567687186)]),
#   ( [('this',), ('is',)],
#     [ ('correct', -9.923593730785608),
#       ('Um', -16.343986188690504),
#       ('Rloc-', -16.377819957581163),
#       ('Wci', -17.204546518048744)]),
#   ( [('is',), ('attributed',)],
#     [ ('correct', -15.13445736207576),
#       ('Wci', -19.962142455702384),
#       ('Um', -22.26018825129794),
#       ('Rloc-', -22.266697915914044)]),
#   ( [('attributed',), ('to',)],
#     [ ('correct', -14.368406591973725),
#       ('Wci', -18.62482863220175),
#       ('Rloc-', -21.338628898980055),
#       ('Um', -21.412132815116927)]),
#   ( [('to',), ('the',)],
#     [ ('correct', -6.602367685677116),
#       ('Um', -12.825227011289389),
#       ('Rloc-', -12.939994043687951),
#       ('Wci', -13.738785215691207)]),
#   ( [('the',), ('era',)],
#     [ ('correct', -13.716501014512183),
#       ('ArtOrDet', -20.009326849501306),
#       ('Um', -20.70413992358652),
#       ('Rloc-', -20.89892053673806)]),
#   ( [('era',), ('of',)],
#     [ ('correct', -14.5176127145645),
#       ('Rloc-', -21.3351397119091),
#       ('Um', -21.515769880927195),
#       ('Wci', -21.78707857624817)]),
#   ( [('of',), ('baby',)],
#     [ ('correct', -13.361292108275743),
#       ('Um', -18.471247443203772),
#       ('Wci', -19.3891833034498),
#       ('WOinc', -20.52962279973486)]),
#   ( [('baby',), ('boomers',)],
#     [ ('correct', -20.64130036115993),
#       ('Um', -23.848628016892267),
#       ('Wci', -26.990585638033533),
#       ('WOinc', -27.51526461737407)]),
#   ( [('boomers',), (',',)],
#     [ ('correct', -14.298997966318908),
#       ('Um', -18.958995221079366),
#       ('Rloc-', -21.2263368520603),
#       ('Mec', -22.121579332080508)]),
#   ( [(',',), ('who',)],
#     [ ('correct', -10.00718648845957),
#       ('Um', -16.21522693737508),
#       ('Rloc-', -16.277576961682133),
#       ('Wci', -18.846275964725116)]),
#   ( [('who',), ('are',)],
#     [ ('correct', -11.75053737018663),
#       ('Um', -17.68635271399073),
#       ('Rloc-', -17.701107128088665),
#       ('Wci', -19.445724569375077)]),
#   ( [('are',), ('now',)],
#     [ ('correct', -12.79619417632477),
#       ('Rloc-', -17.9403368171545),
#       ('Vt', -19.104985123156474),
#       ('Um', -19.11444420378908)]),
#   ( [('now',), ('mostly',)],
#     [ ('correct', -18.024923256066092),
#       ('Rloc-', -21.543502752994407),
#       ('WOinc', -25.518710735499997),
#       ('Um', -25.577473660709753)]),
#   ( [('mostly',), ('in',)],
#     [ ('correct', -14.436012823090632),
#       ('Rloc-', -18.837857844693445),
#       ('Um', -22.097359909018948),
#       ('Wci', -22.233084608935172)]),
#   ( [('in',), ('their',)],
#     [ ('correct', -9.549275715358368),
#       ('Rloc-', -15.727522188400451),
#       ('Um', -15.803940630172466),
#       ('Wci', -16.790666898413377)]),
#   ( [('their',), ('late',)],
#     [ ('correct', -15.336372264205668),
#       ('Um', -20.599731175769207),
#       ('Wci', -20.901540762586688),
#       ('Rloc-', -23.142697298013747)]),
#   ( [('late',), ('fifties',)],
#     [ ('correct', -22.96687765564222),
#       ('Wci', -26.343958473108483),
#       ('Um', -26.89315045461569),
#       ('Rloc-', -29.297555392030166)]),
#   ( [('fifties',), ('or',)],
#     [ ('correct', -19.094504892831367),
#       ('Rloc-', -23.164157349033516),
#       ('Um', -23.806248793923405),
#       ('Wci', -24.994031756159465)]),
#   ( [('or',), ('early',)],
#     [ ('correct', -14.794132111514326),
#       ('Um', -20.761726356199983),
#       ('Rloc-', -20.766262076235144),
#       ('Wci', -21.28045968945516)]),
#   ( [('early',), ('sixties',)],
#     [ ('correct', -24.108922584846972),
#       ('Wci', -25.674908844127597),
#       ('Um', -26.246523289690636),
#       ('Rloc-', -26.899660119231793)]),
#   ( [('sixties',), ('.',)],
#     [ ('correct', -18.775644014524993),
#       ('Um', -21.806115444124398),
#       ('Rloc-', -22.19835364847707),
#       ('Wci', -23.47227884822447)])]
# [ ( [(' ',), ('one',)],
#     [ ('correct', -21.66288323759064),
#       ('Rloc-', -23.77210245289838),
#       ('Um', -24.495255181817317),
#       ('Wci', -24.513283587630752)]),
#   ( [('one',), ('cause',)],
#     [ ('correct', -14.003240283025958),
#       ('Rloc-', -20.05853038619407),
#       ('Wci', -20.118834432958316),
#       ('Um', -20.78168311511301)]),
#   ( [('cause',), ('for',)],
#     [ ('correct', -12.526439875002708),
#       ('Wci', -18.320733788391813),
#       ('Um', -18.785129233238944),
#       ('Rloc-', -18.92340817548617)]),
#   ( [('for',), ('this',)],
#     [ ('correct', -10.265688996964904),
#       ('Um', -16.582499237335814),
#       ('Rloc-', -16.748102283857598),
#       ('Wci', -16.913064567687186)]),
#   ( [('this',), ('is',)],
#     [ ('correct', -9.923593730785608),
#       ('Um', -16.343986188690504),
#       ('Rloc-', -16.377819957581163),
#       ('Wci', -17.204546518048744)]),
#   ( [('is',), ('attributed',)],
#     [ ('correct', -15.13445736207576),
#       ('Wci', -19.962142455702384),
#       ('Um', -22.26018825129794),
#       ('Rloc-', -22.266697915914044)]),
#   ( [('attributed',), ('to',)],
#     [ ('correct', -14.368406591973725),
#       ('Wci', -18.62482863220175),
#       ('Rloc-', -21.338628898980055),
#       ('Um', -21.412132815116927)]),
#   ( [('to',), ('the',)],
#     [ ('correct', -6.602367685677116),
#       ('Um', -12.825227011289389),
#       ('Rloc-', -12.939994043687951),
#       ('Wci', -13.738785215691207)]),
#   ( [('the',), ('era',)],
#     [ ('correct', -13.716501014512183),
#       ('ArtOrDet', -20.009326849501306),
#       ('Um', -20.70413992358652),
#       ('Rloc-', -20.89892053673806)]),
#   ( [('era',), ('of',)],
#     [ ('correct', -14.5176127145645),
#       ('Rloc-', -21.3351397119091),
#       ('Um', -21.515769880927195),
#       ('Wci', -21.78707857624817)]),
#   ( [('of',), ('baby',)],
#     [ ('correct', -13.361292108275743),
#       ('Um', -18.471247443203772),
#       ('Wci', -19.3891833034498),
#       ('WOinc', -20.52962279973486)]),
#   ( [('baby',), ('boomers',)],
#     [ ('correct', -20.64130036115993),
#       ('Um', -23.848628016892267),
#       ('Wci', -26.990585638033533),
#       ('WOinc', -27.51526461737407)]),
#   ( [('boomers',), (',',)],
#     [ ('correct', -14.298997966318908),
#       ('Um', -18.958995221079366),
#       ('Rloc-', -21.2263368520603),
#       ('Mec', -22.121579332080508)]),
#   ( [(',',), ('who',)],
#     [ ('correct', -10.00718648845957),
#       ('Um', -16.21522693737508),
#       ('Rloc-', -16.277576961682133),
#       ('Wci', -18.846275964725116)]),
#   ( [('who',), ('are',)],
#     [ ('correct', -11.75053737018663),
#       ('Um', -17.68635271399073),
#       ('Rloc-', -17.701107128088665),
#       ('Wci', -19.445724569375077)]),
#   ( [('are',), ('now',)],
#     [ ('correct', -12.79619417632477),
#       ('Rloc-', -17.9403368171545),
#       ('Vt', -19.104985123156474),
#       ('Um', -19.11444420378908)]),
#   ( [('now',), ('mostly',)],
#     [ ('correct', -18.024923256066092),
#       ('Rloc-', -21.543502752994407),
#       ('WOinc', -25.518710735499997),
#       ('Um', -25.577473660709753)]),
#   ( [('mostly',), ('in',)],
#     [ ('correct', -14.436012823090632),
#       ('Rloc-', -18.837857844693445),
#       ('Um', -22.097359909018948),
#       ('Wci', -22.233084608935172)]),
#   ( [('in',), ('their',)],
#     [ ('correct', -9.549275715358368),
#       ('Rloc-', -15.727522188400451),
#       ('Um', -15.803940630172466),
#       ('Wci', -16.790666898413377)]),
#   ( [('their',), ('late',)],
#     [ ('correct', -15.336372264205668),
#       ('Um', -20.599731175769207),
#       ('Wci', -20.901540762586688),
#       ('Rloc-', -23.142697298013747)]),
#   ( [('late',), ('fifties',)],
#     [ ('correct', -22.96687765564222),
#       ('Wci', -26.343958473108483),
#       ('Um', -26.89315045461569),
#       ('Rloc-', -29.297555392030166)]),
#   ( [('fifties',), ('or',)],
#     [ ('correct', -19.094504892831367),
#       ('Rloc-', -23.164157349033516),
#       ('Um', -23.806248793923405),
#       ('Wci', -24.994031756159465)]),
#   ( [('or',), ('early',)],
#     [ ('correct', -14.794132111514326),
#       ('Um', -20.761726356199983),
#       ('Rloc-', -20.766262076235144),
#       ('Wci', -21.28045968945516)]),
#   ( [('early',), ('sixties',)],
#     [ ('correct', -24.108922584846972),
#       ('Wci', -25.674908844127597),
#       ('Um', -26.246523289690636),
#       ('Rloc-', -26.899660119231793)]),
#   ( [('sixties',), ('.',)],
#     [ ('correct', -18.775644014524993),
#       ('Um', -21.806115444124398),
#       ('Rloc-', -22.19835364847707),
#       ('Wci', -23.47227884822447)])]
# [ ( [(' ',), ('one',)],
#     [ ('correct', -21.66288323759064),
#       ('Rloc-', -23.77210245289838),
#       ('Um', -24.495255181817317),
#       ('Wci', -24.513283587630752)]),
#   ( [('one',), ('cause',)],
#     [ ('correct', -14.003240283025958),
#       ('Rloc-', -20.05853038619407),
#       ('Wci', -20.118834432958316),
#       ('Um', -20.78168311511301)]),
#   ( [('cause',), ('for',)],
#     [ ('correct', -12.526439875002708),
#       ('Wci', -18.320733788391813),
#       ('Um', -18.785129233238944),
#       ('Rloc-', -18.92340817548617)]),
#   ( [('for',), ('this',)],
#     [ ('correct', -10.265688996964904),
#       ('Um', -16.582499237335814),
#       ('Rloc-', -16.748102283857598),
#       ('Wci', -16.913064567687186)]),
#   ( [('this',), ('is',)],
#     [ ('correct', -9.923593730785608),
#       ('Um', -16.343986188690504),
#       ('Rloc-', -16.377819957581163),
#       ('Wci', -17.204546518048744)]),
#   ( [('is',), ('attributed',)],
#     [ ('correct', -15.13445736207576),
#       ('Wci', -19.962142455702384),
#       ('Um', -22.26018825129794),
#       ('Rloc-', -22.266697915914044)]),
#   ( [('attributed',), ('to',)],
#     [ ('correct', -14.368406591973725),
#       ('Wci', -18.62482863220175),
#       ('Rloc-', -21.338628898980055),
#       ('Um', -21.412132815116927)]),
#   ( [('to',), ('the',)],
#     [ ('correct', -6.602367685677116),
#       ('Um', -12.825227011289389),
#       ('Rloc-', -12.939994043687951),
#       ('Wci', -13.738785215691207)]),
#   ( [('the',), ('era',)],
#     [ ('correct', -13.716501014512183),
#       ('ArtOrDet', -20.009326849501306),
#       ('Um', -20.70413992358652),
#       ('Rloc-', -20.89892053673806)]),
#   ( [('era',), ('of',)],
#     [ ('correct', -14.5176127145645),
#       ('Rloc-', -21.3351397119091),
#       ('Um', -21.515769880927195),
#       ('Wci', -21.78707857624817)]),
#   ( [('of',), ('baby',)],
#     [ ('correct', -13.361292108275743),
#       ('Um', -18.471247443203772),
#       ('Wci', -19.3891833034498),
#       ('WOinc', -20.52962279973486)]),
#   ( [('baby',), ('boomers',)],
#     [ ('correct', -20.64130036115993),
#       ('Um', -23.848628016892267),
#       ('Wci', -26.990585638033533),
#       ('WOinc', -27.51526461737407)]),
#   ( [('boomers',), (',',)],
#     [ ('correct', -14.298997966318908),
#       ('Um', -18.958995221079366),
#       ('Rloc-', -21.2263368520603),
#       ('Mec', -22.121579332080508)]),
#   ( [(',',), ('who',)],
#     [ ('correct', -10.00718648845957),
#       ('Um', -16.21522693737508),
#       ('Rloc-', -16.277576961682133),
#       ('Wci', -18.846275964725116)]),
#   ( [('who',), ('are',)],
#     [ ('correct', -11.75053737018663),
#       ('Um', -17.68635271399073),
#       ('Rloc-', -17.701107128088665),
#       ('Wci', -19.445724569375077)]),
#   ( [('are',), ('now',)],
#     [ ('correct', -12.79619417632477),
#       ('Rloc-', -17.9403368171545),
#       ('Vt', -19.104985123156474),
#       ('Um', -19.11444420378908)]),
#   ( [('now',), ('mostly',)],
#     [ ('correct', -18.024923256066092),
#       ('Rloc-', -21.543502752994407),
#       ('WOinc', -25.518710735499997),
#       ('Um', -25.577473660709753)]),
#   ( [('mostly',), ('in',)],
#     [ ('correct', -14.436012823090632),
#       ('Rloc-', -18.837857844693445),
#       ('Um', -22.097359909018948),
#       ('Wci', -22.233084608935172)]),
#   ( [('in',), ('their',)],
#     [ ('correct', -9.549275715358368),
#       ('Rloc-', -15.727522188400451),
#       ('Um', -15.803940630172466),
#       ('Wci', -16.790666898413377)]),
#   ( [('their',), ('late',)],
#     [ ('correct', -15.336372264205668),
#       ('Um', -20.599731175769207),
#       ('Wci', -20.901540762586688),
#       ('Rloc-', -23.142697298013747)]),
#   ( [('late',), ('fifties',)],
#     [ ('correct', -22.96687765564222),
#       ('Wci', -26.343958473108483),
#       ('Um', -26.89315045461569),
#       ('Rloc-', -29.297555392030166)]),
#   ( [('fifties',), ('or',)],
#     [ ('correct', -19.094504892831367),
#       ('Rloc-', -23.164157349033516),
#       ('Um', -23.806248793923405),
#       ('Wci', -24.994031756159465)]),
#   ( [('or',), ('early',)],
#     [ ('correct', -14.794132111514326),
#       ('Um', -20.761726356199983),
#       ('Rloc-', -20.766262076235144),
#       ('Wci', -21.28045968945516)]),
#   ( [('early',), ('sixties',)],
#     [ ('correct', -24.108922584846972),
#       ('Wci', -25.674908844127597),
#       ('Um', -26.246523289690636),
#       ('Rloc-', -26.899660119231793)]),
#   ( [('sixties',), ('.',)],
#     [ ('correct', -18.775644014524993),
#       ('Um', -21.806115444124398),
#       ('Rloc-', -22.19835364847707),
#       ('Wci', -23.47227884822447)])]
# [ ( [(' ',), ('one',)],
#     [ ('correct', -21.66288323759064),
#       ('Rloc-', -23.77210245289838),
#       ('Um', -24.495255181817317),
#       ('Wci', -24.513283587630752)]),
#   ( [('one',), ('cause',)],
#     [ ('correct', -14.003240283025958),
#       ('Rloc-', -20.05853038619407),
#       ('Wci', -20.118834432958316),
#       ('Um', -20.78168311511301)]),
#   ( [('cause',), ('for',)],
#     [ ('correct', -12.526439875002708),
#       ('Wci', -18.320733788391813),
#       ('Um', -18.785129233238944),
#       ('Rloc-', -18.92340817548617)]),
#   ( [('for',), ('this',)],
#     [ ('correct', -10.265688996964904),
#       ('Um', -16.582499237335814),
#       ('Rloc-', -16.748102283857598),
#       ('Wci', -16.913064567687186)]),
#   ( [('this',), ('is',)],
#     [ ('correct', -9.923593730785608),
#       ('Um', -16.343986188690504),
#       ('Rloc-', -16.377819957581163),
#       ('Wci', -17.204546518048744)]),
#   ( [('is',), ('attributed',)],
#     [ ('correct', -15.13445736207576),
#       ('Wci', -19.962142455702384),
#       ('Um', -22.26018825129794),
#       ('Rloc-', -22.266697915914044)]),
#   ( [('attributed',), ('to',)],
#     [ ('correct', -14.368406591973725),
#       ('Wci', -18.62482863220175),
#       ('Rloc-', -21.338628898980055),
#       ('Um', -21.412132815116927)]),
#   ( [('to',), ('the',)],
#     [ ('correct', -6.602367685677116),
#       ('Um', -12.825227011289389),
#       ('Rloc-', -12.939994043687951),
#       ('Wci', -13.738785215691207)]),
#   ( [('the',), ('era',)],
#     [ ('correct', -13.716501014512183),
#       ('ArtOrDet', -20.009326849501306),
#       ('Um', -20.70413992358652),
#       ('Rloc-', -20.89892053673806)]),
#   ( [('era',), ('of',)],
#     [ ('correct', -14.5176127145645),
#       ('Rloc-', -21.3351397119091),
#       ('Um', -21.515769880927195),
#       ('Wci', -21.78707857624817)]),
#   ( [('of',), ('baby',)],
#     [ ('correct', -13.361292108275743),
#       ('Um', -18.471247443203772),
#       ('Wci', -19.3891833034498),
#       ('WOinc', -20.52962279973486)]),
#   ( [('baby',), ('boomers',)],
#     [ ('correct', -20.64130036115993),
#       ('Um', -23.848628016892267),
#       ('Wci', -26.990585638033533),
#       ('WOinc', -27.51526461737407)]),
#   ( [('boomers',), (',',)],
#     [ ('correct', -14.298997966318908),
#       ('Um', -18.958995221079366),
#       ('Rloc-', -21.2263368520603),
#       ('Mec', -22.121579332080508)]),
#   ( [(',',), ('who',)],
#     [ ('correct', -10.00718648845957),
#       ('Um', -16.21522693737508),
#       ('Rloc-', -16.277576961682133),
#       ('Wci', -18.846275964725116)]),
#   ( [('who',), ('are',)],
#     [ ('correct', -11.75053737018663),
#       ('Um', -17.68635271399073),
#       ('Rloc-', -17.701107128088665),
#       ('Wci', -19.445724569375077)]),
#   ( [('are',), ('now',)],
#     [ ('correct', -12.79619417632477),
#       ('Rloc-', -17.9403368171545),
#       ('Vt', -19.104985123156474),
#       ('Um', -19.11444420378908)]),
#   ( [('now',), ('mostly',)],
#     [ ('correct', -18.024923256066092),
#       ('Rloc-', -21.543502752994407),
#       ('WOinc', -25.518710735499997),
#       ('Um', -25.577473660709753)]),
#   ( [('mostly',), ('in',)],
#     [ ('correct', -14.436012823090632),
#       ('Rloc-', -18.837857844693445),
#       ('Um', -22.097359909018948),
#       ('Wci', -22.233084608935172)]),
#   ( [('in',), ('their',)],
#     [ ('correct', -9.549275715358368),
#       ('Rloc-', -15.727522188400451),
#       ('Um', -15.803940630172466),
#       ('Wci', -16.790666898413377)]),
#   ( [('their',), ('late',)],
#     [ ('correct', -15.336372264205668),
#       ('Um', -20.599731175769207),
#       ('Wci', -20.901540762586688),
#       ('Rloc-', -23.142697298013747)]),
#   ( [('late',), ('fifties',)],
#     [ ('correct', -22.96687765564222),
#       ('Wci', -26.343958473108483),
#       ('Um', -26.89315045461569),
#       ('Rloc-', -29.297555392030166)]),
#   ( [('fifties',), ('or',)],
#     [ ('correct', -19.094504892831367),
#       ('Rloc-', -23.164157349033516),
#       ('Um', -23.806248793923405),
#       ('Wci', -24.994031756159465)]),
#   ( [('or',), ('early',)],
#     [ ('correct', -14.794132111514326),
#       ('Um', -20.761726356199983),
#       ('Rloc-', -20.766262076235144),
#       ('Wci', -21.28045968945516)]),
#   ( [('early',), ('sixties',)],
#     [ ('correct', -24.108922584846972),
#       ('Wci', -25.674908844127597),
#       ('Um', -26.246523289690636),
#       ('Rloc-', -26.899660119231793)]),
#   ( [('sixties',), ('.',)],
#     [ ('correct', -18.775644014524993),
#       ('Um', -21.806115444124398),
#       ('Rloc-', -22.19835364847707),
#       ('Wci', -23.47227884822447)])]
# [ ( [(' ',), ('one',)],
#     [ ('correct', -21.66288323759064),
#       ('Rloc-', -23.77210245289838),
#       ('Um', -24.495255181817317),
#       ('Wci', -24.513283587630752)]),
#   ( [('one',), ('cause',)],
#     [ ('correct', -14.003240283025958),
#       ('Rloc-', -20.05853038619407),
#       ('Wci', -20.118834432958316),
#       ('Um', -20.78168311511301)]),
#   ( [('cause',), ('for',)],
#     [ ('correct', -12.526439875002708),
#       ('Wci', -18.320733788391813),
#       ('Um', -18.785129233238944),
#       ('Rloc-', -18.92340817548617)]),
#   ( [('for',), ('this',)],
#     [ ('correct', -10.265688996964904),
#       ('Um', -16.582499237335814),
#       ('Rloc-', -16.748102283857598),
#       ('Wci', -16.913064567687186)]),
#   ( [('this',), ('is',)],
#     [ ('correct', -9.923593730785608),
#       ('Um', -16.343986188690504),
#       ('Rloc-', -16.377819957581163),
#       ('Wci', -17.204546518048744)]),
#   ( [('is',), ('attributed',)],
#     [ ('correct', -15.13445736207576),
#       ('Wci', -19.962142455702384),
#       ('Um', -22.26018825129794),
#       ('Rloc-', -22.266697915914044)]),
#   ( [('attributed',), ('to',)],
#     [ ('correct', -14.368406591973725),
#       ('Wci', -18.62482863220175),
#       ('Rloc-', -21.338628898980055),
#       ('Um', -21.412132815116927)]),
#   ( [('to',), ('the',)],
#     [ ('correct', -6.602367685677116),
#       ('Um', -12.825227011289389),
#       ('Rloc-', -12.939994043687951),
#       ('Wci', -13.738785215691207)]),
#   ( [('the',), ('era',)],
#     [ ('correct', -13.716501014512183),
#       ('ArtOrDet', -20.009326849501306),
#       ('Um', -20.70413992358652),
#       ('Rloc-', -20.89892053673806)]),
#   ( [('era',), ('of',)],
#     [ ('correct', -14.5176127145645),
#       ('Rloc-', -21.3351397119091),
#       ('Um', -21.515769880927195),
#       ('Wci', -21.78707857624817)]),
#   ( [('of',), ('baby',)],
#     [ ('correct', -13.361292108275743),
#       ('Um', -18.471247443203772),
#       ('Wci', -19.3891833034498),
#       ('WOinc', -20.52962279973486)]),
#   ( [('baby',), ('boomers',)],
#     [ ('correct', -20.64130036115993),
#       ('Um', -23.848628016892267),
#       ('Wci', -26.990585638033533),
#       ('WOinc', -27.51526461737407)]),
#   ( [('boomers',), (',',)],
#     [ ('correct', -14.298997966318908),
#       ('Um', -18.958995221079366),
#       ('Rloc-', -21.2263368520603),
#       ('Mec', -22.121579332080508)]),
#   ( [(',',), ('who',)],
#     [ ('correct', -10.00718648845957),
#       ('Um', -16.21522693737508),
#       ('Rloc-', -16.277576961682133),
#       ('Wci', -18.846275964725116)]),
#   ( [('who',), ('are',)],
#     [ ('correct', -11.75053737018663),
#       ('Um', -17.68635271399073),
#       ('Rloc-', -17.701107128088665),
#       ('Wci', -19.445724569375077)]),
#   ( [('are',), ('now',)],
#     [ ('correct', -12.79619417632477),
#       ('Rloc-', -17.9403368171545),
#       ('Vt', -19.104985123156474),
#       ('Um', -19.11444420378908)]),
#   ( [('now',), ('mostly',)],
#     [ ('correct', -18.024923256066092),
#       ('Rloc-', -21.543502752994407),
#       ('WOinc', -25.518710735499997),
#       ('Um', -25.577473660709753)]),
#   ( [('mostly',), ('in',)],
#     [ ('correct', -14.436012823090632),
#       ('Rloc-', -18.837857844693445),
#       ('Um', -22.097359909018948),
#       ('Wci', -22.233084608935172)]),
#   ( [('in',), ('their',)],
#     [ ('correct', -9.549275715358368),
#       ('Rloc-', -15.727522188400451),
#       ('Um', -15.803940630172466),
#       ('Wci', -16.790666898413377)]),
#   ( [('their',), ('late',)],
#     [ ('correct', -15.336372264205668),
#       ('Um', -20.599731175769207),
#       ('Wci', -20.901540762586688),
#       ('Rloc-', -23.142697298013747)]),
#   ( [('late',), ('fifties',)],
#     [ ('correct', -22.96687765564222),
#       ('Wci', -26.343958473108483),
#       ('Um', -26.89315045461569),
#       ('Rloc-', -29.297555392030166)]),
#   ( [('fifties',), ('or',)],
#     [ ('correct', -19.094504892831367),
#       ('Rloc-', -23.164157349033516),
#       ('Um', -23.806248793923405),
#       ('Wci', -24.994031756159465)]),
#   ( [('or',), ('early',)],
#     [ ('correct', -14.794132111514326),
#       ('Um', -20.761726356199983),
#       ('Rloc-', -20.766262076235144),
#       ('Wci', -21.28045968945516)]),
#   ( [('early',), ('sixties',)],
#     [ ('correct', -24.108922584846972),
#       ('Wci', -25.674908844127597),
#       ('Um', -26.246523289690636),
#       ('Rloc-', -26.899660119231793)]),
#   ( [('sixties',), ('.',)],
#     [ ('correct', -18.775644014524993),
#       ('Um', -21.806115444124398),
#       ('Rloc-', -22.19835364847707),
#       ('Wci', -23.47227884822447)])]
# [ ( [(' ',), ('one',)],
#     [ ('correct', -21.66288323759064),
#       ('Rloc-', -23.77210245289838),
#       ('Um', -24.495255181817317),
#       ('Wci', -24.513283587630752)]),
#   ( [('one',), ('cause',)],
#     [ ('correct', -14.003240283025958),
#       ('Rloc-', -20.05853038619407),
#       ('Wci', -20.118834432958316),
#       ('Um', -20.78168311511301)]),
#   ( [('cause',), ('for',)],
#     [ ('correct', -12.526439875002708),
#       ('Wci', -18.320733788391813),
#       ('Um', -18.785129233238944),
#       ('Rloc-', -18.92340817548617)]),
#   ( [('for',), ('this',)],
#     [ ('correct', -10.265688996964904),
#       ('Um', -16.582499237335814),
#       ('Rloc-', -16.748102283857598),
#       ('Wci', -16.913064567687186)]),
#   ( [('this',), ('is',)],
#     [ ('correct', -9.923593730785608),
#       ('Um', -16.343986188690504),
#       ('Rloc-', -16.377819957581163),
#       ('Wci', -17.204546518048744)]),
#   ( [('is',), ('attributed',)],
#     [ ('correct', -15.13445736207576),
#       ('Wci', -19.962142455702384),
#       ('Um', -22.26018825129794),
#       ('Rloc-', -22.266697915914044)]),
#   ( [('attributed',), ('to',)],
#     [ ('correct', -14.368406591973725),
#       ('Wci', -18.62482863220175),
#       ('Rloc-', -21.338628898980055),
#       ('Um', -21.412132815116927)]),
#   ( [('to',), ('the',)],
#     [ ('correct', -6.602367685677116),
#       ('Um', -12.825227011289389),
#       ('Rloc-', -12.939994043687951),
#       ('Wci', -13.738785215691207)]),
#   ( [('the',), ('era',)],
#     [ ('correct', -13.716501014512183),
#       ('ArtOrDet', -20.009326849501306),
#       ('Um', -20.70413992358652),
#       ('Rloc-', -20.89892053673806)]),
#   ( [('era',), ('of',)],
#     [ ('correct', -14.5176127145645),
#       ('Rloc-', -21.3351397119091),
#       ('Um', -21.515769880927195),
#       ('Wci', -21.78707857624817)]),
#   ( [('of',), ('baby',)],
#     [ ('correct', -13.361292108275743),
#       ('Um', -18.471247443203772),
#       ('Wci', -19.3891833034498),
#       ('WOinc', -20.52962279973486)]),
#   ( [('baby',), ('boomers',)],
#     [ ('correct', -20.64130036115993),
#       ('Um', -23.848628016892267),
#       ('Wci', -26.990585638033533),
#       ('WOinc', -27.51526461737407)]),
#   ( [('boomers',), (',',)],
#     [ ('correct', -14.298997966318908),
#       ('Um', -18.958995221079366),
#       ('Rloc-', -21.2263368520603),
#       ('Mec', -22.121579332080508)]),
#   ( [(',',), ('who',)],
#     [ ('correct', -10.00718648845957),
#       ('Um', -16.21522693737508),
#       ('Rloc-', -16.277576961682133),
#       ('Wci', -18.846275964725116)]),
#   ( [('who',), ('are',)],
#     [ ('correct', -11.75053737018663),
#       ('Um', -17.68635271399073),
#       ('Rloc-', -17.701107128088665),
#       ('Wci', -19.445724569375077)]),
#   ( [('are',), ('now',)],
#     [ ('correct', -12.79619417632477),
#       ('Rloc-', -17.9403368171545),
#       ('Vt', -19.104985123156474),
#       ('Um', -19.11444420378908)]),
#   ( [('now',), ('mostly',)],
#     [ ('correct', -18.024923256066092),
#       ('Rloc-', -21.543502752994407),
#       ('WOinc', -25.518710735499997),
#       ('Um', -25.577473660709753)]),
#   ( [('mostly',), ('in',)],
#     [ ('correct', -14.436012823090632),
#       ('Rloc-', -18.837857844693445),
#       ('Um', -22.097359909018948),
#       ('Wci', -22.233084608935172)]),
#   ( [('in',), ('their',)],
#     [ ('correct', -9.549275715358368),
#       ('Rloc-', -15.727522188400451),
#       ('Um', -15.803940630172466),
#       ('Wci', -16.790666898413377)]),
#   ( [('their',), ('late',)],
#     [ ('correct', -15.336372264205668),
#       ('Um', -20.599731175769207),
#       ('Wci', -20.901540762586688),
#       ('Rloc-', -23.142697298013747)]),
#   ( [('late',), ('fifties',)],
#     [ ('correct', -22.96687765564222),
# ...
#   ( [('of',), ('baby',)],
#     [ ('correct', -13.361292108275743),
#       ('Um', -18.471247443203772),
#       ('Wci', -19.3891833034498),
#       ('WOinc', -20.52962279973486)]),
#   ( [('baby',), ('boomers',)],
#     [ ('correct', -20.64130036115993),
#       ('Um', -23.848628016892267),
#       ('Wci', -26.990585638033533),
#       ('WOinc', -27.51526461737407)]),
#   ( [('boomers',), (',',)],
#     [ ('correct', -14.298997966318908),
#       ('Um', -18.958995221079366),
#       ('Rloc-', -21.2263368520603),
#       ('Mec', -22.121579332080508)]),
#   ( [(',',), ('who',)],
#     [ ('correct', -10.00718648845957),
#       ('Um', -16.21522693737508),
#       ('Rloc-', -16.277576961682133),
#       ('Wci', -18.846275964725116)]),
#   ( [('who',), ('are',)],
#     [ ('correct', -11.75053737018663),
#       ('Um', -17.68635271399073),
#       ('Rloc-', -17.701107128088665),
#       ('Wci', -19.445724569375077)]),
#   ( [('are',), ('now',)],
#     [ ('correct', -12.79619417632477),
#       ('Rloc-', -17.9403368171545),
#       ('Vt', -19.104985123156474),
#       ('Um', -19.11444420378908)]),
#   ( [('now',), ('mostly',)],
#     [ ('correct', -18.024923256066092),
#       ('Rloc-', -21.543502752994407),
#       ('WOinc', -25.518710735499997),
#       ('Um', -25.577473660709753)]),
#   ( [('mostly',), ('in',)],
#     [ ('correct', -14.436012823090632),
#       ('Rloc-', -18.837857844693445),
#       ('Um', -22.097359909018948),
#       ('Wci', -22.233084608935172)]),
#   ( [('in',), ('their',)],
#     [ ('correct', -9.549275715358368),
#       ('Rloc-', -15.727522188400451),
#       ('Um', -15.803940630172466),
#       ('Wci', -16.790666898413377)]),
#   ( [('their',), ('late',)],
#     [ ('correct', -15.336372264205668),
#       ('Um', -20.599731175769207),
#       ('Wci', -20.901540762586688),
#       ('Rloc-', -23.142697298013747)]),
#   ( [('late',), ('fifties',)],
#     [ ('correct', -22.96687765564222),
#       ('Wci', -26.343958473108483),
#       ('Um', -26.89315045461569),
#       ('Rloc-', -29.297555392030166)]),
#   ( [('fifties',), ('or',)],
#     [ ('correct', -19.094504892831367),
#       ('Rloc-', -23.164157349033516),
#       ('Um', -23.806248793923405),
#       ('Wci', -24.994031756159465)]),
#   ( [('or',), ('early',)],
#     [ ('correct', -14.794132111514326),
#       ('Um', -20.761726356199983),
#       ('Rloc-', -20.766262076235144),
#       ('Wci', -21.28045968945516)]),
#   ( [('early',), ('sixties',)],
#     [ ('correct', -24.108922584846972),
#       ('Wci', -25.674908844127597),
#       ('Um', -26.246523289690636),
#       ('Rloc-', -26.899660119231793)]),
#   ( [('sixties',), ('.',)],
#     [ ('correct', -18.775644014524993),
#       ('Um', -21.806115444124398),
#       ('Rloc-', -22.19835364847707),
#       ('Wci', -23.47227884822447)])]
# [ ( [(' ',), ('one',)],
#     [ ('correct', -21.66288323759064),
#       ('Rloc-', -23.77210245289838),
#       ('Um', -24.495255181817317),
#       ('Wci', -24.513283587630752)]),
#   ( [('one',), ('cause',)],
#     [ ('correct', -14.003240283025958),
#       ('Rloc-', -20.05853038619407),
#       ('Wci', -20.118834432958316),
#       ('Um', -20.78168311511301)]),
#   ( [('cause',), ('for',)],
#     [ ('correct', -12.526439875002708),
#       ('Wci', -18.320733788391813),
#       ('Um', -18.785129233238944),
#       ('Rloc-', -18.92340817548617)]),
#   ( [('for',), ('this',)],
#     [ ('correct', -10.265688996964904),
#       ('Um', -16.582499237335814),
#       ('Rloc-', -16.748102283857598),
#       ('Wci', -16.913064567687186)]),
#   ( [('this',), ('is',)],
#     [ ('correct', -9.923593730785608),
#       ('Um', -16.343986188690504),
#       ('Rloc-', -16.377819957581163),
#       ('Wci', -17.204546518048744)]),
#   ( [('is',), ('attributed',)],
#     [ ('correct', -15.13445736207576),
#       ('Wci', -19.962142455702384),
#       ('Um', -22.26018825129794),
#       ('Rloc-', -22.266697915914044)]),
#   ( [('attributed',), ('to',)],
#     [ ('correct', -14.368406591973725),
#       ('Wci', -18.62482863220175),
#       ('Rloc-', -21.338628898980055),
#       ('Um', -21.412132815116927)]),
#   ( [('to',), ('the',)],
#     [ ('correct', -6.602367685677116),
#       ('Um', -12.825227011289389),
#       ('Rloc-', -12.939994043687951),
#       ('Wci', -13.738785215691207)]),
#   ( [('the',), ('era',)],
#     [ ('correct', -13.716501014512183),
#       ('ArtOrDet', -20.009326849501306),
#       ('Um', -20.70413992358652),
#       ('Rloc-', -20.89892053673806)]),
#   ( [('era',), ('of',)],
#     [ ('correct', -14.5176127145645),
#       ('Rloc-', -21.3351397119091),
#       ('Um', -21.515769880927195),
#       ('Wci', -21.78707857624817)]),
#   ( [('of',), ('baby',)],
#     [ ('correct', -13.361292108275743),
#       ('Um', -18.471247443203772),
#       ('Wci', -19.3891833034498),
#       ('WOinc', -20.52962279973486)]),
#   ( [('baby',), ('boomers',)],
#     [ ('correct', -20.64130036115993),
#       ('Um', -23.848628016892267),
#       ('Wci', -26.990585638033533),
#       ('WOinc', -27.51526461737407)]),
#   ( [('boomers',), (',',)],
#     [ ('correct', -14.298997966318908),
#       ('Um', -18.958995221079366),
#       ('Rloc-', -21.2263368520603),
#       ('Mec', -22.121579332080508)]),
#   ( [(',',), ('who',)],
#     [ ('correct', -10.00718648845957),
#       ('Um', -16.21522693737508),
#       ('Rloc-', -16.277576961682133),
#       ('Wci', -18.846275964725116)]),
#   ( [('who',), ('are',)],
#     [ ('correct', -11.75053737018663),
#       ('Um', -17.68635271399073),
#       ('Rloc-', -17.701107128088665),
#       ('Wci', -19.445724569375077)]),
#   ( [('are',), ('now',)],
#     [ ('correct', -12.79619417632477),
#       ('Rloc-', -17.9403368171545),
#       ('Vt', -19.104985123156474),
#       ('Um', -19.11444420378908)]),
#   ( [('now',), ('mostly',)],
#     [ ('correct', -18.024923256066092),
#       ('Rloc-', -21.543502752994407),
#       ('WOinc', -25.518710735499997),
#       ('Um', -25.577473660709753)]),
#   ( [('mostly',), ('in',)],
#     [ ('correct', -14.436012823090632),
#       ('Rloc-', -18.837857844693445),
#       ('Um', -22.097359909018948),
#       ('Wci', -22.233084608935172)]),
#   ( [('in',), ('their',)],
#     [ ('correct', -9.549275715358368),
#       ('Rloc-', -15.727522188400451),
#       ('Um', -15.803940630172466),
#       ('Wci', -16.790666898413377)]),
#   ( [('their',), ('late',)],
#     [ ('correct', -15.336372264205668),
#       ('Um', -20.599731175769207),
#       ('Wci', -20.901540762586688),
#       ('Rloc-', -23.142697298013747)]),
#   ( [('late',), ('fifties',)],
#     [ ('correct', -22.96687765564222),
#       ('Wci', -26.343958473108483),
#       ('Um', -26.89315045461569),
#       ('Rloc-', -29.297555392030166)]),
#   ( [('fifties',), ('or',)],
#     [ ('correct', -19.094504892831367),
#       ('Rloc-', -23.164157349033516),
#       ('Um', -23.806248793923405),
#       ('Wci', -24.994031756159465)]),
#   ( [('or',), ('early',)],
#     [ ('correct', -14.794132111514326),
#       ('Um', -20.761726356199983),
#       ('Rloc-', -20.766262076235144),
#       ('Wci', -21.28045968945516)]),
#   ( [('early',), ('sixties',)],
#     [ ('correct', -24.108922584846972),
#       ('Wci', -25.674908844127597),
#       ('Um', -26.246523289690636),
#       ('Rloc-', -26.899660119231793)]),
#   ( [('sixties',), ('.',)],
#     [ ('correct', -18.775644014524993),
#       ('Um', -21.806115444124398),
#       ('Rloc-', -22.19835364847707),
#       ('Wci', -23.47227884822447)])]
# [ ( [(' ',), ('one',)],
#     [ ('correct', -21.66288323759064),
#       ('Rloc-', -23.77210245289838),
#       ('Um', -24.495255181817317),
#       ('Wci', -24.513283587630752)]),
#   ( [('one',), ('cause',)],
#     [ ('correct', -14.003240283025958),
#       ('Rloc-', -20.05853038619407),
#       ('Wci', -20.118834432958316),
#       ('Um', -20.78168311511301)]),
#   ( [('cause',), ('for',)],
#     [ ('correct', -12.526439875002708),
#       ('Wci', -18.320733788391813),
#       ('Um', -18.785129233238944),
#       ('Rloc-', -18.92340817548617)]),
#   ( [('for',), ('this',)],
#     [ ('correct', -10.265688996964904),
#       ('Um', -16.582499237335814),
#       ('Rloc-', -16.748102283857598),
#       ('Wci', -16.913064567687186)]),
#   ( [('this',), ('is',)],
#     [ ('correct', -9.923593730785608),
#       ('Um', -16.343986188690504),
#       ('Rloc-', -16.377819957581163),
#       ('Wci', -17.204546518048744)]),
#   ( [('is',), ('attributed',)],
#     [ ('correct', -15.13445736207576),
#       ('Wci', -19.962142455702384),
#       ('Um', -22.26018825129794),
#       ('Rloc-', -22.266697915914044)]),
#   ( [('attributed',), ('to',)],
#     [ ('correct', -14.368406591973725),
#       ('Wci', -18.62482863220175),
#       ('Rloc-', -21.338628898980055),
#       ('Um', -21.412132815116927)]),
#   ( [('to',), ('the',)],
#     [ ('correct', -6.602367685677116),
#       ('Um', -12.825227011289389),
#       ('Rloc-', -12.939994043687951),
#       ('Wci', -13.738785215691207)]),
#   ( [('the',), ('era',)],
#     [ ('correct', -13.716501014512183),
#       ('ArtOrDet', -20.009326849501306),
#       ('Um', -20.70413992358652),
#       ('Rloc-', -20.89892053673806)]),
#   ( [('era',), ('of',)],
#     [ ('correct', -14.5176127145645),
#       ('Rloc-', -21.3351397119091),
#       ('Um', -21.515769880927195),
#       ('Wci', -21.78707857624817)]),
#   ( [('of',), ('baby',)],
#     [ ('correct', -13.361292108275743),
#       ('Um', -18.471247443203772),
#       ('Wci', -19.3891833034498),
#       ('WOinc', -20.52962279973486)]),
#   ( [('baby',), ('boomers',)],
#     [ ('correct', -20.64130036115993),
#       ('Um', -23.848628016892267),
#       ('Wci', -26.990585638033533),
#       ('WOinc', -27.51526461737407)]),
#   ( [('boomers',), (',',)],
#     [ ('correct', -14.298997966318908),
#       ('Um', -18.958995221079366),
#       ('Rloc-', -21.2263368520603),
#       ('Mec', -22.121579332080508)]),
#   ( [(',',), ('who',)],
#     [ ('correct', -10.00718648845957),
#       ('Um', -16.21522693737508),
#       ('Rloc-', -16.277576961682133),
#       ('Wci', -18.846275964725116)]),
#   ( [('who',), ('are',)],
#     [ ('correct', -11.75053737018663),
#       ('Um', -17.68635271399073),
#       ('Rloc-', -17.701107128088665),
#       ('Wci', -19.445724569375077)]),
#   ( [('are',), ('now',)],
#     [ ('correct', -12.79619417632477),
#       ('Rloc-', -17.9403368171545),
#       ('Vt', -19.104985123156474),
#       ('Um', -19.11444420378908)]),
#   ( [('now',), ('mostly',)],
#     [ ('correct', -18.024923256066092),
#       ('Rloc-', -21.543502752994407),
#       ('WOinc', -25.518710735499997),
#       ('Um', -25.577473660709753)]),
#   ( [('mostly',), ('in',)],
#     [ ('correct', -14.436012823090632),
#       ('Rloc-', -18.837857844693445),
#       ('Um', -22.097359909018948),
#       ('Wci', -22.233084608935172)]),
#   ( [('in',), ('their',)],
#     [ ('correct', -9.549275715358368),
#       ('Rloc-', -15.727522188400451),
#       ('Um', -15.803940630172466),
#       ('Wci', -16.790666898413377)]),
#   ( [('their',), ('late',)],
#     [ ('correct', -15.336372264205668),
#       ('Um', -20.599731175769207),
#       ('Wci', -20.901540762586688),
#       ('Rloc-', -23.142697298013747)]),
#   ( [('late',), ('fifties',)],
#     [ ('correct', -22.96687765564222),
#       ('Wci', -26.343958473108483),
#       ('Um', -26.89315045461569),
#       ('Rloc-', -29.297555392030166)]),
#   ( [('fifties',), ('or',)],
#     [ ('correct', -19.094504892831367),
#       ('Rloc-', -23.164157349033516),
#       ('Um', -23.806248793923405),
#       ('Wci', -24.994031756159465)]),
#   ( [('or',), ('early',)],
#     [ ('correct', -14.794132111514326),
#       ('Um', -20.761726356199983),
#       ('Rloc-', -20.766262076235144),
#       ('Wci', -21.28045968945516)]),
#   ( [('early',), ('sixties',)],
#     [ ('correct', -24.108922584846972),
#       ('Wci', -25.674908844127597),
#       ('Um', -26.246523289690636),
#       ('Rloc-', -26.899660119231793)]),
#   ( [('sixties',), ('.',)],
#     [ ('correct', -18.775644014524993),
#       ('Um', -21.806115444124398),
#       ('Rloc-', -22.19835364847707),
#       ('Wci', -23.47227884822447)])]
# [ ( [(' ',), ('one',)],
#     [ ('correct', -21.66288323759064),
#       ('Rloc-', -23.77210245289838),
#       ('Um', -24.495255181817317),
#       ('Wci', -24.513283587630752)]),
#   ( [('one',), ('cause',)],
#     [ ('correct', -14.003240283025958),
#       ('Rloc-', -20.05853038619407),
#       ('Wci', -20.118834432958316),
#       ('Um', -20.78168311511301)]),
#   ( [('cause',), ('for',)],
#     [ ('correct', -12.526439875002708),
#       ('Wci', -18.320733788391813),
#       ('Um', -18.785129233238944),
#       ('Rloc-', -18.92340817548617)]),
#   ( [('for',), ('this',)],
#     [ ('correct', -10.265688996964904),
#       ('Um', -16.582499237335814),
#       ('Rloc-', -16.748102283857598),
#       ('Wci', -16.913064567687186)]),
#   ( [('this',), ('is',)],
#     [ ('correct', -9.923593730785608),
#       ('Um', -16.343986188690504),
#       ('Rloc-', -16.377819957581163),
#       ('Wci', -17.204546518048744)]),
#   ( [('is',), ('attributed',)],
#     [ ('correct', -15.13445736207576),
#       ('Wci', -19.962142455702384),
#       ('Um', -22.26018825129794),
#       ('Rloc-', -22.266697915914044)]),
#   ( [('attributed',), ('to',)],
#     [ ('correct', -14.368406591973725),
#       ('Wci', -18.62482863220175),
#       ('Rloc-', -21.338628898980055),
#       ('Um', -21.412132815116927)]),
#   ( [('to',), ('the',)],
#     [ ('correct', -6.602367685677116),
#       ('Um', -12.825227011289389),
#       ('Rloc-', -12.939994043687951),
#       ('Wci', -13.738785215691207)]),
#   ( [('the',), ('era',)],
#     [ ('correct', -13.716501014512183),
#       ('ArtOrDet', -20.009326849501306),
#       ('Um', -20.70413992358652),
#       ('Rloc-', -20.89892053673806)]),
#   ( [('era',), ('of',)],
#     [ ('correct', -14.5176127145645),
#       ('Rloc-', -21.3351397119091),
#       ('Um', -21.515769880927195),
#       ('Wci', -21.78707857624817)]),
#   ( [('of',), ('baby',)],
#     [ ('correct', -13.361292108275743),
#       ('Um', -18.471247443203772),
#       ('Wci', -19.3891833034498),
#       ('WOinc', -20.52962279973486)]),
#   ( [('baby',), ('boomers',)],
#     [ ('correct', -20.64130036115993),
#       ('Um', -23.848628016892267),
#       ('Wci', -26.990585638033533),
#       ('WOinc', -27.51526461737407)]),
#   ( [('boomers',), (',',)],
#     [ ('correct', -14.298997966318908),
#       ('Um', -18.958995221079366),
#       ('Rloc-', -21.2263368520603),
#       ('Mec', -22.121579332080508)]),
#   ( [(',',), ('who',)],
#     [ ('correct', -10.00718648845957),
#       ('Um', -16.21522693737508),
#       ('Rloc-', -16.277576961682133),
#       ('Wci', -18.846275964725116)]),
#   ( [('who',), ('are',)],
#     [ ('correct', -11.75053737018663),
#       ('Um', -17.68635271399073),
#       ('Rloc-', -17.701107128088665),
#       ('Wci', -19.445724569375077)]),
#   ( [('are',), ('now',)],
#     [ ('correct', -12.79619417632477),
#       ('Rloc-', -17.9403368171545),
#       ('Vt', -19.104985123156474),
#       ('Um', -19.11444420378908)]),
#   ( [('now',), ('mostly',)],
#     [ ('correct', -18.024923256066092),
#       ('Rloc-', -21.543502752994407),
#       ('WOinc', -25.518710735499997),
#       ('Um', -25.577473660709753)]),
#   ( [('mostly',), ('in',)],
#     [ ('correct', -14.436012823090632),
#       ('Rloc-', -18.837857844693445),
#       ('Um', -22.097359909018948),
#       ('Wci', -22.233084608935172)]),
#   ( [('in',), ('their',)],
#     [ ('correct', -9.549275715358368),
#       ('Rloc-', -15.727522188400451),
#       ('Um', -15.803940630172466),
#       ('Wci', -16.790666898413377)]),
#   ( [('their',), ('late',)],
#     [ ('correct', -15.336372264205668),
#       ('Um', -20.599731175769207),
#       ('Wci', -20.901540762586688),
#       ('Rloc-', -23.142697298013747)]),
#   ( [('late',), ('fifties',)],
#     [ ('correct', -22.96687765564222),
#       ('Wci', -26.343958473108483),
#       ('Um', -26.89315045461569),
#       ('Rloc-', -29.297555392030166)]),
#   ( [('fifties',), ('or',)],
#     [ ('correct', -19.094504892831367),
#       ('Rloc-', -23.164157349033516),
#       ('Um', -23.806248793923405),
#       ('Wci', -24.994031756159465)]),
#   ( [('or',), ('early',)],
#     [ ('correct', -14.794132111514326),
#       ('Um', -20.761726356199983),
#       ('Rloc-', -20.766262076235144),
#       ('Wci', -21.28045968945516)]),
#   ( [('early',), ('sixties',)],
#     [ ('correct', -24.108922584846972),
#       ('Wci', -25.674908844127597),
#       ('Um', -26.246523289690636),
#       ('Rloc-', -26.899660119231793)]),
#   ( [('sixties',), ('.',)],
#     [ ('correct', -18.775644014524993),
#       ('Um', -21.806115444124398),
#       ('Rloc-', -22.19835364847707),
#       ('Wci', -23.47227884822447)])]
