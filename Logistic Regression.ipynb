# %% [markdown]
# # POS Tagging using Logistic Regression

# %% [markdown]
# ## Imports and Initialisations

# %%
from collections import Counter
from copy import deepcopy
from math import exp
import matplotlib.pyplot as plt
import numpy as np
import nltk
import os
import pickle

nltk.download('brown')
nltk.download('universal_tagset')

from nltk.corpus import brown
# Out:
# [nltk_data] Downloading package brown to /Users/sounak/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     /Users/sounak/nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!

# %%
sents = brown.tagged_sents(tagset='universal')
_N = int(len(sents) * (8 / 10))
sents_train = sents[:_N]
sents_test = sents[_N:]

# %%
sents[0]
# Out:
# [('The', 'DET'),
#  ('Fulton', 'NOUN'),
#  ('County', 'NOUN'),
#  ('Grand', 'ADJ'),
#  ('Jury', 'NOUN'),
#  ('said', 'VERB'),
#  ('Friday', 'NOUN'),
#  ('an', 'DET'),
#  ('investigation', 'NOUN'),
#  ('of', 'ADP'),
#  ("Atlanta's", 'NOUN'),
#  ('recent', 'ADJ'),
#  ('primary', 'NOUN'),
#  ('election', 'NOUN'),
#  ('produced', 'VERB'),
#  ('``', '.'),
#  ('no', 'DET'),
#  ('evidence', 'NOUN'),
#  ("''", '.'),
#  ('that', 'ADP'),
#  ('any', 'DET'),
#  ('irregularities', 'NOUN'),
#  ('took', 'VERB'),
#  ('place', 'NOUN'),
#  ('.', '.')]

# %% [markdown]
# ## One vs Many Logistic Regression

# %%
def save_obj(obj, name):
    if 'obj' not in os.listdir():
        os.mkdir('obj')
    with open('obj/'+ name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name):
    try:
        with open('obj/' + name + '.pkl', 'rb') as f:
            return pickle.load(f)
    except:
        return None

word_vecs = load_obj('word_vecs')

if not word_vecs:
    GLOVE_PATH = "/Users/sounak/Documents/clg/nlp/nlp-projects/data/glove.6B.300d.txt"
    f = open(GLOVE_PATH, 'r')
    word_vecs = {}
    for line in f.readlines():
        t = line.split(' ')
        word_vecs[t[0]] = np.array([float(_) for _ in t[1:]])
    f.close()
    save_obj(word_vecs, 'word_vecs')
    
print('word_vecs have been loaded')
# Out:
# word_vecs have been loaded

# %%
class Multiclass_LR:
    def _ascii(self, s):
        return int(''.join(str(ord(c)) for c in s))
        
    def tag_sent(self, sent, tags):
        sent_tagged = []
#         feature_extractors = {
#             'is_upper_first_letter': lambda sent, i: sent[i][0].isupper(),
#             'is_upper_all': lambda sent, i: sent[i].isupper(),
#             'is_hyphenated': lambda sent, i: '-' in sent[i],
#             'is_punctuation': lambda sent, i: sent[i] in self.puncs,
#             'previous_tag': lambda sent, i: self.tags.index(tags[i-1]) if i != 0 else -1,
#             'current_tag': lambda sent, i: self.tags.index(tags[i]),
# #             sent_tagged[i-1][1]
# #             '1_prefix': lambda sent, i: self._ascii(sent[i][0]) if len(sent[i]) >= 1 else 0,
# #             '2_prefix': lambda sent, i: self._ascii(sent[i][1]) if len(sent[i]) >= 2 else 0,
# #             '1_postfix': lambda sent, i: self._ascii(sent[i][-1]) if len(sent[i]) >= 1 else 0,
# #             '2_postfix': lambda sent, i: self._ascii(sent[i][-2]) if len(sent[i]) >= 2 else 0,
#         }
        for i, word in enumerate(sent):
#             x = np.array([int(ex(sent, i)) for k, ex in feature_extractors.items()])
            try:
                x = word_vecs[word.lower()]
            except KeyError:
                x = word_vecs['unk']
            max_tag = max([(word, tag) for tag in self.tags], key=lambda k: np.dot(np.append(x, 1), self.W[k[1]]))
            sent_tagged.append(max_tag)
        return sent_tagged
        
    def train_model(self):
        for tag in self.tags:
            print('Training for tag', tag)
            self.W[tag] = self.logistic_regression(tag)
    
    def sigmoid(self, a):
        return 1.0 / (1 + np.exp(-a))
        
    def logistic_regression(self, tag, num_steps=300000, learning_rate=5e-5, add_intercept=True):
        X = self.X[tag]
        Y = self.Y[tag]
        if add_intercept:
            intercept = np.ones((X.shape[0], 1))
            X = np.hstack((X, intercept))
            
        w = np.zeros(X.shape[1])
        for step in range(num_steps):
            scores = np.dot(X, w)
            predictions = self.sigmoid(scores)
            output_error_signal = Y - predictions
            gradient = np.dot(X.T, output_error_signal)
            w += learning_rate * gradient
        return w
        
    def loss(self, w, X, Y):
        w = np.array(w).reshape(-1, 1)
        sum = 0
        for i in range(Y.shape[0]):
            x = X[i].reshape(-1, 1)
            wTx = np.matmul(w.T, x)
            sum += Y[i] * wTx - np.log(1 + np.exp(wTx))
        return sum.reshape(())
        
    def get_feature_set(self):
        self.puncs = {'!', "'", "''", '(', ')', ',', '--', '.', ':', ';', '?', '[', ']', '``'}
        self.feature_extractors = {
            'is_upper_first_letter': lambda sent, i: sent[i][0][0].isupper(),
            'is_upper_all': lambda sent, i: sent[i][0].isupper(),
            'is_hyphenated': lambda sent, i: '-' in sent[i][0],
            'is_punctuation': lambda sent, i: sent[i][0] in self.puncs,
            'previous_tag': lambda sent, i: self.tags.index(sent[i-1][1]) if i != 0 else -1,
            'current_tag': lambda sent, i: self.tags.index(sent[i][1]),
#             '1_prefix': lambda sent, i: self._ascii(sent[i][0][0]) if len(sent[i][0]) >= 1 else 0,
#             '2_prefix': lambda sent, i: self._ascii(sent[i][0][1]) if len(sent[i][0]) >= 2 else 0,
#             '1_postfix': lambda sent, i: self._ascii(sent[i][0][-1]) if len(sent[i][0]) >= 1 else 0,
#             '2_postfix': lambda sent, i: self._ascii(sent[i][0][-2]) if len(sent[i][0]) >= 2 else 0,
        }
        
        for t in range(len(self.tags)):
            self.X[self.tags[t]] = []
            self.Y[self.tags[t]] = []
            for sent in self.sents:
                for i, (word, tag) in enumerate(sent):
#                     x = [int(ex(sent, i)) for k, ex in self.feature_extractors.items()]
                    try:
                        x = word_vecs[word.lower()]
                    except KeyError:
                        x = word_vecs['unk']
                    self.X[self.tags[t]].append(x)
                    self.Y[self.tags[t]].append(1 if tag == self.tags[t] else 0)
            self.X[self.tags[t]] = np.array(self.X[self.tags[t]])
            self.Y[self.tags[t]] = np.array(self.Y[self.tags[t]])

    def __init__(self, tagged_sents):
        self.sents = tagged_sents
        self.tags = list(set([tag for sent in self.sents for word, tag in sent]))
        self.X = {}
        self.Y = {}
        self.W = {}
        self.get_feature_set()
        self.train_model()
        pass

# %%
T = Multiclass_LR(sents_train[:100])
# Out:
# Training for tag DET
# Training for tag ADP
# Training for tag ADV
# Training for tag NOUN
# Training for tag ADJ
# Training for tag CONJ
# Training for tag PRT
# Training for tag NUM
# Training for tag PRON
# Training for tag VERB
# Training for tag .

# %%
score = 0
total_count = 0
for i, sent in enumerate(sents_test[:1000]):
    _sent = [word for word, tag in sent]
    _tags = [tag for word, tag in sent]
    res = T.tag_sent(_sent, _tags)
    print(res)
    N = len(sent)
    total_count += N
    for i in range(N):
        score += 1 if res[i][1] == sent[i][1] else 0
            
accuracy = (score / total_count) * 100
print('Accuracy', accuracy)
# Out:
# [('The', 'DET'), ('quarrel', 'DET'), ('ended', 'NOUN'), ('in', 'ADP'), ('a', 'DET'), ('ridiculous', 'NOUN'), ('draw', 'VERB'), (',', '.'), ('but', 'CONJ'), ('I', 'PRON'), ('must', 'VERB'), ('tell', 'NOUN'), ('you', 'PRON'), ('about', 'ADP'), ('it', 'PRON'), ('.', '.')]
# [('Oh', '.'), (',', '.'), ('yes', '.'), (',', '.'), ("I'm", 'NOUN'), ('quite', 'ADV'), ('sure', 'VERB'), ("it's", 'NOUN'), ('important', 'DET'), (',', '.'), ('because', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('Beech', 'ADV'), ('Pasture', 'DET'), ('.', '.')]
# [("What's", 'NOUN'), ('that', 'ADP'), ('?', '.'), ('?', '.')]
# [('Why', 'NOUN'), (',', '.'), ("that's", 'NOUN'), ('what', 'DET'), ('gave', 'VERB'), ('me', 'PRON'), ('the', 'DET'), ('feeling', 'NOUN'), (',', '.'), ('gave', 'VERB'), ('me', 'PRON'), ('as-it-were', 'NOUN'), ('the', 'DET'), ('spirit', 'VERB'), (',', '.'), ('the', 'DET'), ('demoniac', 'NOUN'), (',', '.'), ('evil', 'DET'), ('spirit', 'VERB'), ('of', 'ADP'), ('this', 'DET'), ('whole', 'NOUN'), ('affair', 'NOUN'), ('.', '.')]
# [('You', 'PRON'), ('see', 'NOUN'), (',', '.'), ('besides', 'VERB'), ('being', 'VERB'), ('custodian', 'NOUN'), ('of', 'ADP'), ('antiquities', 'CONJ'), (',', '.'), ('I', 'PRON'), ('am', 'PRON'), ('also', 'ADV'), ('registrar', 'ADJ'), ('.', '.')]
# [('No', 'DET'), (',', '.'), ('I', 'PRON'), ("don't", 'NOUN'), ('hold', 'VERB'), ('with', 'ADP'), ('those', 'ADP'), ('who', 'PRON'), ('live', 'ADP'), ('entirely', 'NOUN'), ('among', 'ADP'), ('dead', 'NOUN'), ('things', 'NOUN'), ('.', '.')]
# [('I', 'PRON'), ('know', 'PRON'), ('as', 'ADP'), ('well', 'ADV'), ('as', 'ADP'), ('the', 'DET'), ('next', 'ADJ'), ('man', 'NOUN'), ('that', 'ADP'), ('a', 'DET'), ('ship', 'VERB'), ('is', 'VERB'), ('called', 'NOUN'), ('from', 'ADP'), ('the', 'DET'), ('rigging', 'NOUN'), ('she', 'ADJ'), ('carries', 'VERB'), (',', '.'), ('where', 'ADV'), ('the', 'DET'), ('live', 'ADP'), ('wind', 'VERB'), ('blows', 'NOUN'), (',', '.'), ('and', 'CONJ'), ('not', 'ADV'), ('from', 'ADP'), ('the', 'DET'), ('hull', 'VERB'), ('.', '.')]
# [('But', 'CONJ'), ("you've", 'NOUN'), ('got', 'VERB'), ('to', 'PRT'), ('know', 'PRON'), ('both', 'DET'), ('.', '.')]
# [("What's", 'NOUN'), ('below', 'VERB'), ('the', 'DET'), ('water-line', 'NOUN'), ('interests', 'NOUN'), ('me', 'PRON'), ('also', 'ADV'), ('.', '.')]
# [('As', 'ADP'), ('I', 'PRON'), ('was', 'VERB'), ('saying', 'VERB'), (',', '.'), ("I've", 'NOUN'), ('known', 'DET'), ('all', 'PRT'), ('about', 'ADP'), ('the', 'DET'), ('old', 'ADJ'), ('records', 'NOUN'), (',', '.'), ('including', 'NOUN'), ('the', 'DET'), ('old', 'ADJ'), ('Norberg', 'ADJ'), ('deed', 'DET'), ('.', '.')]
# [('Some', 'DET'), ('ten', 'NUM'), ('years', 'NOUN'), ('ago', 'VERB'), ('that', 'ADP'), ('page', 'VERB'), ('was', 'VERB'), ('torn', 'NOUN'), ('out', 'PRT'), (',', '.'), ('I', 'PRON'), ("don't", 'NOUN'), ('know', 'PRON'), ('by', 'ADP'), ('whom', 'VERB'), ('.', '.')]
# [('About', 'ADP'), ('five', 'NUM'), ('years', 'NOUN'), ('ago', 'VERB'), (',', '.'), ('Handley', 'NUM'), ('came', 'NOUN'), ('to', 'PRT'), ('ask', 'VERB'), ('me', 'PRON'), ('if', 'VERB'), ('he', 'PRON'), ('could', 'VERB'), ('see', 'NOUN'), ('the', 'DET'), ('tattered', 'DET'), ('register', 'NOUN'), ('.', '.')]
# [('He', 'PRON'), ('was', 'VERB'), ('courteous', 'ADJ'), ('and', 'CONJ'), ('casual', 'ADJ'), ('about', 'ADP'), ('it', 'PRON'), (',', '.'), ('as', 'ADP'), ('though', 'ADV'), ('it', 'PRON'), ('were', 'VERB'), ('of', 'ADP'), ('no', 'DET'), ('consequence', 'NOUN'), ('.', '.')]
# [("He's", 'NOUN'), ('always', 'VERB'), ('like', 'ADP'), ('that', 'ADP'), (',', '.'), ('in', 'ADP'), ('spite', 'NOUN'), ('of', 'ADP'), ('being', 'VERB'), ('a', 'DET'), ('big', 'NOUN'), ('man', 'NOUN'), ('.', '.')]
# [('(', '.'), ('When', 'ADV'), ('you', 'PRON'), ('see', 'NOUN'), ('him', 'PRON'), (',', '.'), ("you'll", 'NOUN'), ('notice', 'NOUN'), ('his', 'DET'), ('habit', 'NOUN'), ('of', 'ADP'), ('fingering', 'VERB'), (',', '.'), ('I', 'PRON'), ('might', 'VERB'), ('almost', 'VERB'), ('say', 'NOUN'), (',', '.'), ('stroking', 'VERB'), ('a', 'DET'), ('large', 'ADJ'), ('mole', 'ADJ'), ('with', 'ADP'), ('black', 'NOUN'), ('hairs', 'ADJ'), ('on', 'ADP'), ('it', 'PRON'), (',', '.'), ('by', 'ADP'), ('his', 'DET'), ('right', 'VERB'), ('temple', 'NOUN'), ('.', '.')]
# [(')', '.'), ('A', 'DET'), ('sensual', 'ADJ'), ('man', 'NOUN'), (',', '.'), ('but', 'CONJ'), ('very', 'ADV'), ('courteous', 'ADJ'), (',', '.'), ('some', 'DET'), ('would', 'VERB'), ('say', 'NOUN'), ('slick', 'VERB'), ('.', '.')]
# [('Like', 'ADP'), ('his', 'DET'), ('glossy', 'NOUN'), ('black', 'NOUN'), ('hair', 'ADJ'), ('.', '.')]
# [('Too', 'ADV'), ('many', 'ADJ'), ('outside', 'NOUN'), ('manners', 'NOUN'), (',', '.'), ('to', 'PRT'), ('my', 'DET'), ('taste', 'VERB'), ('.', '.')]
# [('He', 'PRON'), ('is', 'VERB'), ('the', 'DET'), ('sort', 'NOUN'), ('who', 'PRON'), (',', '.'), ('with', 'ADP'), ('an', 'DET'), ('appraising', 'DET'), ('eye', 'VERB'), (',', '.'), ('would', 'VERB'), ('cross', 'VERB'), ('the', 'DET'), ('street', 'NOUN'), ('to', 'PRT'), ('help', 'NOUN'), ('a', 'DET'), ('strange', 'NOUN'), ('woman', 'VERB'), ('on', 'ADP'), ('to', 'PRT'), ('a', 'DET'), ('bus', 'NOUN'), ('and', 'CONJ'), ('then', 'ADV'), ('pinch', 'VERB'), ('her', 'ADJ'), ('.', '.')]
# [('A', 'DET'), ('real', 'ADV'), ('gentleman', 'NOUN'), (',', '.'), ('I', 'PRON'), ('feel', 'VERB'), (',', '.'), ('would', 'VERB'), ('do', 'VERB'), ('neither', 'ADV'), ('.', '.')]
# [("He's", 'NOUN'), ('always', 'VERB'), ('worn', 'VERB'), ('a', 'DET'), ('broad-brimmed', 'NOUN'), ('hat', 'NOUN'), (',', '.'), ('and', 'CONJ'), ("I've", 'NOUN'), ('noticed', 'VERB'), (',', '.'), ('in', 'ADP'), ('my', 'DET'), ('small', 'DET'), ('study', 'VERB'), ('at', 'ADP'), ('the', 'DET'), ('Society', 'VERB'), (',', '.'), ('that', 'ADP'), ('he', 'PRON'), ('rather', 'NOUN'), ('smells', 'VERB'), ('of', 'ADP'), ('cosmetics', 'VERB'), ('.', '.')]
# [('The', 'DET'), ('next', 'ADJ'), ('week', 'NOUN'), (',', '.'), ('cousin', 'NOUN'), ('Red', 'VERB'), ('wandered', 'ADP'), ('in', 'ADP'), ('as', 'ADP'), ('casually', 'ADV'), (',', '.'), ('but', 'CONJ'), ('curt', 'ADJ'), ('and', 'CONJ'), ('untidy', 'ADJ'), ('.', '.')]
# [('Red', 'VERB'), ('was', 'VERB'), ('small', 'DET'), ('and', 'CONJ'), ('fine-boned', 'NOUN'), (',', '.'), ('like', 'ADP'), ('ivory-inlay', 'NOUN'), ('.', '.')]
# [('He', 'PRON'), ('too', 'ADV'), ('asked', 'VERB'), ('to', 'PRT'), ('see', 'NOUN'), ('the', 'DET'), ('same', 'DET'), ('page', 'VERB'), ('.', '.')]
# [('When', 'ADV'), ('I', 'PRON'), ('told', 'VERB'), ('him', 'PRON'), ('someone', 'VERB'), ('had', 'VERB'), ('torn', 'NOUN'), ('it', 'PRON'), ('out', 'PRT'), (',', '.'), ('he', 'PRON'), ('shouted', '.'), ('.', '.')]
# [('``', '.'), ('By', 'ADP'), ('God', 'VERB'), (',', '.'), ("it's", 'NOUN'), ('that', 'ADP'), ('damn', 'PRON'), ('Handley', 'NUM'), (',', '.'), ('the', 'DET'), ('sneak', 'PRON'), ("''", '.'), ('!', '.'), ('!', '.')]
# [('And', 'CONJ'), ('later', 'ADV'), ('in', 'ADP'), ('the', 'DET'), ('same', 'DET'), ('week', 'NOUN'), ('they', 'PRON'), ('both', 'DET'), ('came', 'NOUN'), ('together', 'ADV'), ('to', 'PRT'), ('examine', 'NOUN'), ('the', 'DET'), ('register', 'NOUN'), ('.', '.')]
# [('Fortunately', 'NOUN'), ('we', 'PRON'), ('were', 'VERB'), ('alone', 'NOUN'), ('in', 'ADP'), ('the', 'DET'), ('building', 'NOUN'), ('--', '.'), ('so', 'ADV'), ('few', 'ADJ'), ('people', 'ADP'), ('nowadays', 'ADV'), ('are', 'VERB'), ('interested', 'VERB'), ('even', 'VERB'), ('in', 'ADP'), ('their', 'DET'), ('own', 'DET'), ('past', 'NOUN'), ('or', 'CONJ'), ('in', 'ADP'), ('the', 'DET'), ('lovely', 'ADJ'), ('craft', 'ADJ'), ('of', 'ADP'), ('other', 'ADJ'), ('days', 'NOUN'), ('--', '.'), ('for', 'ADP'), ('they', 'PRON'), ('began', 'ADP'), ('to', 'PRT'), ('abuse', 'VERB'), ('each', 'DET'), ('other', 'ADJ'), ('in', 'ADP'), ('the', 'DET'), ('foulest', 'ADV'), ('language', 'DET'), ('.', '.')]
# [('Red', 'VERB'), ('thrusting', 'VERB'), ('out', 'PRT'), ('his', 'DET'), ('tawny', 'NOUN'), ('beard', 'VERB'), (',', '.'), ('Handley', 'NUM'), ('glowering', 'ADJ'), ('under', 'ADP'), ('his', 'DET'), ('suddenly', 'VERB'), ('rumpled', 'ADJ'), ('black', 'NOUN'), ('hair', 'ADJ'), ('.', '.')]
# [('They', 'PRON'), ('actually', 'VERB'), ('bristled', 'ADJ'), ('.', '.')]
# [('Le', 'VERB'), ('rouge', 'CONJ'), ('et', 'NOUN'), ('le', 'VERB'), ('noir', 'ADJ'), ('.', '.')]
# [('Violent', 'NOUN'), ('men', 'NOUN'), ('both', 'DET'), ('.', '.')]
# [('Red', 'VERB'), ('always', 'VERB'), ('was', 'VERB'), ('morose', 'ADJ'), (',', '.'), ('yet', 'ADV'), ('that', 'ADP'), ('day', 'NOUN'), ('the', 'DET'), ('dapper', 'NOUN'), ('Handley', 'NUM'), ('was', 'VERB'), ('the', 'DET'), ('louder', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('two', 'NUM'), ('.', '.')]
# [('But', 'CONJ'), ('for', 'ADP'), ('my', 'DET'), ('presence', 'ADJ'), (',', '.'), ('they', 'PRON'), ('would', 'VERB'), ('have', 'VERB'), ('been', 'VERB'), ('at', 'ADP'), ('each', 'DET'), ("others'", 'NOUN'), ('throats', 'DET'), ('.', '.')]
# [('During', 'ADP'), ('the', 'DET'), ('quarrel', 'DET'), ('I', 'PRON'), ('learned', 'VERB'), ('what', 'DET'), ('the', 'DET'), ('trouble', 'NOUN'), ('was', 'VERB'), (',', '.'), ('from', 'ADP'), ('the', 'DET'), ('accusations', 'NOUN'), ('each', 'DET'), ('hurled', 'NOUN'), ('at', 'ADP'), ('the', 'DET'), ('other', 'ADJ'), ('.', '.')]
# [('The', 'DET'), ('Beech', 'ADV'), ('Pasture', 'DET'), ('had', 'VERB'), ('suddenly', 'VERB'), ('become', 'VERB'), ('valuable', 'VERB'), ('.', '.')]
# [("There's", 'NOUN'), ('a', 'DET'), ('fine', 'VERB'), ('granite', 'ADJ'), ('quarry', 'DET'), ('there', 'PRT'), (',', '.'), ('and', 'CONJ'), ("granite's", 'NOUN'), ('coming', 'NOUN'), ('back', 'ADV'), ('for', 'ADP'), ('public', 'ADJ'), ('buildings', 'NOUN'), ('.', '.')]
# [('Both', 'DET'), ('men', 'NOUN'), ('knew', 'VERB'), ('it', 'PRON'), ('was', 'VERB'), ('in', 'ADP'), ('the', 'DET'), ('Norberg', 'ADJ'), ('family', 'NOUN'), ('holdings', 'VERB'), (',', '.'), ('but', 'CONJ'), ('to', 'PRT'), ('which', 'DET'), ('of', 'ADP'), ('the', 'DET'), ('cousins', 'NOUN'), ('did', 'VERB'), ('it', 'PRON'), ('belong', 'VERB'), (',', '.'), ('Anta', 'ADJ'), ('or', 'CONJ'), ('Freya', 'VERB'), ('?', '.'), ('?', '.')]
# [('Fortunately', 'NOUN'), (',', '.'), ('I', 'PRON'), ('knew', 'VERB'), ('almost', 'VERB'), ('exactly', 'NOUN'), ('what', 'DET'), ('the', 'DET'), ('will', 'VERB'), ('had', 'VERB'), ('said', 'VERB'), ('.', '.')]
# [('It', 'PRON'), ('began', 'ADP'), ('with', 'ADP'), ('a', 'DET'), ('preamble', 'VERB'), (',', '.'), ('of', 'ADP'), ('course', 'VERB'), ('.', '.')]
# [('This', 'DET'), ('explained', 'VERB'), ('that', 'ADP'), ('the', 'DET'), ('judge', 'NOUN'), ('of', 'ADP'), ('probate', 'NOUN'), ('of', 'ADP'), ('Essex', 'NUM'), ('County', 'NOUN'), (',', '.'), ('1785', 'NOUN'), ('or', 'CONJ'), ('1786', 'NUM'), (',', '.'), ('appointed', 'VERB'), ('three', 'NUM'), ('free-holders', 'NOUN'), ('of', 'ADP'), ('Gloucester', 'NOUN'), ('to', 'PRT'), ('divide', 'VERB'), ('and', 'CONJ'), ('establish', 'NOUN'), ('the', 'DET'), ('Norberg', 'ADJ'), ('estate', 'NOUN'), ('.', '.')]
# [('After', 'ADP'), ('the', 'DET'), ('usual', 'ADJ'), ('Honorable', 'VERB'), ('Sirs', '.'), (',', '.'), ('it', 'PRON'), ('went', 'VERB'), ('on', 'ADP'), ('to', 'PRT'), ('say', 'NOUN'), ('that', 'ADP'), ('there', 'PRT'), ('had', 'VERB'), ('been', 'VERB'), ('set', 'VERB'), ('off', 'PRT'), ('to', 'PRT'), ('the', 'DET'), ('widow', 'NOUN'), ('one', 'NUM'), ('full', 'DET'), ('third', 'VERB'), ('part', 'DET'), ('of', 'ADP'), ('the', 'DET'), ('real', 'ADV'), ('estate', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('deceased', 'NOUN'), ('Salu', 'NOUN'), ('Norberg', 'ADJ'), (',', '.'), ('one', 'NUM'), ('lower', 'VERB'), ('room', 'NOUN'), (',', '.'), ('on', 'ADP'), ('the', 'DET'), ('Western', 'ADJ'), ('side', 'DET'), (',', '.'), ('privileges', 'ADJ'), ('to', 'PRT'), ('the', 'DET'), ('well', 'ADV'), ('and', 'CONJ'), ('bake-oven', 'NOUN'), ('and', 'CONJ'), ('to', 'PRT'), ('one', 'NUM'), ('third', 'VERB'), ('of', 'ADP'), ('the', 'DET'), ('cellar', 'ADJ'), ('(', '.'), ('I', 'PRON'), ('can', 'VERB'), ('show', 'ADJ'), ('you', 'PRON'), ('the', 'DET'), ('cellar', 'ADJ'), ('when', 'ADV'), ('we', 'PRON'), ('go', 'VERB'), ('up', 'PRT'), (')', '.'), (',', '.'), ('also', 'ADV'), ('one', 'NUM'), ('Cow', 'NOUN'), ('Right', 'VERB'), (',', '.'), ('and', 'CONJ'), ('lastly', 'VERB'), ('they', 'PRON'), ('set', 'VERB'), ('off', 'PRT'), ('to', 'PRT'), ('the', 'DET'), ('widow', 'NOUN'), ('her', 'ADJ'), ('own', 'DET'), ('land', 'NOUN'), ('that', 'ADP'), ('she', 'ADJ'), ('brought', 'VERB'), ('with', 'ADP'), ('her', 'ADJ'), ('as', 'ADP'), ('dower', 'NOUN'), (',', '.'), ('namely', 'NOUN'), ('the', 'DET'), ('Beech', 'ADV'), ('Pasture', 'DET'), ('.', '.')]
# [('And', 'CONJ'), ('I', 'PRON'), ('remember', 'NOUN'), ('that', 'ADP'), ('the', 'DET'), ('whole', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('privileges', 'ADJ'), (',', '.'), ('not', 'ADV'), ('counting', 'NOUN'), ('the', 'DET'), ('Beech', 'ADV'), ('Pasture', 'DET'), (',', '.'), ('was', 'VERB'), ('valued', 'ADV'), ('at', 'ADP'), ('twenty', 'NUM'), ('pounds', 'NUM'), ('.', '.')]
# [('I', 'PRON'), ('wish', 'NOUN'), ('you', 'PRON'), ('could', 'VERB'), ('have', 'VERB'), ('seen', 'VERB'), ('the', 'DET'), ('crests', 'NOUN'), ('fall', 'ADP'), ('on', 'ADP'), ('these', 'DET'), ('two', 'NUM'), ('sparring', 'ADJ'), ('coxcombs', 'NOUN'), ('when', 'ADV'), ('I', 'PRON'), ('told', 'VERB'), ('them', 'PRON'), ('that', 'ADP'), ('obviously', 'NOUN'), ('the', 'DET'), ('pasture', 'DET'), ('belonged', 'VERB'), ('to', 'PRT'), ('their', 'DET'), ('wives', 'ADJ'), ('jointly', 'VERB'), ('.', '.')]
# [('That', 'ADP'), ('battle', 'NOUN'), ('scene', 'ADJ'), (',', '.'), ('ridiculous', 'NOUN'), ('as', 'ADP'), ('it', 'PRON'), ('was', 'VERB'), (',', '.'), ('remained', 'ADJ'), ('in', 'ADP'), ('my', 'DET'), ('mind', 'NOUN'), ('.', '.')]
# [('A', 'DET'), ('disturbing', 'NOUN'), ('picture', 'NOUN'), ('of', 'ADP'), ('bad', 'NOUN'), ('blood', 'ADP'), (',', '.'), ('to', 'PRT'), ('be', 'VERB'), ('further', 'ADV'), ('heightened', 'NOUN'), ('with', 'ADP'), ('illicit', 'NOUN'), ('if', 'VERB'), ('buccolic', 'NOUN'), ('colors', 'VERB'), (',', '.'), ('for', 'ADP'), ('on', 'ADP'), ('a', 'DET'), ('subsequent', 'NOUN'), ('day', 'NOUN'), ('I', 'PRON'), ('saw', 'VERB'), ('Handley', 'NUM'), ('escorting', 'PRON'), ('Anta', 'ADJ'), (',', '.'), ("Red's", 'NOUN'), ('wife', 'NOUN'), (',', '.'), ('up', 'PRT'), ('on', 'ADP'), ('Dogtown', '.'), ('Common', 'ADJ'), ('.', '.')]
# [('I', 'PRON'), ('felt', 'VERB'), ('it', 'PRON'), ('would', 'VERB'), ('be', 'VERB'), ('inopportune', 'NOUN'), ('to', 'PRT'), ('disclose', 'NOUN'), ('my', 'DET'), ('presence', 'ADJ'), ('.', '.')]
# [('Not', 'ADV'), ('that', 'ADP'), ('I', 'PRON'), ('intentionally', 'VERB'), ('go', 'VERB'), ('unperceived', 'NOUN'), (',', '.'), ('but', 'CONJ'), ('the', 'DET'), ('boulders', 'ADV'), ('up', 'PRT'), ('there', 'PRT'), ('are', 'VERB'), ('very', 'ADV'), ('high', 'ADP'), ('and', 'CONJ'), ('I', 'PRON'), ('am', 'PRON'), ('a', 'DET'), ('small', 'DET'), ('woman', 'VERB'), ('.', '.')]
# [('One', 'NUM'), ('other', 'ADJ'), ('cause', 'DET'), ('of', 'ADP'), ('jealousy', 'NOUN'), ('between', 'DET'), ('them', 'PRON'), ('I', 'PRON'), ('must', 'VERB'), ('tell', 'NOUN'), ('you', 'PRON'), ('.', '.')]
# [('Paint', 'VERB'), ('!', '.'), ('!', '.')]
# [('Gloomy', 'ADJ'), ('and', 'CONJ'), ('unkempt', 'ADJ'), ('as', 'ADP'), ('Red', 'VERB'), ('McIver', 'ADJ'), ('was', 'VERB'), (',', '.'), ('he', 'PRON'), ('was', 'VERB'), ('much', 'VERB'), ('the', 'DET'), ('better', 'VERB'), ('painter', 'VERB'), ('.', '.')]
# [('I', 'PRON'), ('suppose', 'NOUN'), ('Handley', 'NUM'), ('knew', 'VERB'), ('it', 'PRON'), ('.', '.')]
# [('If', 'VERB'), ('Red', 'VERB'), ('had', 'VERB'), ('a', 'DET'), ('show', 'ADJ'), ('at', 'ADP'), ('Gloucester', 'NOUN'), (',', '.'), ('Handley', 'NUM'), ('would', 'VERB'), ('hurry', 'ADV'), ('to', 'PRT'), ('hang', 'PRT'), ('his', 'DET'), ('pictures', 'NOUN'), ('in', 'ADP'), ('Rockport', 'NOUN'), ('.', '.')]
# [('You', 'PRON'), ('may', 'VERB'), ('say', 'NOUN'), ('this', 'DET'), ('has', 'VERB'), ('little', 'VERB'), ('pertinence', 'NOUN'), (',', '.'), ('but', 'CONJ'), (',', '.'), ('gentlemen', 'ADJ'), (',', '.'), ('remember', 'NOUN'), ('that', 'ADP'), ('all', 'PRT'), ('this', 'DET'), ('prepared', 'VERB'), ('my', 'DET'), ('mind', 'NOUN'), (',', '.'), ('alerted', 'VERB'), ('my', 'DET'), ('intelligence', 'NOUN'), ('.', '.')]
# [('By', 'ADP'), ('such', 'ADJ'), ('touches', 'VERB'), ('the', 'DET'), ('pattern', 'VERB'), ('takes', 'NOUN'), ('shape', 'ADJ'), ('.', '.')]
# [('You', 'PRON'), ('would', 'VERB'), ('call', 'NOUN'), ('these', 'DET'), ('the', 'DET'), ('motives', 'NOUN'), ('of', 'ADP'), ('crime', 'NOUN'), ('.', '.')]
# [('I', 'PRON'), ('would', 'VERB'), ('call', 'NOUN'), ('them', 'PRON'), ('the', 'DET'), ('patterns', 'VERB'), ('of', 'ADP'), ('life', 'NOUN'), (',', '.'), ('perhaps', 'VERB'), ('even', 'VERB'), ('the', 'DET'), ('designs', 'VERB'), ('of', 'ADP'), ('destiny', '.'), ('.', '.')]
# [('Yet', 'ADV'), ('with', 'ADP'), ('all', 'PRT'), ('this', 'DET'), ('knowledge', 'DET'), ('I', 'PRON'), ('had', 'VERB'), ('nothing', 'VERB'), ('of', 'ADP'), ('substance', 'VERB'), ('to', 'PRT'), ('unravel', 'NOUN'), ('our', 'DET'), ('case', 'NOUN'), (',', '.'), ('as', 'ADP'), ('you', 'PRON'), ('would', 'VERB'), ('call', 'NOUN'), ('it', 'PRON'), (',', '.'), ('till', 'NOUN'), ('yesterday', 'NOUN'), ('.', '.')]
# [('One', 'NUM'), ('month', 'NOUN'), ('ago', 'VERB'), (',', '.'), ('on', 'ADP'), ('the', 'DET'), ('20th', 'ADJ'), ('of', 'ADP'), ('October', 'VERB'), (',', '.'), ('was', 'VERB'), ('the', 'DET'), ('opening', 'VERB'), ('of', 'ADP'), ('the', 'DET'), ('gunning', 'VERB'), ('season', 'ADV'), ('in', 'ADP'), ('Massachusetts', 'ADJ'), ('.', '.')]
# [('Not', 'ADV'), ('much', 'VERB'), ('to', 'PRT'), ('shoot', 'PRON'), (',', '.'), ('but', 'CONJ'), ('there', 'PRT'), ('are', 'VERB'), ('a', 'DET'), ('few', 'ADJ'), ('pheasant', 'CONJ'), ('.', '.')]
# [('Rabbits', 'ADV'), (',', '.'), ('too', 'ADV'), (',', '.'), ('if', 'VERB'), ('you', 'PRON'), ('care', 'NOUN'), ('for', 'ADP'), ('them', 'PRON'), (',', '.'), ('which', 'DET'), ('most', 'ADV'), ('of', 'ADP'), ('the', 'DET'), ('folk', 'ADJ'), ('around', 'ADP'), ('here', 'VERB'), ("haven't", 'NOUN'), ('the', 'DET'), ('sense', 'DET'), ('to', 'PRT'), ('appreciate', 'VERB'), ('.', '.')]
# [('Any', 'DET'), ('more', 'ADJ'), ('than', 'ADP'), ('they', 'PRON'), ('have', 'VERB'), ('the', 'DET'), ('sense', 'DET'), ('to', 'PRT'), ('eat', 'ADV'), ('mussels', 'CONJ'), ('.', '.')]
# [('That', 'ADP'), ('was', 'VERB'), ('the', 'DET'), ('day', 'NOUN'), ('Red', 'VERB'), ('was', 'VERB'), ('said', 'VERB'), ('to', 'PRT'), ('have', 'VERB'), ('gone', 'VERB'), ('away', 'VERB'), ('.', '.')]
# [('Oh', '.'), ('yes', '.'), (',', '.'), ("he'd", 'NOUN'), ('talked', 'VERB'), ('about', 'ADP'), ('doing', 'VERB'), ('so', 'ADV'), ('.', '.')]
# [('In', 'ADP'), ('fact', 'NOUN'), (',', '.'), ('he', 'PRON'), ('often', 'ADV'), ('disappeared', 'VERB'), (',', '.'), ('from', 'ADP'), ('time', 'NOUN'), ('to', 'PRT'), ('time', 'NOUN'), (',', '.'), ('--', '.'), ('off', 'PRT'), ('to', 'PRT'), ('paint', 'VERB'), ('the', 'DET'), ('sea', 'ADP'), (',', '.'), ('aboard', 'VERB'), ('a', 'DET'), ('dragger', 'NOUN'), ('out', 'PRT'), ('from', 'ADP'), ('Gloucester', 'NOUN'), ('.', '.')]
# [('Anta', 'ADJ'), (',', '.'), ('his', 'DET'), ('wife', 'NOUN'), (',', '.'), ('never', 'ADV'), ('seemed', 'VERB'), ('to', 'PRT'), ('mind', 'NOUN'), ('.', '.')]
# [('I', 'PRON'), ('suppose', 'NOUN'), ('these', 'DET'), ('absences', 'NOUN'), ('gave', 'VERB'), ('her', 'ADJ'), ('more', 'ADJ'), ('clearance', 'VERB'), ('for', 'ADP'), ('her', 'ADJ'), ('embraces', 'ADJ'), ('with', 'ADP'), ('Cousin', 'NOUN'), ('Handley', 'NUM'), ('.', '.')]
# [('Anyhow', '.'), (',', '.'), ('I', 'PRON'), ("wasn't", 'NOUN'), ('surprised', 'VERB'), (',', '.'), ('early', 'ADV'), ('that', 'ADP'), ('morning', 'NOUN'), (',', '.'), ('to', 'PRT'), ('see', 'NOUN'), ('Handley', 'NUM'), ('himself', 'PRON'), ('crossing', 'VERB'), ('from', 'ADP'), ('Dogtown', '.'), ('Common', 'ADJ'), ('Road', 'NOUN'), ('to', 'PRT'), ('the', 'DET'), ('Back', 'ADV'), ('Road', 'NOUN'), ('.', '.')]
# [('No', 'DET'), (',', '.'), ('he', 'PRON'), ("didn't", 'NOUN'), ('have', 'VERB'), ('his', 'DET'), ('gun', 'NOUN'), (',', '.'), ('which', 'DET'), ('he', 'PRON'), ('should', 'VERB'), ('have', 'VERB'), ('.', '.')]
# [('It', 'PRON'), ('would', 'VERB'), ('have', 'VERB'), ('been', 'VERB'), ('a', 'DET'), ('good', 'ADJ'), ('excuse', 'NOUN'), ('for', 'ADP'), ('his', 'DET'), ('being', 'VERB'), ('there', 'PRT'), ('at', 'ADP'), ('all', 'PRT'), ('.', '.')]
# [('I', 'PRON'), ('myself', 'PRON'), ('had', 'VERB'), ('been', 'VERB'), ('up', 'PRT'), ('there', 'PRT'), ('by', 'ADP'), ('seven', 'NUM'), ("o'clock", 'NOUN'), (',', '.'), ('after', 'ADP'), ('mushrooms', 'ADV'), (',', '.'), ('since', 'ADP'), ("there'd", 'NOUN'), ('been', 'VERB'), ('a', 'DET'), ('week', 'NOUN'), ('of', 'ADP'), ('rain', 'VERB'), ('which', 'DET'), ('had', 'VERB'), ('stopped', 'NOUN'), ('early', 'ADV'), ('that', 'ADP'), ('morning', 'NOUN'), ('and', 'CONJ'), ('the', 'DET'), ('day', 'NOUN'), ('was', 'VERB'), ('as', 'ADP'), ('clear', 'ADV'), ('as', 'ADP'), ('Sandwich', 'VERB'), ('glass', 'VERB'), ('.', '.')]
# [("That's", 'NOUN'), ('what', 'DET'), ('the', 'DET'), ('man', 'NOUN'), ('had', 'VERB'), ('said', 'VERB'), ('.', '.')]
# [('Haney', 'VERB'), ('peered', 'VERB'), ('doubtfully', 'NOUN'), ('at', 'ADP'), ('his', 'DET'), ('drinking', 'ADP'), ('companion', 'NOUN'), ('through', 'ADP'), ('bleary', 'NOUN'), (',', '.'), ('tear-filled', 'NOUN'), ('eyes', 'VERB'), ('.', '.')]
# [('He', 'PRON'), ('had', 'VERB'), ('no', 'DET'), ('ready', 'ADJ'), ('answer', 'NOUN'), (',', '.'), ('as', 'ADP'), ('much', 'VERB'), ('from', 'ADP'), ('surprise', 'ADV'), ('as', 'ADP'), ('from', 'ADP'), ('the', 'DET'), ('fit', 'ADJ'), ('of', 'ADP'), ('coughing', 'ADP'), ('.', '.')]
# [('Was', 'VERB'), ('the', 'DET'), ('man', 'NOUN'), ('drunk', 'ADV'), ('or', 'CONJ'), ('crazy', 'NOUN'), ('or', 'CONJ'), ('both', 'DET'), ('?', '.'), ('?', '.')]
# [('But', 'CONJ'), ('his', 'DET'), ('new-found', 'DET'), ('buddy', 'NOUN'), ('had', 'VERB'), ('matched', 'NOUN'), ('him', 'PRON'), ('drink', 'VERB'), ('for', 'ADP'), ('drink', 'VERB'), ('until', 'CONJ'), ('he', 'PRON'), ('lost', 'CONJ'), ('count', 'VERB'), (',', '.'), ('and', 'CONJ'), ('the', 'DET'), ("man's", 'NOUN'), ('eyes', 'VERB'), ('were', 'VERB'), ('still', 'ADP'), ('clear', 'ADV'), ('.', '.')]
# [('The', 'DET'), ('guy', 'VERB'), ('is', 'VERB'), ('off', 'PRT'), ('his', 'DET'), ('rocker', 'VERB'), (',', '.'), ('Haney', 'VERB'), ('thought', 'VERB'), ('to', 'PRT'), ('himself', 'PRON'), (',', '.'), ('and', 'CONJ'), ('looked', 'VERB'), ('away', 'VERB'), ('from', 'ADP'), ('those', 'ADP'), ('eyes', 'VERB'), ('.', '.')]
# [('Eyes', 'VERB'), ('that', 'ADP'), ('were', 'VERB'), ('clear', 'ADV'), (',', '.'), ('but', 'CONJ'), ('also', 'ADV'), ('bright', 'VERB'), ('with', 'ADP'), ('a', 'DET'), ('strange', 'NOUN'), ('intensity', 'ADP'), (',', '.'), ('a', 'DET'), ('sort', 'NOUN'), ('of', 'ADP'), ('cold', 'NOUN'), ('fire', 'NOUN'), ('burning', 'NOUN'), ('behind', 'VERB'), ('them', 'PRON'), ('.', '.')]
# [('Why', 'NOUN'), ("hadn't", 'NOUN'), ('he', 'PRON'), ('noticed', 'VERB'), ('it', 'PRON'), ('before', 'ADP'), ('?', '.'), ('?', '.')]
# [('No', 'DET'), (',', '.'), ('the', 'DET'), ('man', 'NOUN'), ('was', 'VERB'), ('not', 'ADV'), ('drunk', 'ADV')]
# [('He', 'PRON'), ('wondered', 'VERB'), ('how', 'ADP'), ('he', 'PRON'), ('got', 'VERB'), ('tied', 'NOUN'), ('up', 'PRT'), ('with', 'ADP'), ('this', 'DET'), ('stranger', 'VERB'), ('.', '.')]
# [('But', 'CONJ'), (',', '.'), ('of', 'ADP'), ('course', 'VERB'), (',', '.'), ('he', 'PRON'), ('remembered', 'VERB'), ('now', 'VERB'), ('.', '.')]
# [('It', 'PRON'), ('was', 'VERB'), ('blurred', 'VERB'), (',', '.'), ('after', 'ADP'), ('two', 'NUM'), ('hours', 'NOUN'), ('of', 'ADP'), ('steady', 'ADJ'), ('drinking', 'ADP'), (',', '.'), ('but', 'CONJ'), ('the', 'DET'), ('occasion', 'VERB'), ('of', 'ADP'), ('it', 'PRON'), ('came', 'NOUN'), ('back', 'ADV'), ('to', 'PRT'), ('him', 'PRON'), ('.', '.')]
# [('The', 'DET'), ('stranger', 'VERB'), (',', '.'), ('his', 'DET'), ('head', 'VERB'), ('seemingly', 'NOUN'), ('sunk', 'ADV'), ('in', 'ADP'), ('thought', 'VERB'), (',', '.'), ('started', 'VERB'), ('to', 'PRT'), ('cross', 'VERB'), ('the', 'DET'), ('street', 'NOUN'), ('against', 'ADP'), ('the', 'DET'), ('light', 'VERB'), ('just', 'ADV'), ('as', 'ADP'), ('a', 'DET'), ('huge', 'NOUN'), ('moving', 'ADP'), ('van', 'VERB'), ('roared', 'ADP'), ('through', 'ADP'), ('the', 'DET'), ('intersection', 'NOUN'), ('.', '.')]
# [('Brakes', 'ADV'), ('howled', 'ADP'), ('and', 'CONJ'), ('a', 'DET'), ('horn', 'DET'), ('blared', 'NOUN'), ('furiously', 'ADP'), (',', '.'), ('but', 'CONJ'), ('the', 'DET'), ('man', 'NOUN'), ('would', 'VERB'), ('have', 'VERB'), ('been', 'VERB'), ('hit', 'ADV'), ('if', 'VERB'), ('Phil', 'NOUN'), ("hadn't", 'NOUN'), ('called', 'NOUN'), ('out', 'PRT'), ('to', 'PRT'), ('him', 'PRON'), ('a', 'DET'), ('second', 'ADV'), ('before', 'ADP'), ('.', '.')]
# [('His', 'DET'), ('shout', 'PRT'), ('had', 'VERB'), ('been', 'VERB'), ('involuntary', 'ADJ'), (',', '.'), ('something', 'VERB'), ('anybody', 'VERB'), ('might', 'VERB'), ('have', 'VERB'), ('done', 'VERB'), ('without', 'VERB'), ('thinking', 'ADV'), (',', '.'), ('on', 'ADP'), ('the', 'DET'), ('spur', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('moment', 'NOUN'), ('.', '.')]
# [('As', 'ADP'), ('a', 'DET'), ('matter', 'VERB'), ('of', 'ADP'), ('fact', 'NOUN'), (',', '.'), ('he', 'PRON'), ("wouldn't", 'NOUN'), ('have', 'VERB'), ('cared', 'PRON'), ('at', 'ADP'), ('all', 'PRT'), ('if', 'VERB'), ('the', 'DET'), ('guy', 'VERB'), ('had', 'VERB'), ('been', 'VERB'), ('hit', 'ADV'), ('.', '.')]
# [('Actually', 'VERB'), (',', '.'), ('he', 'PRON'), ('regretted', 'VERB'), ('having', 'VERB'), ('opened', 'VERB'), ('his', 'DET'), ('mouth', 'VERB'), ('when', 'ADV'), ('the', 'DET'), ('truck', 'NOUN'), ('came', 'NOUN'), ('to', 'PRT'), ('a', 'DET'), ('stop', 'NOUN'), ('and', 'CONJ'), ('the', 'DET'), ('angry', 'NOUN'), ('driver', 'NOUN'), ('jumped', 'NOUN'), ('down', 'PRT'), ('from', 'ADP'), ('the', 'DET'), ('cab', 'ADJ'), ('and', 'CONJ'), ('walked', 'VERB'), ('back', 'ADV'), ('toward', 'ADP'), ('them', 'PRON'), ('.', '.')]
# [('By', 'ADP'), ('then', 'ADV'), (',', '.'), ('the', 'DET'), ('stranger', 'VERB'), ('was', 'VERB'), ('thanking', 'PRON'), ('Haney', 'VERB'), ('profusely', 'ADV'), ('and', 'CONJ'), ('had', 'VERB'), ('one', 'NUM'), ('arm', 'DET'), ('around', 'ADP'), ('his', 'DET'), ('shoulders', 'DET'), ('as', 'ADP'), ('if', 'VERB'), ('he', 'PRON'), ('were', 'VERB'), ('an', 'DET'), ('old', 'ADJ'), ('friend', 'NOUN'), ('.', '.')]
# [('So', 'ADV'), ('the', 'DET'), ('driver', 'NOUN'), ('started', 'VERB'), ('to', 'PRT'), ('curse', 'NOUN'), ('at', 'ADP'), ('both', 'DET'), ('of', 'ADP'), ('them', 'PRON'), ('as', 'ADP'), ('if', 'VERB'), ('they', 'PRON'), ('had', 'VERB'), ('been', 'VERB'), ('in', 'ADP'), ('a', 'DET'), ('plot', 'VERB'), ('together', 'ADV'), ('to', 'PRT'), ('ruin', 'NOUN'), ('his', 'DET'), ('safe-driving', 'NOUN'), ('record', 'NOUN'), ('.', '.')]
# [('Then', 'ADV'), ('the', 'DET'), ('man', 'NOUN'), ('he', 'PRON'), ('saved', 'VERB'), ('turned', 'VERB'), ('and', 'CONJ'), ('looked', 'VERB'), ('squarely', 'PRON'), ('into', 'ADP'), ('the', 'DET'), ('truck', 'NOUN'), ("driver's", 'NOUN'), ('face', 'VERB'), (',', '.'), ('without', 'VERB'), ('saying', 'VERB'), ('a', 'DET'), ('word', 'NOUN'), ('.', '.')]
# [('Very', 'ADV'), ('suddenly', 'VERB'), (',', '.'), ('the', 'DET'), ('driver', 'NOUN'), ('stopped', 'NOUN'), ('swearing', 'NOUN'), ('at', 'ADP'), ('them', 'PRON'), (',', '.'), ('turned', 'VERB'), ('on', 'ADP'), ('his', 'DET'), ('heel', 'NOUN'), ('and', 'CONJ'), ('went', 'VERB'), ('back', 'ADV'), ('to', 'PRT'), ('his', 'DET'), ('truck', 'NOUN'), ('.', '.')]
# [('Haney', 'VERB'), ("hadn't", 'NOUN'), ('given', 'VERB'), ('it', 'PRON'), ('much', 'VERB'), ('thought', 'VERB'), ('at', 'ADP'), ('the', 'DET'), ('time', 'NOUN'), ('.', '.')]
# [('Now', 'VERB'), ('he', 'PRON'), ('recalled', 'VERB'), ('it', 'PRON'), ('very', 'ADV'), ('clearly', 'ADV'), (',', '.'), ('and', 'CONJ'), ('wondered', 'VERB'), ('what', 'DET'), ('the', 'DET'), ('truck', 'NOUN'), ('driver', 'NOUN'), ('had', 'VERB'), ('seen', 'VERB'), ('in', 'ADP'), ('those', 'ADP'), ('eyes', 'VERB'), ('to', 'PRT'), ('make', 'VERB'), ('him', 'PRON'), ('back', 'ADV'), ('off', 'PRT'), ('.', '.')]
# [('It', 'PRON'), ('must', 'VERB'), ('have', 'VERB'), ('been', 'VERB'), ('the', 'DET'), ('sort', 'NOUN'), ('of', 'ADP'), ('look', 'ADJ'), ('that', 'ADP'), ('can', 'VERB'), ('call', 'NOUN'), ('a', 'DET'), ('bluff', 'VERB'), ('without', 'VERB'), ('saying', 'VERB'), ('a', 'DET'), ('word', 'NOUN'), ('.', '.')]
# [('When', 'ADV'), ('the', 'DET'), ('light', 'VERB'), ('went', 'VERB'), ('their', 'DET'), ('way', 'ADP'), (',', '.'), ('they', 'PRON'), ('went', 'VERB'), ('on', 'ADP'), ('across', 'ADP'), ('the', 'DET'), ('street', 'NOUN'), ('.', '.')]
# [('And', 'CONJ'), ('when', 'ADV'), ('the', 'DET'), ('stranger', 'VERB'), ('found', 'VERB'), ('out', 'PRT'), ('that', 'ADP'), ('Phil', 'NOUN'), ('was', 'VERB'), ('on', 'ADP'), ('the', 'DET'), ('way', 'ADP'), ('to', 'PRT'), ('one', 'NUM'), ('of', 'ADP'), ('his', 'DET'), ('favorite', 'VERB'), ('bars', 'VERB'), (',', '.'), ('he', 'PRON'), ('insisted', 'VERB'), ('on', 'ADP'), ('offering', 'VERB'), ('to', 'PRT'), ('buy', 'VERB'), ('drinks', 'VERB'), ('for', 'ADP'), ('both', 'DET'), ('of', 'ADP'), ('them', 'PRON'), ('.', '.')]
# [('Phil', 'NOUN'), ('usually', 'ADV'), ('went', 'VERB'), ('alone', 'NOUN'), ('and', 'CONJ'), ('kept', 'VERB'), ('to', 'PRT'), ('himself', 'PRON'), (',', '.'), ('sitting', 'VERB'), ('in', 'ADP'), ('a', 'DET'), ('corner', 'VERB'), ('and', 'CONJ'), ('passing', 'NOUN'), ('the', 'DET'), ('time', 'NOUN'), ('by', 'ADP'), ('nursing', 'NOUN'), ('his', 'DET'), ('favorite', 'VERB'), ('grudges', 'DET'), ('.', '.')]
# [('But', 'CONJ'), ('he', 'PRON'), ('decided', 'VERB'), ('he', 'PRON'), ("wouldn't", 'NOUN'), ('mind', 'NOUN'), ('company', 'VERB'), ('in', 'ADP'), ('return', 'VERB'), ('for', 'ADP'), ('free', 'ADJ'), ('drinks', 'VERB'), (',', '.'), ('even', 'VERB'), ('though', 'ADV'), ('he', 'PRON'), ('made', 'VERB'), ('good', 'ADJ'), ('money', 'NOUN'), ('at', 'ADP'), ('his', 'DET'), ('job', 'NOUN'), ('.', '.')]
# [('Phil', 'NOUN'), ('was', 'VERB'), ('like', 'ADP'), ('that', 'ADP'), ('.', '.')]
# [('Now', 'VERB'), ('he', 'PRON'), ('wondered', 'VERB'), ('if', 'VERB'), ('it', 'PRON'), ('was', 'VERB'), ('worth', 'NOUN'), ('it', 'PRON'), (',', '.'), ('having', 'VERB'), ('a', 'DET'), ('screwball', 'DET'), ('for', 'ADP'), ('company', 'VERB'), ('.', '.')]
# [('He', 'PRON'), ('really', 'NOUN'), ("didn't", 'NOUN'), ('take', 'VERB'), ('the', 'DET'), ('offer', 'VERB'), ('seriously', 'ADV'), (',', '.'), ('but', 'CONJ'), ('he', 'PRON'), ('began', 'ADP'), ('to', 'PRT'), ('feel', 'VERB'), ('uneasy', 'ADJ'), ('.', '.')]
# [('When', 'ADV'), ('he', 'PRON'), ('finally', 'ADV'), ('got', 'VERB'), ('the', 'DET'), ('coughing', 'ADP'), ('under', 'ADP'), ('control', 'NOUN'), (',', '.'), ('he', 'PRON'), ('realized', 'ADV'), ('that', 'ADP'), ('Pete', 'NOUN'), ('(', '.'), ('all', 'PRT'), ('he', 'PRON'), ('gave', 'VERB'), ('was', 'VERB'), ('his', 'DET'), ('first', 'ADJ'), ('name', 'VERB'), (')', '.'), ('was', 'VERB'), ('still', 'ADP'), ('waiting', 'NOUN'), ('for', 'ADP'), ('an', 'DET'), ('answer', 'NOUN'), ('--', '.'), ('he', 'PRON'), ("didn't", 'NOUN'), ('even', 'VERB'), ('seem', 'NOUN'), ('to', 'PRT'), ('wink', 'CONJ'), ('as', 'ADP'), ('he', 'PRON'), ('continued', 'NOUN'), ('to', 'PRT'), ('stare', 'DET'), ('.', '.')]
# [('Haney', 'VERB'), ('managed', 'ADV'), ('a', 'DET'), ('weak', 'ADV'), ('laugh', 'VERB'), ('.', '.')]
# [('``', '.'), ('Guess', 'NOUN'), ('I', 'PRON'), ("can't", 'NOUN'), ('think', 'VERB'), ('of', 'ADP'), ('anyone', 'VERB'), (',', '.'), ('Pete', 'NOUN'), ('.', '.')]
# [('Thanks', 'NOUN'), ('anyhow', '.'), ("''", '.'), ('.', '.')]
# [('A', 'DET'), ('faint', 'ADP'), ('crease', 'PRT'), ('appeared', 'ADJ'), ('between', 'DET'), ('the', 'DET'), ("man's", 'NOUN'), ('eyebrows', 'ADJ'), ('.', '.')]
# [('``', '.'), ('I', 'PRON'), ('think', 'VERB'), ('you', 'PRON'), ("aren't", 'NOUN'), ('taking', 'VERB'), ('me', 'PRON'), ('seriously', 'ADV'), (',', '.'), ('Phil', 'NOUN'), ('.', '.')]
# [('I', 'PRON'), ('meant', 'VERB'), ('it', 'PRON'), ('.', '.')]
# [('And', 'CONJ'), ('everybody', 'VERB'), ('has', 'VERB'), ('some', 'DET'), ('kind', 'NOUN'), ('of', 'ADP'), ('grudge', 'NOUN'), ('.', '.')]
# [('I', 'PRON'), ('might', 'VERB'), ('have', 'VERB'), ('got', 'VERB'), ('hit', 'ADV'), ('by', 'ADP'), ('that', 'ADP'), ('truck', 'NOUN'), ('if', 'VERB'), ('it', 'PRON'), ("wasn't", 'NOUN'), ('for', 'ADP'), ('you', 'PRON'), ('.', '.')]
# [('I', 'PRON'), ('believe', 'VERB'), ('in', 'ADP'), ('returning', 'ADV'), ('favors', 'VERB'), ('.', '.')]
# [("I'll", 'NOUN'), ('do', 'VERB'), ('anything', 'VERB'), ('for', 'ADP'), ('somebody', 'VERB'), ('I', 'PRON'), ('like', 'ADP'), ('.', '.')]
# [('It', 'PRON'), ("won't", 'NOUN'), ('cost', 'NOUN'), ('you', 'PRON'), ('a', 'DET'), ('cent', 'NOUN'), (',', '.'), ('Phil', 'NOUN'), ('.', '.')]
# [('Go', 'VERB'), ('ahead', 'VERB'), ('and', 'CONJ'), ('try', 'VERB'), ('me', 'PRON'), ("''", '.'), ('!', '.'), ('!', '.')]
# [('Phil', 'NOUN'), ('rubbed', 'VERB'), ('his', 'DET'), ('forehead', 'DET'), ('wearily', 'VERB'), ('.', '.')]
# [('He', 'PRON'), ('was', 'VERB'), ('beginning', 'NOUN'), ('to', 'PRT'), ('feel', 'VERB'), ('woolly', 'ADJ'), ('.', '.')]
# [('Maybe', 'VERB'), ('it', 'PRON'), ('would', 'VERB'), ('be', 'VERB'), ('better', 'VERB'), ('to', 'PRT'), ('humor', 'DET'), ('the', 'DET'), ('guy', 'VERB'), ('and', 'CONJ'), ('then', 'ADV'), ('make', 'VERB'), ('an', 'DET'), ('exit', 'NOUN'), ('.', '.')]
# [('He', 'PRON'), ('really', 'NOUN'), ("didn't", 'NOUN'), ('expect', 'NOUN'), ('anything', 'VERB'), ('to', 'PRT'), ('come', 'NOUN'), ('of', 'ADP'), ('it', 'PRON'), (',', '.'), ('and', 'CONJ'), ('there', 'PRT'), ('were', 'VERB'), ('a', 'DET'), ('few', 'ADJ'), ('people', 'ADP')]
# [('``', '.'), ('All', 'PRT'), ('right', 'VERB'), ("''", '.'), (',', '.'), ('he', 'PRON'), ('conceded', 'ADV'), ('finally', 'ADV'), (',', '.'), ('``', '.'), ('if', 'VERB'), ('you', 'PRON'), ('must', 'VERB'), ('know', 'PRON'), (',', '.'), ('I', 'PRON'), ("don't", 'NOUN'), ('get', 'NOUN'), ('along', 'VERB'), ('with', 'ADP'), ('the', 'DET'), ('landlord', 'NOUN'), ('.', '.')]
# [('He', 'PRON'), ('keeps', 'NOUN'), ('riding', 'NOUN'), ('me', 'PRON'), ('because', 'NOUN'), ('I', 'PRON'), ('like', 'ADP'), ('to', 'PRT'), ('listen', 'PRON'), ('to', 'PRT'), ('the', 'DET'), ('radio', 'ADJ'), ('and', 'CONJ'), ('sing', 'PRT'), ('while', 'ADP'), ("I'm", 'NOUN'), ('taking', 'VERB'), ('a', 'DET'), ('bath', 'VERB'), ('.', '.')]
# [('He', 'PRON'), ('says', 'VERB'), ('the', 'DET'), ('neighbors', 'NOUN'), ('complain', 'NOUN'), (',', '.'), ('but', 'CONJ'), ('I', 'PRON'), ("don't", 'NOUN'), ('believe', 'VERB'), ('it', 'PRON'), ('.', '.')]
# [('Why', 'NOUN'), ("don't", 'NOUN'), ('they', 'PRON'), ('tell', 'NOUN'), ('me', 'PRON'), ('themselves', 'PRON'), ('if', 'VERB'), ('it', 'PRON'), ('bothers', 'PRON'), ('them', 'PRON'), ("''", '.'), ('?', '.'), ('?', '.')]
# [('The', 'DET'), ('man', 'NOUN'), ('closed', 'NOUN'), ('his', 'DET'), ('eyes', 'VERB'), ('and', 'CONJ'), ('nodded', 'ADV'), ('.', '.')]
# [('When', 'ADV'), ('he', 'PRON'), ('looked', 'VERB'), ('up', 'PRT'), ('again', 'ADV'), (',', '.'), ('he', 'PRON'), ('seemed', 'VERB'), ('almost', 'VERB'), ('contented', 'ADJ'), ('.', '.')]
# [('``', '.'), ('Fine', 'VERB'), ('.', '.')]
# [('Give', 'VERB'), ('me', 'PRON'), ('your', 'NOUN'), ('address', 'NOUN'), ('.', '.')]
# [('It', 'PRON'), ('will', 'VERB'), ('take', 'VERB'), ('a', 'DET'), ('little', 'VERB'), ('time', 'NOUN'), ('.', '.')]
# [('I', 'PRON'), ('want', 'VERB'), ('to', 'PRT'), ('study', 'VERB'), ('your', 'NOUN'), ("landlord's", 'NOUN'), ('habits', 'VERB'), ('and', 'CONJ'), ('movements', 'DET'), ('first', 'ADJ'), ('.', '.')]
# [('You', 'PRON'), ('see', 'NOUN'), (',', '.'), ('I', 'PRON'), ('always', 'VERB'), ('make', 'VERB'), ('it', 'PRON'), ('look', 'ADJ'), ('like', 'ADP'), ('an', 'DET'), ('accident', 'NOUN'), ('.', '.')]
# [('Maybe', 'VERB'), ('suicide', 'ADP'), (',', '.'), ('if', 'VERB'), ('it', 'PRON'), ('looks', 'ADJ'), ('reasonable', 'ADJ'), ('.', '.')]
# [('In', 'ADP'), ('that', 'ADP'), ('way', 'ADP'), ("there's", 'NOUN'), ('no', 'DET'), ('trouble', 'NOUN'), ('for', 'ADP'), ('the', 'DET'), ('customer', 'NOUN'), ("''", '.'), ('.', '.')]
# [("Haney's", 'NOUN'), ('eyebrows', 'ADJ'), ('flew', 'VERB'), ('up', 'PRT'), ('.', '.')]
# [('``', '.'), ('Customer', 'NOUN'), ("''", '.'), ('?', '.'), ('?', '.')]
# [('Pete', 'NOUN'), ('smiled', 'ADV'), ('modestly', 'ADV'), ('.', '.')]
# [('``', '.'), ("It's", 'NOUN'), ('my', 'DET'), ('line', 'VERB'), ('of', 'ADP'), ('work', 'VERB'), ("''", '.'), (',', '.'), ('he', 'PRON'), ('said', 'VERB')]
# [('Five', 'NUM'), ('minutes', 'ADV'), ('later', 'ADV'), (',', '.'), ('before', 'ADP'), ('Haney', 'VERB'), ('could', 'VERB'), ('make', 'VERB'), ('his', 'DET'), ('break', 'VERB'), (',', '.'), ('the', 'DET'), ('stranger', 'VERB'), ('stood', 'VERB'), ('up', 'PRT'), ('and', 'CONJ'), ('nodded', 'ADV'), ('farewell', 'ADJ'), ('.', '.')]
# [('Haney', 'VERB'), ('watched', 'NOUN'), ('the', 'DET'), ('small', 'DET'), ('but', 'CONJ'), ('wiry', 'ADJ'), ('man', 'NOUN'), ('slip', 'ADV'), ('out', 'PRT'), ('the', 'DET'), ('door', 'NOUN'), ('quickly', 'ADV'), ('and', 'CONJ'), ('silently', 'ADP'), (',', '.'), ('and', 'CONJ'), ('felt', 'VERB'), ('relieved', 'NOUN'), ('to', 'PRT'), ('see', 'NOUN'), ('that', 'ADP'), ('nobody', 'NOUN'), ('else', 'VERB'), ('seemed', 'VERB'), ('to', 'PRT'), ('notice', 'NOUN'), ('his', 'DET'), ('departure', 'NOUN'), ('.', '.')]
# [('Phil', 'NOUN'), ('decided', 'VERB'), ('to', 'PRT'), ('stay', 'NOUN'), ('a', 'DET'), ('little', 'VERB'), ('longer', 'VERB'), (',', '.'), ('and', 'CONJ'), ('as', 'ADP'), ('time', 'NOUN'), ('passed', 'VERB'), ('it', 'PRON'), ('seemed', 'VERB'), ('as', 'ADP'), ('if', 'VERB'), ('the', 'DET'), ('strange', 'NOUN'), ('little', 'VERB'), ('man', 'NOUN'), ('had', 'VERB'), ('never', 'ADV'), ('been', 'VERB'), ('there', 'PRT'), (',', '.'), ('but', 'CONJ'), ('for', 'ADP'), ('the', 'DET'), ('other', 'ADJ'), ('glass', 'VERB'), ('on', 'ADP'), ('the', 'DET'), ('table', 'ADJ'), ('.', '.')]
# [('Some', 'DET'), ('time', 'NOUN'), ('before', 'ADP'), ('midnight', 'NOUN'), ('he', 'PRON'), ('returned', 'VERB'), ('to', 'PRT'), ('his', 'DET'), ('apartment', 'NOUN'), ('and', 'CONJ'), ('hit', 'ADV'), ('the', 'DET'), ('sack', 'NOUN'), (',', '.'), ('putting', 'VERB'), ('the', 'DET'), ('whole', 'NOUN'), ('incident', 'NOUN'), ('out', 'PRT'), ('of', 'ADP'), ('mind', 'NOUN'), ('before', 'ADP'), ('he', 'PRON'), ('fell', 'ADP'), ('asleep', 'ADV'), ('.', '.')]
# [('The', 'DET'), ('next', 'ADJ'), ('day', 'NOUN'), (',', '.'), ('Sunday', 'NOUN'), (',', '.'), ('the', 'DET'), ('hangover', 'ADJ'), ('reminded', 'VERB'), ('Haney', 'VERB'), ('where', 'ADV'), ('he', 'PRON'), ('had', 'VERB'), ('been', 'VERB'), ('the', 'DET'), ('night', 'NOUN'), ('before', 'ADP'), ('.', '.')]
# [('The', 'DET'), ('hangover', 'ADJ'), ('in', 'ADP'), ('turn', 'ADV'), ('reminded', 'VERB'), ('him', 'PRON'), ('of', 'ADP'), ('his', 'DET'), ('conversation', 'VERB'), ('with', 'ADP'), ('the', 'DET'), ('weirdy', 'NOUN'), (',', '.'), ('and', 'CONJ'), ('he', 'PRON'), ('groaned', '.'), ('.', '.')]
# [('He', 'PRON'), ('went', 'VERB'), ('for', 'ADP'), ('more', 'ADJ'), ('aspirin', 'VERB'), ('later', 'ADV'), ('in', 'ADP'), ('the', 'DET'), ('day', 'NOUN'), (',', '.'), ('and', 'CONJ'), ('passed', 'VERB'), ('the', 'DET'), ('surly', 'ADJ'), ('landlord', 'NOUN'), ('on', 'ADP'), ('the', 'DET'), ('way', 'ADP'), ('--', '.'), ('he', 'PRON'), ('was', 'VERB'), ('still', 'ADP'), ('alive', 'VERB'), ('and', 'CONJ'), ('scowling', 'NOUN'), ('as', 'ADP'), ('usual', 'ADJ'), (',', '.'), ('as', 'ADP'), ('if', 'VERB'), ('tenants', 'ADJ'), ('were', 'VERB'), ('a', 'DET'), ('burden', 'NOUN'), ('in', 'ADP'), ('his', 'DET'), ('life', 'NOUN'), ('.', '.')]
# [('Phil', 'NOUN'), ('shrugged', 'ADV'), ('and', 'CONJ'), ('ignored', 'VERB'), ('him', 'PRON'), ('.', '.')]
# [('He', 'PRON'), ('went', 'VERB'), ('back', 'ADV'), ('to', 'PRT'), ('work', 'VERB'), ('Monday', 'NOUN'), ('.', '.')]
# [('By', 'ADP'), ('Wednesday', 'NOUN'), ('the', 'DET'), ('landlord', 'NOUN'), ('was', 'VERB'), ('still', 'ADP'), ('alive', 'VERB'), ('.', '.')]
# [('Of', 'ADP'), ('course', 'VERB'), ('On', 'ADP'), ('Thursday', 'NOUN'), (',', '.'), ('Haney', 'VERB'), ('mailed', 'NOUN'), ('the', 'DET'), ('monthly', 'NOUN'), ('check', 'VERB'), ('for', 'ADP'), ('separate', 'NOUN'), ('maintenance', 'NOUN'), ('to', 'PRT'), ('his', 'DET'), ('wife', 'NOUN'), ('Lolly', 'ADV'), (',', '.'), ('and', 'CONJ'), ('wished', 'VERB'), ('the', 'DET'), ('stranger', 'VERB'), ('could', 'VERB'), ('do', 'VERB'), ('something', 'VERB'), ('about', 'ADP'), ('her', 'ADJ')]
# [('Coming', 'NOUN'), ('home', 'NOUN'), ('from', 'ADP'), ('work', 'VERB'), (',', '.'), ('he', 'PRON'), ('was', 'VERB'), ('startled', 'NOUN'), ('to', 'PRT'), ('see', 'NOUN'), ('a', 'DET'), ('police', 'NOUN'), ('car', 'NOUN'), ('parked', 'ADV'), ('in', 'ADP'), ('front', 'DET'), ('of', 'ADP'), ('the', 'DET'), ('apartment', 'NOUN'), ('building', 'NOUN'), ('.', '.')]
# [('Inside', 'VERB'), ('the', 'DET'), ('lobby', 'NOUN'), (',', '.'), ('people', 'ADP'), ('were', 'VERB'), ('standing', 'ADJ'), ('around', 'ADP'), (',', '.'), ('talking', 'ADP'), ('excitedly', 'ADP'), ('.', '.')]
# [('His', 'DET'), ('spine', 'ADV'), ('crawled', 'PRON'), ('with', 'ADP'), ('a', 'DET'), ('foreboding', 'ADJ'), ('premonition', 'VERB'), ('as', 'ADP'), ('he', 'PRON'), ('asked', 'VERB'), ('one', 'NUM'), ('of', 'ADP'), ('his', 'DET'), ('fellow', 'VERB'), ('tenants', 'ADJ'), ('what', 'DET'), ('had', 'VERB'), ('happened', 'NOUN'), ('.', '.')]
# [('The', 'DET'), ('landlord', 'NOUN'), ('had', 'VERB'), ('died', 'NOUN'), ('.', '.')]
# [('Late', 'ADV'), ('that', 'ADP'), ('afternoon', 'NOUN'), (',', '.'), ('it', 'PRON'), ('seemed', 'VERB'), (',', '.'), ('he', 'PRON'), ('had', 'VERB'), ('fallen', 'ADP'), ('off', 'PRT'), ('the', 'DET'), ('roof', 'DET'), ('while', 'ADP'), ('on', 'ADP'), ('some', 'DET'), ('obscure', 'NOUN'), ('errand', 'NOUN'), ('or', 'CONJ'), ('inspection', 'NOUN'), ('.', '.')]
# [('He', 'PRON'), ('had', 'VERB'), ('apparently', 'ADV'), ('been', 'VERB'), ('alone', 'NOUN'), ('.', '.')]
# [('Nobody', 'NOUN'), ('witnessed', 'VERB'), ('the', 'DET'), ('fall', 'ADP'), ('--', '.'), ('just', 'ADV'), ('the', 'DET'), ('sickening', 'NUM'), ('impact', 'NOUN'), ('when', 'ADV'), ('his', 'DET'), ('body', 'ADJ'), ('smashed', 'ADV'), ('on', 'ADP'), ('the', 'DET'), ('pavement', 'ADV'), ('just', 'ADV'), ('outside', 'NOUN'), ('the', 'DET'), ('basement', 'DET'), ('delivery', 'CONJ'), ('entrance', 'NOUN'), ('.', '.')]
# [('Haney', 'VERB'), ('hoped', 'VERB'), ('that', 'ADP'), ('nobody', 'NOUN'), ('noticed', 'VERB'), ('his', 'DET'), ('sudden', 'NOUN'), ('pallor', 'ADJ'), (',', '.'), ('as', 'ADP'), ('he', 'PRON'), ('felt', 'VERB'), ('the', 'DET'), ('blood', 'ADP'), ('drain', 'ADV'), ('from', 'ADP'), ('his', 'DET'), ('cheeks', 'DET'), ('.', '.')]
# [('He', 'PRON'), ('muttered', '.'), ('something', 'VERB'), ('about', 'ADP'), ('how', 'ADP'), ('terrible', 'DET'), ('it', 'PRON'), ('was', 'VERB'), (',', '.'), ('and', 'CONJ'), ('walked', 'VERB'), ('with', 'ADP'), ('deliberate', 'NOUN'), ('slowness', 'ADJ'), ('to', 'PRT'), ('the', 'DET'), ('elevator', 'ADJ'), ('.', '.')]
# [('Once', 'VERB'), ('inside', 'VERB'), ('his', 'DET'), ('apartment', 'NOUN'), (',', '.'), ('he', 'PRON'), ('poured', 'ADV'), ('a', 'DET'), ('drink', 'VERB'), ('with', 'ADP'), ('trembling', 'VERB'), ('hands', 'VERB'), ('and', 'CONJ'), ('flopped', 'DET'), ('limply', 'ADP'), ('in', 'ADP'), ('a', 'DET'), ('chair', 'VERB'), ('.', '.')]
# [('After', 'ADP'), ('a', 'DET'), ('while', 'ADP'), ('he', 'PRON'), ('began', 'ADP'), ('to', 'PRT'), ('feel', 'VERB'), ('better', 'VERB'), ('about', 'ADP'), ('it', 'PRON'), (',', '.'), ('especially', 'NOUN'), ('when', 'ADV'), ('no', 'DET'), ('one', 'NUM'), ('bothered', 'ADV'), ('to', 'PRT'), ('ask', 'VERB'), ('any', 'DET'), ('questions', 'NOUN'), ('.', '.')]
# [('But', 'CONJ'), ('after', 'ADP'), ('all', 'PRT'), (',', '.'), ('why', 'NOUN'), ('should', 'VERB'), ('they', 'PRON'), ('?', '.'), ('?', '.')]
# [('Still', 'ADP'), ('later', 'ADV'), (',', '.'), ('he', 'PRON'), ('finally', 'ADV'), ('convinced', 'VERB'), ('himself', 'PRON'), ('that', 'ADP'), ('it', 'PRON'), ('was', 'VERB'), ('an', 'DET'), ('accident', 'NOUN'), ('--', '.'), ('just', 'ADV'), ('a', 'DET'), ('coincidence', 'NOUN'), ('.', '.')]
# [('The', 'DET'), ('stranger', 'VERB'), ('really', 'NOUN'), ('had', 'VERB'), ('nothing', 'VERB'), ('to', 'PRT'), ('do', 'VERB'), ('with', 'ADP'), ('it', 'PRON'), (',', '.'), ('of', 'ADP'), ('course', 'VERB')]
# [('Haney', 'VERB'), ('went', 'VERB'), ('to', 'PRT'), ('bed', 'ADJ'), (',', '.'), ('happy', 'NOUN'), ('that', 'ADP'), ('at', 'ADP'), ('least', 'NUM'), ('he', 'PRON'), ('was', 'VERB'), ('rid', 'NOUN'), ('of', 'ADP'), ('that', 'ADP'), ('lousy', 'NOUN'), ('landlord', 'NOUN'), ('.', '.')]
# [('After', 'ADP'), ('all', 'PRT'), (',', '.'), ('the', 'DET'), ('man', 'NOUN'), ('had', 'VERB'), ('no', 'DET'), ('family', 'NOUN'), (',', '.'), ('so', 'ADV'), ('no', 'DET'), ('one', 'NUM'), ('suffered', 'ADV'), (',', '.'), ('and', 'CONJ'), ('everybody', 'VERB'), ('was', 'VERB'), ('better', 'VERB'), ('off', 'PRT'), ('for', 'ADP'), ('it', 'PRON'), ('.', '.')]
# [('Really', 'NOUN'), (',', '.'), ('he', 'PRON'), ('said', 'VERB'), ('to', 'PRT'), ('himself', 'PRON'), (',', '.'), ('nobody', 'NOUN'), ('kills', 'NOUN'), ('a', 'DET'), ('man', 'NOUN'), ('just', 'ADV'), ('as', 'ADP'), ('a', 'DET'), ('favor', 'VERB'), ('!', '.'), ('!', '.')]
# [('So', 'ADV'), ('you', 'PRON'), ('thought', 'VERB'), ('I', 'PRON'), ("didn't", 'NOUN'), ('mean', 'NOUN'), ('what', 'DET'), ('I', 'PRON'), ('said', 'VERB'), ('.', '.')]
# [('The', 'DET'), ("stranger's", 'NOUN'), ('eyes', 'VERB'), ('were', 'VERB'), ('large', 'ADJ'), ('and', 'CONJ'), ('sad', 'NOUN'), (',', '.'), ('as', 'ADP'), ('if', 'VERB'), ('Phil', 'NOUN'), ('Haney', 'VERB'), ('had', 'VERB'), ('hurt', 'NOUN'), ('his', 'DET'), ('feelings', 'NOUN'), ('.', '.')]
# [('It', 'PRON'), ('was', 'VERB'), ('like', 'ADP'), ('a', 'DET'), ('recurrent', 'ADV'), (',', '.'), ('annoying', 'NOUN'), ('dream', 'NOUN'), (',', '.'), ('but', 'CONJ'), ('now', 'VERB'), ('the', 'DET'), ('dream', 'NOUN'), ('was', 'VERB'), ('beginning', 'NOUN'), ('to', 'PRT'), ('take', 'VERB'), ('on', 'ADP'), ('overtones', 'ADJ'), ('of', 'ADP'), ('a', 'DET'), ('nightmare', 'NOUN'), ('.', '.')]
# [('However', 'ADV'), (',', '.'), ('Haney', 'VERB'), ('knew', 'VERB'), ('it', 'PRON'), ('was', 'VERB'), ('not', 'ADV'), ('a', 'DET'), ('dream', 'NOUN'), ('.', '.')]
# [('He', 'PRON'), ('might', 'VERB'), ('be', 'VERB'), ('very', 'ADV'), ('tight', 'NOUN'), (',', '.'), ('but', 'CONJ'), ('he', 'PRON'), ('knew', 'VERB'), ('where', 'ADV'), ('he', 'PRON'), ('was', 'VERB'), ('.', '.')]
# [('It', 'PRON'), ('was', 'VERB'), ('the', 'DET'), ('same', 'DET'), ('bar', 'NOUN'), (',', '.'), ('and', 'CONJ'), ('it', 'PRON'), ('was', 'VERB'), ('two', 'NUM'), ('weeks', 'NOUN'), ('later', 'ADV'), ('--', '.'), ('Saturday', 'NOUN'), ('night', 'NOUN'), (',', '.'), ('when', 'ADV'), ('he', 'PRON'), ('had', 'VERB'), ('an', 'DET'), ('excuse', 'NOUN'), ('to', 'PRT'), ('drink', 'VERB'), ('heavier', 'ADJ'), ('than', 'ADP'), ('usual', 'ADJ'), ('.', '.')]
# [('He', 'PRON'), ('had', 'VERB'), ('been', 'VERB'), ('sitting', 'VERB'), ('in', 'ADP'), ('the', 'DET'), ('usual', 'ADJ'), ('corner', 'VERB'), ('at', 'ADP'), ('the', 'DET'), ('little', 'VERB'), ('table', 'ADJ'), (',', '.'), ('as', 'ADP'), ('far', 'ADV'), ('as', 'ADP'), ('possible', 'ADJ'), ('from', 'ADP'), ('any', 'DET'), ('talkative', 'ADV'), (',', '.'), ('friendly', 'ADJ'), ('lushes', 'NOUN'), ('.', '.')]
# [('He', 'PRON'), ('was', 'VERB'), ('enjoying', 'ADJ'), ('the', 'DET'), ('weekly', 'NOUN'), ('ritual', 'VERB'), ('of', 'ADP'), ('washing', 'VERB'), ('down', 'PRT'), ('his', 'DET'), ('pet', 'NOUN'), ('grievance', 'DET'), ('with', 'ADP'), ('bourbon', 'VERB'), ('slightly', 'ADV'), ('moistened', 'VERB'), ('with', 'ADP'), ('water', 'VERB'), ('.', '.')]
# [('This', 'DET'), ('favorite', 'VERB'), ('grievance', 'DET'), ('was', 'VERB'), ('not', 'ADV'), ('the', 'DET'), ('landlord', 'NOUN'), ('.', '.')]
# [('He', 'PRON'), ('had', 'VERB'), ('already', 'VERB'), ('quite', 'ADV'), ('forgotten', 'VERB'), ('about', 'ADP'), ('him', 'PRON'), ('.', '.')]
# ...
# [('It', 'PRON'), ('was', 'VERB'), ('day', 'NOUN'), (',', '.'), ('but', 'CONJ'), ('in', 'ADP'), ('the', 'DET'), ('thin', 'VERB'), ('atmosphere', 'ADJ'), ('contrasts', 'ADJ'), ('were', 'VERB'), ('sharp', 'NOUN'), ('between', 'DET'), ('light', 'VERB'), ('and', 'CONJ'), ('shadow', 'NOUN'), ('.', '.')]
# [('They', 'PRON'), ('walked', 'VERB'), ('from', 'ADP'), ('midnight', 'NOUN'), ('to', 'PRT'), ('noon', 'NOUN'), (',', '.'), ('noon', 'NOUN'), ('to', 'PRT'), ('midnight', 'NOUN'), (',', '.'), ('and', 'CONJ'), ('came', 'NOUN'), ('to', 'PRT'), ('the', 'DET'), ('beast', 'VERB'), ('sprawled', 'PRT'), ('on', 'ADP'), ('its', 'DET'), ('side', 'DET'), ('.', '.')]
# [('Ekstrohm', 'NOUN'), ('nudged', 'ADV'), ('it', 'PRON'), ('with', 'ADP'), ('a', 'DET'), ('boot', 'NOUN'), ('.', '.')]
# [('``', '.'), ('Hey', 'NOUN'), (',', '.'), ('this', 'DET'), ('is', 'VERB'), ('pretty', 'NOUN'), ('close', 'NOUN'), ('to', 'PRT'), ('a', 'DET'), ('wart-hog', 'NOUN'), ("''", '.'), ('.', '.')]
# [('``', '.'), ('Uh-huh', 'NOUN'), ("''", '.'), (',', '.'), ('Ryan', 'VERB'), ('admitted', 'VERB'), ('.', '.')]
# [('``', '.'), ('One', 'NUM'), ('of', 'ADP'), ('the', 'DET'), ('best', 'ADJ'), ('matches', 'ADJ'), ("I've", 'NOUN'), ('ever', 'ADV'), ('found', 'VERB'), ('.', '.')]
# [('Well', 'ADV'), (',', '.'), ('it', 'PRON'), ('has', 'VERB'), ('to', 'PRT'), ('happen', 'VERB'), ('.', '.')]
# [('Statistical', 'NOUN'), ('average', 'NOUN'), ('and', 'CONJ'), ('all', 'PRT'), ('.', '.')]
# [('Still', 'ADP'), (',', '.'), ('it', 'PRON'), ('sometimes', 'VERB'), ('gives', 'VERB'), ('you', 'PRON'), ('a', 'DET'), ('creepy', 'NOUN'), ('feeling', 'NOUN'), ('to', 'PRT'), ('find', 'NOUN'), ('a', 'DET'), ('rabbit', 'NOUN'), ('or', 'CONJ'), ('a', 'DET'), ('snapping', 'NOUN'), ('turtle', '.'), ('on', 'ADP'), ('some', 'DET'), ('strange', 'NOUN'), ('world', 'ADP'), ('.', '.')]
# [('It', 'PRON'), ('makes', 'VERB'), ('you', 'PRON'), ('wonder', 'VERB'), ('if', 'VERB'), ('this', 'DET'), ('exploration', 'VERB'), ('business', 'NOUN'), ("isn't", 'NOUN'), ('all', 'PRT'), ('some', 'DET'), ('big', 'NOUN'), ('joke', 'ADV'), (',', '.'), ('and', 'CONJ'), ('somebody', 'VERB'), ('has', 'VERB'), ('been', 'VERB'), ('everywhere', 'VERB'), ('before', 'ADP'), ('you', 'PRON'), ('even', 'VERB'), ('started', 'VERB'), ("''", '.'), ('.', '.')]
# [('The', 'DET'), ('surveyor', 'NOUN'), ('looked', 'VERB'), ('sidewise', 'VERB'), ('at', 'ADP'), ('the', 'DET'), ('captain', 'VERB'), ('.', '.')]
# [('The', 'DET'), ('big', 'NOUN'), ('man', 'NOUN'), ('seldom', 'ADV'), ('gave', 'VERB'), ('out', 'PRT'), ('with', 'ADP'), ('such', 'ADJ'), ('thoughts', 'NOUN'), ('.', '.')]
# [('Ekstrohm', 'NOUN'), ('cleared', 'VERB'), ('his', 'DET'), ('throat', 'VERB'), ('.', '.')]
# [('``', '.'), ('What', 'DET'), ('shall', 'NOUN'), ('we', 'PRON'), ('do', 'VERB'), ('with', 'ADP'), ('this', 'DET'), ('one', 'NUM'), ('?', '.'), ('?', '.')]
# [('Dissect', 'DET'), ('it', 'PRON'), ("''", '.'), ('?', '.'), ('?', '.')]
# [('Ryan', 'VERB'), ('nudged', 'ADV'), ('it', 'PRON'), ('with', 'ADP'), ('his', 'DET'), ('toe', 'NOUN'), (',', '.'), ('following', 'NOUN'), ("Ekstrohm's", 'NOUN'), ('example', 'ADJ'), ('.', '.')]
# [('``', '.'), ('I', 'PRON'), ("don't", 'NOUN'), ('know', 'PRON'), (',', '.'), ('Stormy', 'ADJ'), ('.', '.')]
# [('It', 'PRON'), ('sure', 'VERB'), ('as', 'ADP'), ('hell', 'NOUN'), ("doesn't", 'NOUN'), ('look', 'ADJ'), ('like', 'ADP'), ('any', 'DET'), ('dominant', 'ADJ'), ('intelligent', 'NOUN'), ('species', 'DET'), ('to', 'PRT'), ('me', 'PRON'), ('.', '.')]
# [('No', 'DET'), ('hands', 'VERB'), (',', '.'), ('for', 'ADP'), ('one', 'NUM'), ('thing', 'NOUN'), ('.', '.')]
# [('Of', 'ADP'), ('course', 'VERB'), (',', '.'), ("that's", 'NOUN'), ('not', 'ADV'), ('definite', 'VERB'), ('proof', 'NOUN'), ("''", '.'), ('.', '.')]
# [('``', '.'), ('No', 'DET'), (',', '.'), ('it', 'PRON'), ("isn't", 'NOUN'), ("''", '.'), (',', '.'), ('Ekstrohm', 'NOUN'), ('said', 'VERB'), ('.', '.')]
# [('``', '.'), ('I', 'PRON'), ('think', 'VERB'), ("we'd", 'NOUN'), ('better', 'VERB'), ('let', 'VERB'), ('it', 'PRON'), ('lay', 'VERB'), ('until', 'CONJ'), ('we', 'PRON'), ('get', 'NOUN'), ('a', 'DET'), ('clearer', 'VERB'), ('picture', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('ecological', 'NOUN'), ('setup', 'VERB'), ('around', 'ADP'), ('here', 'VERB'), ('.', '.')]
# [('In', 'ADP'), ('the', 'DET'), ('meantime', 'VERB'), (',', '.'), ('we', 'PRON'), ('might', 'VERB'), ('be', 'VERB'), ('thinking', 'ADV'), ('on', 'ADP'), ('the', 'DET'), ('problem', 'NOUN'), ('all', 'PRT'), ('these', 'DET'), ('dead', 'NOUN'), ('beasts', 'PRON'), ('represent', 'VERB'), ('.', '.')]
# [('What', 'DET'), ('killed', 'NOUN'), ('them', 'PRON'), ("''", '.'), ('?', '.'), ('?', '.')]
# [('``', '.'), ('It', 'PRON'), ('looks', 'ADJ'), ('like', 'ADP'), ('we', 'PRON'), ('did', 'VERB'), (',', '.'), ('when', 'ADV'), ('we', 'PRON'), ('made', 'VERB'), ('blastdown', 'NOUN'), ("''", '.'), ('.', '.')]
# [('``', '.'), ('But', 'CONJ'), ('what', 'DET'), ('about', 'ADP'), ('our', 'DET'), ('landing', 'ADJ'), ('was', 'VERB'), ('lethal', 'ADP'), ('to', 'PRT'), ('the', 'DET'), ('creatures', 'DET'), ("''", '.'), ('?', '.'), ('?', '.')]
# [('``', '.'), ('Radiation', 'ADP'), ("''", '.'), ('?', '.'), ('?', '.')]
# [('Ekstrohm', 'NOUN'), ('suggested', 'VERB'), ('.', '.')]
# [('``', '.'), ('The', 'DET'), ('planet', 'ADP'), ('is', 'VERB'), ('very', 'ADV'), ('low', 'ADP'), ('in', 'ADP'), ('radiation', 'ADP'), ('from', 'ADP'), ('mineral', 'VERB'), ('deposits', 'VERB'), (',', '.'), ('and', 'CONJ'), ('the', 'DET'), ('atmosphere', 'ADJ'), ('seems', 'VERB'), ('to', 'PRT'), ('shield', 'VERB'), ('out', 'PRT'), ('most', 'ADV'), ('of', 'ADP'), ('the', 'DET'), ('solar', 'VERB'), ('output', 'ADV'), ('.', '.')]
# [('Any', 'DET'), ('little', 'VERB'), ('dose', 'ADJ'), ('of', 'ADP'), ('radiation', 'ADP'), ('might', 'VERB'), ('knock', 'ADV'), ('off', 'PRT'), ('these', 'DET'), ('critters', 'NOUN'), ("''", '.'), ('.', '.')]
# [('``', '.'), ('I', 'PRON'), ("don't", 'NOUN'), ('know', 'PRON'), ('about', 'ADP'), ('that', 'ADP'), ('.', '.')]
# [('Maybe', 'VERB'), ('it', 'PRON'), ('would', 'VERB'), ('work', 'VERB'), ('the', 'DET'), ('other', 'ADJ'), ('way', 'ADP'), ('.', '.')]
# [('Maybe', 'VERB'), ('because', 'NOUN'), ('they', 'PRON'), ('have', 'VERB'), ('had', 'VERB'), ('virtually', 'VERB'), ('no', 'DET'), ('radioactive', 'ADP'), ('exposure', 'ADP'), ('and', 'CONJ'), ("don't", 'NOUN'), ('have', 'VERB'), ('any', 'DET'), ("R's", 'NOUN'), ('stored', 'ADJ'), ('up', 'PRT'), (',', '.'), ('they', 'PRON'), ('could', 'VERB'), ('take', 'VERB'), ('a', 'DET'), ('lot', 'NOUN'), ('without', 'VERB'), ('harm', 'NOUN'), ("''", '.'), ('.', '.')]
# [('``', '.'), ('Then', 'ADV'), ('maybe', 'VERB'), ('it', 'PRON'), ('was', 'VERB'), ('the', 'DET'), ('shockwave', 'ADP'), ('we', 'PRON'), ('set', 'VERB'), ('up', 'PRT'), ('.', '.')]
# [('Or', 'CONJ'), ('maybe', 'VERB'), ("it's", 'NOUN'), ('sheer', 'PRT'), ('xenophobia', 'ADV'), ('.', '.')]
# [('They', 'PRON'), ('curl', 'PRT'), ('up', 'PRT'), ('and', 'CONJ'), ('die', 'ADV'), ('at', 'ADP'), ('the', 'DET'), ('sight', 'VERB'), ('of', 'ADP'), ('something', 'VERB'), ('strange', 'NOUN'), ('and', 'CONJ'), ('alien', 'VERB'), ('--', '.'), ('like', 'ADP'), ('a', 'DET'), ('spaceship', 'NOUN'), ("''", '.'), ('.', '.')]
# [('``', '.'), ('Maybe', 'VERB'), ("''", '.'), (',', '.'), ('the', 'DET'), ('captain', 'VERB'), ('admitted', 'VERB'), ('.', '.')]
# [('``', '.'), ('At', 'ADP'), ('this', 'DET'), ('stage', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('game', 'ADP'), ('anything', 'VERB'), ('could', 'VERB'), ('be', 'VERB'), ('possible', 'ADJ'), ('.', '.')]
# [('But', 'CONJ'), ("there's", 'NOUN'), ('one', 'NUM'), ('possibility', 'VERB'), ('I', 'PRON'), ('particularly', 'NOUN'), ("don't", 'NOUN'), ('like', 'ADP'), ("''", '.'), ('.', '.')]
# [('``', '.'), ('And', 'CONJ'), ('that', 'ADP'), ('is', 'VERB'), ("''", '.'), ('?', '.'), ('?', '.')]
# [('``', '.'), ('Suppose', 'NOUN'), ('it', 'PRON'), ('was', 'VERB'), ('not', 'ADV'), ('us', 'NOUN'), ('that', 'ADP'), ('killed', 'NOUN'), ('these', 'DET'), ('aliens', 'VERB'), ('.', '.')]
# [('Suppose', 'NOUN'), ('it', 'PRON'), ('is', 'VERB'), ('something', 'VERB'), ('right', 'VERB'), ('on', 'ADP'), ('the', 'DET'), ('planet', 'ADP'), (',', '.'), ('native', 'CONJ'), ('to', 'PRT'), ('it', 'PRON'), ('.', '.')]
# [('I', 'PRON'), ('just', 'ADV'), ('hope', 'VERB'), ('it', 'PRON'), ("doesn't", 'NOUN'), ('work', 'VERB'), ('on', 'ADP'), ('Earthmen', 'NOUN'), ('too', 'ADV'), ('.', '.')]
# [('These', 'DET'), ('critters', 'NOUN'), ('went', 'VERB'), ('real', 'ADV'), ('sudden', 'NOUN'), ("''", '.'), ('.', '.')]
# [('Ekstrohm', 'NOUN'), ('lay', 'VERB'), ('in', 'ADP'), ('his', 'DET'), ('bunk', 'ADJ'), ('and', 'CONJ'), ('thought', 'VERB'), (',', '.'), ('the', 'DET'), ('camp', 'VERB'), ('is', 'VERB'), ('quiet', 'ADJ'), ('.', '.')]
# [('The', 'DET'), ('Earthmen', 'NOUN'), ('made', 'VERB'), ('camp', 'VERB'), ('outside', 'NOUN'), ('the', 'DET'), ('spaceship', 'NOUN'), ('.', '.')]
# [('There', 'PRT'), ('was', 'VERB'), ('no', 'DET'), ('reason', 'NOUN'), ('to', 'PRT'), ('leave', 'VERB'), ('the', 'DET'), ('comfortable', 'VERB'), ('quarters', 'NOUN'), ('inside', 'VERB'), ('the', 'DET'), ('ship', 'VERB'), (',', '.'), ('except', 'NOUN'), ('that', 'ADP'), (',', '.'), ('faced', 'ADJ'), ('with', 'ADP'), ('a', 'DET'), ('possibility', 'VERB'), ('of', 'ADP'), ('sleeping', 'NOUN'), ('on', 'ADP'), ('solid', 'ADJ'), ('ground', 'ADJ'), (',', '.'), ('they', 'PRON'), ('simply', 'VERB'), ('had', 'VERB'), ('to', 'PRT'), ('get', 'NOUN'), ('out', 'PRT'), ('.', '.')]
# [('The', 'DET'), ('camp', 'VERB'), ('was', 'VERB'), ('a', 'DET'), ('cluster', 'ADV'), ('of', 'ADP'), ('aluminum', 'VERB'), ('bubbles', 'ADV'), (',', '.'), ('ringed', 'NOUN'), ('with', 'ADP'), ('a', 'DET'), ('spy', 'NOUN'), ('web', 'ADJ'), ('to', 'PRT'), ('alert', 'ADJ'), ('the', 'DET'), ('Earthmen', 'NOUN'), ('to', 'PRT'), ('the', 'DET'), ('approach', 'ADJ'), ('of', 'ADP'), ('any', 'DET'), ('being', 'VERB'), ('.', '.')]
# [('Each', 'DET'), ('man', 'NOUN'), ('had', 'VERB'), ('a', 'DET'), ('bubble', 'ADP'), ('to', 'PRT'), ('himself', 'PRON'), (',', '.'), ('privacy', 'ADJ'), ('after', 'ADP'), ('the', 'DET'), ('long', 'ADJ'), ('period', 'ADJ'), ('of', 'ADP'), ('enforced', 'NOUN'), ('intimacy', 'ADJ'), ('on', 'ADP'), ('board', 'NOUN'), ('the', 'DET'), ('ship', 'VERB'), ('.', '.')]
# [('Ekstrohm', 'NOUN'), ('lay', 'VERB'), ('in', 'ADP'), ('his', 'DET'), ('bunk', 'ADJ'), ('and', 'CONJ'), ('listened', 'ADJ'), ('to', 'PRT'), ('the', 'DET'), ('sounds', 'ADJ'), ('of', 'ADP'), ('the', 'DET'), ('night', 'NOUN'), ('on', 'ADP'), ('Yancey-6', 'NOUN'), ('138', 'NUM'), ('.', '.')]
# [('There', 'PRT'), ('was', 'VERB'), ('a', 'DET'), ('keening', 'ADJ'), ('of', 'ADP'), ('wind', 'VERB'), (',', '.'), ('and', 'CONJ'), ('a', 'DET'), ('cracking', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('frozen', 'VERB'), ('ground', 'ADJ'), ('.', '.')]
# [('Insects', 'DET'), ('there', 'PRT'), ('were', 'VERB'), ('on', 'ADP'), ('the', 'DET'), ('world', 'ADP'), (',', '.'), ('but', 'CONJ'), ('they', 'PRON'), ('were', 'VERB'), ('frozen', 'VERB'), ('solid', 'ADJ'), ('during', 'ADP'), ('the', 'DET'), ('night', 'NOUN'), (',', '.'), ('only', 'ADV'), ('to', 'PRT'), ('revive', 'NOUN'), ('and', 'CONJ'), ('thaw', 'VERB'), ('in', 'ADP'), ('the', 'DET'), ('morning', 'NOUN'), ('sun', 'NOUN'), ('.', '.')]
# [('The', 'DET'), ('bunk', 'ADJ'), ('he', 'PRON'), ('lay', 'VERB'), ('on', 'ADP'), ('was', 'VERB'), ('much', 'VERB'), ('more', 'ADJ'), ('uncomfortable', 'VERB'), ('than', 'ADP'), ('the', 'DET'), ('acceleration', 'NOUN'), ('couches', 'ADV'), ('on', 'ADP'), ('board', 'NOUN'), ('.', '.')]
# [('Yet', 'ADV'), ('he', 'PRON'), ('knew', 'VERB'), ('the', 'DET'), ('others', 'ADP'), ('were', 'VERB'), ('sleeping', 'NOUN'), ('more', 'ADJ'), ('soundly', 'ADP'), (',', '.'), ('now', 'VERB'), ('that', 'ADP'), ('they', 'PRON'), ('had', 'VERB'), ('renewed', 'VERB'), ('their', 'DET'), ('contact', 'VERB'), ('with', 'ADP'), ('the', 'DET'), ('matter', 'VERB'), ('that', 'ADP'), ('had', 'VERB'), ('birthed', 'ADJ'), ('them', 'PRON'), ('to', 'PRT'), ('send', 'VERB'), ('them', 'PRON'), ('riding', 'NOUN'), ('high', 'ADP'), ('vacuum', 'ADV'), ('.', '.')]
# [('Ekstrohm', 'NOUN'), ('was', 'VERB'), ('not', 'ADV'), ('asleep', 'ADV'), ('.', '.')]
# [('Now', 'VERB'), ('there', 'PRT'), ('could', 'VERB'), ('be', 'VERB'), ('an', 'DET'), ('end', 'NOUN'), ('to', 'PRT'), ('pretending', 'PRON'), ('.', '.')]
# [('He', 'PRON'), ('threw', 'NOUN'), ('off', 'PRT'), ('the', 'DET'), ('light', 'VERB'), ('blanket', 'ADJ'), ('and', 'CONJ'), ('swung', 'VERB'), ('his', 'DET'), ('feet', 'ADP'), ('off', 'PRT'), ('the', 'DET'), ('bunk', 'ADJ'), (',', '.'), ('to', 'PRT'), ('the', 'DET'), ('floor', 'ADV'), ('.', '.')]
# [('Ekstrohm', 'NOUN'), ('stood', 'VERB'), ('up', 'PRT'), ('.', '.')]
# [('There', 'PRT'), ('was', 'VERB'), ('no', 'DET'), ('longer', 'VERB'), ('any', 'DET'), ('need', 'VERB'), ('to', 'PRT'), ('hide', 'NOUN'), ('.', '.')]
# [('But', 'CONJ'), ('what', 'DET'), ('was', 'VERB'), ('there', 'PRT'), ('to', 'PRT'), ('do', 'VERB'), ('?', '.'), ('?', '.')]
# [('What', 'DET'), ('had', 'VERB'), ('changed', 'VERB'), ('for', 'ADP'), ('him', 'PRON'), ('?', '.'), ('?', '.')]
# [('He', 'PRON'), ('no', 'DET'), ('longer', 'VERB'), ('had', 'VERB'), ('to', 'PRT'), ('lie', 'VERB'), ('in', 'ADP'), ('his', 'DET'), ('bunk', 'ADJ'), ('all', 'PRT'), ('night', 'NOUN'), (',', '.'), ('his', 'DET'), ('eyes', 'VERB'), ('closed', 'NOUN'), (',', '.'), ('pretending', 'PRON'), ('to', 'PRT'), ('sleep', 'ADP'), ('.', '.')]
# [('In', 'ADP'), ('privacy', 'ADJ'), ('he', 'PRON'), ('could', 'VERB'), ('walk', 'VERB'), ('around', 'ADP'), (',', '.'), ('leave', 'VERB'), ('the', 'DET'), ('light', 'VERB'), ('on', 'ADP'), (',', '.'), ('read', 'NOUN'), ('.', '.')]
# [('It', 'PRON'), ('was', 'VERB'), ('small', 'DET'), ('comfort', 'VERB'), ('for', 'ADP'), ('insomnia', 'ADV'), ('.', '.')]
# [('Ekstrohm', 'NOUN'), ('never', 'ADV'), ('slept', 'ADV'), ('.', '.')]
# [('Some', 'DET'), ('doctors', 'NOUN'), ('had', 'VERB'), ('informed', 'NOUN'), ('him', 'PRON'), ('he', 'PRON'), ('was', 'VERB'), ('mistaken', 'NOUN'), ('about', 'ADP'), ('this', 'DET'), ('.', '.')]
# [('Actually', 'VERB'), (',', '.'), ('they', 'PRON'), ('said', 'VERB'), (',', '.'), ('he', 'PRON'), ('did', 'VERB'), ('sleep', 'ADP'), (',', '.'), ('but', 'CONJ'), ('so', 'ADV'), ('shortly', 'ADV'), ('and', 'CONJ'), ('fitfully', 'ADV'), ('that', 'ADP'), ('he', 'PRON'), ('forgot', 'VERB'), ('.', '.')]
# [('Others', 'ADP'), ('admitted', 'VERB'), ('he', 'PRON'), ('was', 'VERB'), ('absolutely', 'NOUN'), ('correct', 'VERB'), ('--', '.'), ('he', 'PRON'), ('never', 'ADV'), ('slept', 'ADV'), ('.', '.')]
# [('His', 'DET'), ('body', 'ADJ'), ('processes', 'NOUN'), ('only', 'ADV'), ('slowed', 'ADV'), ('down', 'PRT'), ('enough', 'ADV'), ('for', 'ADP'), ('him', 'PRON'), ('to', 'PRT'), ('dispell', 'NOUN'), ('fatigue', 'ADJ'), ('poisons', 'ADP'), ('.', '.')]
# [('Occasionally', 'ADV'), ('he', 'PRON'), ('fell', 'ADP'), ('into', 'ADP'), ('a', 'DET'), ('waking', 'NOUN'), (',', '.'), ('gritty-eyed', 'NOUN'), ('stupor', 'ADJ'), (';', '.'), (';', '.')]
# [('but', 'CONJ'), ('he', 'PRON'), ('never', 'ADV'), ('slept', 'ADV'), ('.', '.')]
# [('Never', 'ADV'), ('at', 'ADP'), ('all', 'PRT'), ('.', '.')]
# [('Naturally', 'ADV'), (',', '.'), ('he', 'PRON'), ("couldn't", 'NOUN'), ('let', 'VERB'), ('his', 'DET'), ('shipmates', 'VERB'), ('know', 'PRON'), ('this', 'DET'), ('.', '.')]
# [('Insomnia', 'ADV'), ('would', 'VERB'), ('ground', 'ADJ'), ('him', 'PRON'), ('from', 'ADP'), ('the', 'DET'), ('Exploration', 'VERB'), ('Service', 'NOUN'), (',', '.'), ('on', 'ADP'), ('physiological', 'DET'), ('if', 'VERB'), ('not', 'ADV'), ('psychological', 'DET'), ('grounds', 'ADJ'), ('.', '.')]
# [('He', 'PRON'), ('had', 'VERB'), ('to', 'PRT'), ('hide', 'NOUN'), ('it', 'PRON'), ('.', '.')]
# Accuracy 71.85180231391693

# %% [markdown]
# ## Test Report
#
# - 56 with 40 sentences, 300d
# - 71 with 100 sentences, 300d, 1000 sentences test
# - 50 with 40 sentences, 50d
# - 58 with 100 sentences, 50d
